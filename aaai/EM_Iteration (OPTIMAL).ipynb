# %% [markdown]
# # EM Iteration Notebook
#
# From AAAI Submission's optimal test, using to compare with current system. Exactly as it was.
#
# ---
#
# ### Required:
# - Tensors:
#     - `X_test`: Testing Image Tensor
#     - `Y_test`: Testing Label Tensor
#     - `X_train`: Training Image Tensor
#     - `X_val`: Validation Image Tensor
#     - `train_offsets`: Window offsets for scanning `Y_train` as path to csv.
#     - `val_offsets`: Window offsets for scanning `Y_val` as path to csv.
#
# - `segments`: Candidate line segments accross training raster in directory
#
# - `preweights`: pre-trained Weights for U-Net model on the passed `X_train`, `X_val` tensors
#
# - `initial_pmap`: pmap output from baseline data

# %%
# -- All Imports --
import os, sys, time, csv

import numpy as np
import random as rand
import geopandas as gpd
import matplotlib.pyplot as plt

from lib.ModuleTools import *
from lib.UnetTools import *
import lib.GeoTools as gt
import lib.ShapeTools as st
import lib.EMTools as emt
import lib.LineGen as lg

# Parameters, Files
from lib.EMconfig import *
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
# -- Module Information --
module_data = {
    'name': 'AAAI_EM', # Module Name
    'desc': 'Iterate over EM process', # Module Description
    'test_name': 'aaai_emtest', # Default test name
    'csv': 'aaai_master.csv', # Csv path
    'verbose': True # Default verbosity
}
test = ModuleTest(module_data)
# -------------------------


# -- Iteration Parameters --
iteration = {}

# Number of EM iterations
EM_target = wrap(2, iteration) 
 
# Constant Value for Learning Rate Schedule 
lr_const = wrap(2, iteration)

# optionally reset layer weights between iterations
rebuild_model = wrap( True, iteration)

# (epsilon) Chance that a candidate will be selected outside of the top candidate, within the K top candidates.
random_candidate_chance = wrap( 0.05, iteration)

# (K) Consider K top-weighted segments. set 1 for top candidate, set 0 to consider all.
weight_limit = wrap( 13, iteration)



# The parameters below are defined in the /lib/EMconfig.py file. 
test.Pgroup("Iteration", iteration)
test.Pgroup("Environment", env)
test.Pgroup("Tensor Data", TensorConfig)
test.Pgroup("Annotation Configuration", Annotations)
test.Pgroup("UNet Config", unetcfg)
test.Pgroup('Baseline Directories', inputDirs)
test.Fgroup('Input Arrays', InputArrays)
test.Fgroup('Source_Data', sourceData)

# ---------------
print(dt.now().strftime('Hyperparameters saved on %a at %I:%M:%S %p.'))
# Out:
# /home/jiang-ws1/.virtualenvs/geo_errors/lib/python3.7/site-packages/geopandas/_compat.py:88: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.8.1-CAPI-1.13.3). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string
# Describe emtest_05:testing confusion output
# Hyperparameters saved on Wed at 10:41:58 PM.

# %% [markdown]
# ## Load Baseline Data

# %%
section_tstamp = time.time()
section_name = 'Prepare Base Data'
# --------------------

# 1. Shapefile Precisions
imp_labels = st.Flatten_Frame(imp_labels)
sourcePrecision = emt.GDF_Precision(gt_labels, imp_labels, precisionBuffer)
prevPrecision = sourcePrecision


# 2. Check Array Shapes
print("-- Inputs  --")
for (title, arr) in [('X_train',X_train), ('X_val',X_val), ('X_test',X_test), ('Y_test',Y_test)]:
    print("{} Shape: {}".format(title, arr.shape))
"""
# 3. Load Candidates 
candidateFrames = lg.LoadCandidates(CandidateDirectory)
print("\n-- Candidates  --")
print("Loaded Candidate Frames: {}".format(len(candidateFrames)))
print("Candidates Per Segment (~): {}".format(len(candidateFrames[0].geometry)))

# 4. Add Windows and Masks to candidates
tstamp = time.time()
candidateFrames = [emt.CandidateWindows(initial_pmap, c_frame, weightBuffer) for c_frame in candidateFrames]
"""

# %store -r candidateFrames
# print("Masked and Windowed candidate frames in {} sec.".format(time.time()-tstamp))
# print(dt.now().strftime('%a at %I:%M:%S%p'))


# --------------------
section_data = {'time': time.time()-section_tstamp, 'stamp': section_tstamp}
test.Section(section_name, section_data)
# --------------------
if test.verbose:
    print("\n{} ({:02}) Complete.".format(section_name, len(test.sectionNames)))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
# Out:
# -- Inputs  --
# X_train Shape: (2792, 224, 224, 7)
# X_val Shape: (160, 224, 224, 7)
# X_test Shape: (200, 224, 224, 7)
# Y_test Shape: (200, 224, 224, 1)
#
# Prepare Base Data (01) Complete.
# Wed at 10:45:12PM

# %%
mirror_strategy = tf.distribute.MirroredStrategy(devices=['/gpu:0', '/gpu:1', '/gpu:2', '/gpu:3'])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')

# %%
section_tstamp = time.time()
section_name = 'Prepare Model'
# --------------------


# 5. Load Unet Model
from tensorflow.keras.optimizers import Adam
with mirror_strategy.scope():
    unet_model = UNET_7_224()
    unet_model.compile(optimizer=Adam(lr=0.1), loss=dice_coef_loss, metrics=metrics)
    unet_model.load_weights(preTrainedPath)

print("\nInitialized U_Net model.")
print(dt.now().strftime('%a at %I:%M:%S%p'))

# 6. Evaluate Unet Model
# Save Training Results
train_results = emt.Evaluate(X_train, Y_train, unet_model)
# Save Validation Results
val_results = emt.Evaluate(X_val, Y_val, unet_model)
# Save Testing Results
test_results = emt.Evaluate(X_test, Y_test, unet_model)

y_pred=np.copy(unet_model.predict(X_test))
y_pred = np.round(y_pred)
y_true=np.copy(Y_test)
y_pred.shape = y_pred.shape[0]* y_pred.shape[1]*y_pred.shape[2]* y_pred.shape[3]
y_true.shape = y_true.shape[0]* y_true.shape[1]*y_true.shape[2]* y_true.shape[3]

c_matrix = confusion_matrix(y_true, y_pred, labels=[0, 1])
print("Confusion Matrix", c_matrix)
report_unet = classification_report(y_true, y_pred)
print("report_unet", report_unet)

# Print the baseline metrics
print("\nRan Initial U_Net evaluation:")
print("\nBaseline Training Results:")
print("- {}".format(train_results[0]))
print("- {}".format(train_results[1]))
print("\nBaseline Validation Results:")
print("- {}".format(val_results[0]))
print("- {}".format(val_results[1]))
print("\nBaseline Testing Results:")
print("- {}".format(test_results[0]))
print("- {}".format(test_results[1]))
print("\nBaseline Shape Metrics")
print("- Precision: {:.2f}".format(sourcePrecision*100))
print(dt.now().strftime('%a at %I:%M:%S%p'))


# Save initial EM Data 
test.Results("Baseline Data", {
    'Precision': '{:.2f}%'.format(sourcePrecision*100),
    'UNet: Training Results': train_results,
    'UNet: Validation Results': val_results,
    'UNet: Testing Results': test_results,
    'UNet: Report': report_unet, 
    'UNet: Confusion Matrix': c_matrix
})


# Create Matrix to save step data in seperate CSV
dataMatrix = {
    'precision': [sourcePrecision*100],
    
    'trainDice': [train_results[0]],
    'trainF1Score': [train_results[1]],
    
    'valDice': [val_results[0]],
    'valF1Score': [val_results[1]],
    
    'testDice': [test_results[0]],
    'testF1Score': [test_results[1]]
}

# --------------------
section_data = {'time': time.time()-section_tstamp, 'stamp': section_tstamp}
test.Section(section_name, section_data)
# --------------------
if test.verbose:
    print("\n{} ({:02}) Complete.".format(section_name, len(test.sectionNames)))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
#
# Initialized U_Net model.
# Wed at 10:48:22PM
# Confusion Matrix [[9774361  123616]
#  [  58450   78773]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99   9897977
#          1.0       0.39      0.57      0.46    137223
#
#     accuracy                           0.98  10035200
#    macro avg       0.69      0.78      0.73  10035200
# weighted avg       0.99      0.98      0.98  10035200
#
#
# Ran Initial U_Net evaluation:
#
# Baseline Training Results:
# - Dice Coef: 41.589%
# - F1 Score: 41.590%
#
# Baseline Validation Results:
# - Dice Coef: 34.709%
# - F1 Score: 34.704%
#
# Baseline Testing Results:
# - Dice Coef: 46.384%
# - F1 Score: 46.390%
#
# Baseline Shape Metrics
# - Precision: 27.39
# Wed at 10:49:31PM
#
# Prepare Model (02) Complete.
# Wed at 10:49:31PM

# %% [markdown]
# ## EM Iteration

# %%
# Prepare EM iterator index.
EM_iterator = 0
print()
print("Target Steps:", EM_target)
print(rebuild_model)
random_candidate_chance = 0.05

import random

# -----------------------------------------------------------------------------
# Begin Iteration -------------------------------------------------------------
while EM_iterator < EM_target:   
    
    # ---------------------------
    # 0. Initialization
    # ---------------------------
    section_tstamp = time.time()
    section_name = 'EM_Step {:02}'.format(EM_iterator)

    # Create folder for em step
    emfolder = os.path.join(test.dir, 'Step_{:02}'.format(EM_iterator))
    if not os.path.exists(emfolder): os.mkdir(emfolder)

    print("\n\nEM Step {:02} begun.".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    anno_stamp = time.time()
    
    # ---------------------------
    # 1. Creating New Annotations
    # ---------------------------

    # 1.1 Get probability output map from last model (Skip first step since it was pre-generated)
    pmap_fp = os.path.join(emfolder, 'pmap_{:02}.tif'.format(EM_iterator))
    p_output = emt.Get_Pmap(train_raster, WinShape, unet_model, pmap_fp)
    
    print("\nGenerated Probability Output Map from previous model. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    
    # 1.2 Weight Candidate Frames
    newSegments = []
    for frame in candidateFrames:
        
        # Get Candidate Weights
        weightedFrame = emt.WeightCandidates(p_output, frame)
        
        # Select Likely or Top Candidate 
        if random.uniform(0,1) < random_candidate_chance:
            # Use 'likely' candidate (ENSURE Select_Candidate() FUNCTION IS UPDATED (lib/EMTools.py))
            newSegments.append(emt.Select_Candidate(weightedFrame, 'weight', weight_limit))
        else:
            # Use top candidate
            newSegments.append(emt.Top_Candidate(weightedFrame, 'weight'))
        
        
    # 1.3 Convert List of segments to GeoDataFrame
    newSegmentFrame = gpd.GeoDataFrame(geometry=newSegments, crs=candidateFrames[0].crs)
    newSegmentFrame.to_file(os.path.join(emfolder, 'segments_{:02}.shp'.format(EM_iterator)))

    # 1.4 Connect top segments:
    newAnnotation = emt.Connect_Lines(newSegmentFrame, maxRepairDist)
    newAnnotation.to_file(os.path.join(emfolder, 'annotation_{:02}.shp'.format(EM_iterator)))

    # 1.5 Save mean precision of this annotation.
    annoPrecision = emt.GDF_Precision(gt_labels, newAnnotation, precisionBuffer)


    
    print("\nCreated New Annotation. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    anno_time = time.time() - anno_stamp
    
    # ---------------------------
    # 2. Create new Label Tensors
    # ---------------------------
    
    # 2.1 Rasterize New Labels
    buff_anno = st.GDF_Buffer(newAnnotation, labelBuffer, flatten=True)
    anno_raster = st.GDF_Rasterize(buff_anno, train_raster)
    
    # 2.2 Read Y_train, Y_val
    Y_train = gt.ResampleTiles(anno_raster, train_offsets_fp)
    Y_val = gt.ResampleTiles(anno_raster, val_offsets_fp)
    
    # 2.2 Augment Y_train, Y_val
    Y_train = gt.AugmentImages(Y_train, h_flip=train_h_flip, v_flip=train_v_flip, rotate=train_rotate)
    Y_val = gt.AugmentImages(Y_val, h_flip=val_h_flip, v_flip=val_v_flip, rotate=val_rotate)
    
    print("\nCreated Y_train {} and Y_val {}. (Step {:02})".format(Y_train.shape, Y_val.shape, EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    
    
    
    
    # ---------------------------
    # 3. Re-Train U-Net 
    # ---------------------------
    
    # 3.1 Load Callbacks 
    callbacks = SetCallbacks(emfolder + '/model_{:02}.h5'.format(EM_iterator))
    
    # 3.2 Determine Learning Rate from schedule
    EM_learningRate = Step_LR_Schedule(learningRate, EM_iterator, EM_target, lr_const)
    print("\nNew Learning Rate: {:.6f}. (Step {:02})".format(EM_learningRate, EM_iterator))
        
    training_stamp = time.time()
    with mirror_strategy.scope():
        unet_model = UNET_7_224()
        unet_model.compile(optimizer=Adam(lr=EM_learningRate), loss=dice_coef_loss, metrics=metrics)
        TrainData = unet_model.fit(X_train, Y_train, validation_data=(X_val, Y_val), shuffle=useShuffle, batch_size=batchSize, epochs=epochs, callbacks=callbacks)
    training_time = time.time() - training_stamp
    
    
    training_metrics = {
        'f1': Get_Metric_Data(TrainData, 'f1_score'),
        'dice_coef': Get_Metric_Data(TrainData, 'dice_coef'),
        'loss': Get_Metric_Data(TrainData, 'loss')
    }

    train_metrics_fp = os.path.join(emfolder, 'train_curve_{:02}.csv'.format(EM_iterator))
    with open(train_metrics_fp, 'a+', newline='\n') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter= ',')
        for key, data in training_metrics.items():
            csvwriter.writerow(['Training {}'.format(key)])
            csvwriter.writerow(data)


    validation_metrics = {
        'f1': Get_Metric_Data(TrainData, 'val_f1_score'),
        'dice_coef': Get_Metric_Data(TrainData, 'val_dice_coef'),
        'loss': Get_Metric_Data(TrainData, 'val_loss')
    }   

    val_metrics_fp = os.path.join(emfolder, 'val_curve_{:02}.csv'.format(EM_iterator))
    with open(val_metrics_fp, 'a+', newline='\n') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter= ',')
        for key, data in validation_metrics.items():
            csvwriter.writerow(['Validation {}'.format(key)])
            csvwriter.writerow(data)
    
    
    SaveHistory(TrainData, os.path.join(emfolder, 'trainingResults_{:02}'.format(EM_iterator)), test.end) # Save Plots
    
    print("\nCompleted UNet Training. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    


    # ---------------------------
    # 4. Evaluate Model
    # ---------------------------

    
    # Training Results
    train_results = emt.Evaluate(X_train, Y_train, unet_model)
    # Validation Results
    val_results = emt.Evaluate(X_val, Y_val, unet_model)
    # Testing Results
    test_results = emt.Evaluate(X_test, Y_test, unet_model)
    
    y_pred=np.copy(unet_model.predict(X_test))
    y_pred = np.round(y_pred)
    y_true=np.copy(Y_test)
    y_pred.shape = y_pred.shape[0]* y_pred.shape[1]*y_pred.shape[2]* y_pred.shape[3]
    y_true.shape = y_true.shape[0]* y_true.shape[1]*y_true.shape[2]* y_true.shape[3]

    c_matrix = confusion_matrix(y_true, y_pred, labels=[0, 1])
    print("confusion_unet", c_matrix)
    report_unet = classification_report(y_true, y_pred)
    print("report_unet", report_unet)

    # print
    print("\nCompleted Unet Evaluation. (Step {:02})".format(EM_iterator))
    print("\nTraining Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(train_results[0]))
    print("- {}".format(train_results[1]))
    print("\nValidation Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(val_results[0]))
    print("- {}".format(val_results[1]))   
    print("\nTesting Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(test_results[0]))
    print("- {}".format(test_results[1]))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    
    
    # ---------------------------
    # 5. Save Step Data
    # ---------------------------
    
    # Save to dict for seperate CSV
    dataMatrix['precision'].append(annoPrecision*100)
    dataMatrix['trainDice'].append(train_results[0]) 
    dataMatrix['trainF1Score'].append(train_results[1]) 
    dataMatrix['valDice'].append(val_results[0]) 
    dataMatrix['valF1Score'].append(val_results[1]) 
    dataMatrix['testDice'].append(test_results[0]) 
    dataMatrix['testF1Score'].append(test_results[1]) 
    
    
    # Save EM Step Data 
    test.Results("EM Data {:02}".format(EM_iterator), {
            
        'Time Elapsed: Re-training': training_time,
        'Time Elapsed: New Annotation': anno_time,
            
        'Precision': '{:.2f}%'.format(annoPrecision*100),
        'SourceDelta': '{:.2f}%'.format((annoPrecision-sourcePrecision)*100),
        'StepDelta': '{:.2f}%'.format((annoPrecision-prevPrecision)*100),
        
        'UNet: LR': str(EM_learningRate),
        'UNet: Epochs': str(len(TrainData.history['dice_coef'])),
        
        'UNet: Training Results': train_results,
        'UNet: Validation Results': val_results,
        'UNet: Testing Results': test_results,
        'UNet: Confusion Matrix': c_matrix,
        'UNet: Report': report_unet
    })
    # Save as section
    section_data = {'time': time.time()-section_tstamp, 'stamp': section_tstamp}
    test.Section(section_name, section_data)
    
    # Print step data
    print("\n{} ({:02}) Complete.".format(section_name, len(test.sectionNames)))
    print('- Precision: {:.2f}%'.format(annoPrecision*100))
    print('- SourceDelta: {:.2f}%'.format((annoPrecision-sourcePrecision)*100))
    print('- StepDelta: {:.2f}%'.format((annoPrecision-prevPrecision)*100))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    print("----------------------------------\n\n")
    
    # Increase iterator and save previous precision for step_delta
    EM_iterator += 1
    prevPrecision = annoPrecision
# Out:
# Target Steps: 2
# True
#
#
# EM Step 00 begun.
# Wed at 10:53:45PM
#
# Generated Probability Output Map from previous model. (Step 00)
# Wed at 10:54:11PM
#
# Created New Annotation. (Step 00)
# Wed at 10:54:58PM
#
# Created Y_train (2792, 224, 224, 1) and Y_val (160, 224, 224, 1). (Step 00)
# Wed at 10:55:07PM
#
# New Learning Rate: 0.100000. (Step 00)
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# 88/88 [==============================] - 15s 169ms/step - accuracy: 0.8920 - dice_coef: 0.1269 - f1_score: 0.1272 - loss: -0.1269 - val_accuracy: 0.0166 - val_dice_coef: 0.0323 - val_f1_score: 0.0323 - val_loss: -0.0323 - lr: 0.1000
# Epoch 2/50
# 88/88 [==============================] - 12s 131ms/step - accuracy: 0.9091 - dice_coef: 0.1545 - f1_score: 0.1545 - loss: -0.1557 - val_accuracy: 0.1713 - val_dice_coef: 0.0351 - val_f1_score: 0.0351 - val_loss: -0.0351 - lr: 0.1000
# Epoch 3/50
# 88/88 [==============================] - 12s 131ms/step - accuracy: 0.9114 - dice_coef: 0.1696 - f1_score: 0.1696 - loss: -0.1694 - val_accuracy: 0.2902 - val_dice_coef: 0.0398 - val_f1_score: 0.0398 - val_loss: -0.0398 - lr: 0.1000
# Epoch 4/50
# 88/88 [==============================] - 12s 131ms/step - accuracy: 0.9116 - dice_coef: 0.1829 - f1_score: 0.1829 - loss: -0.1840 - val_accuracy: 0.4939 - val_dice_coef: 0.0456 - val_f1_score: 0.0456 - val_loss: -0.0456 - lr: 0.1000
# Epoch 5/50
# 88/88 [==============================] - 12s 131ms/step - accuracy: 0.9118 - dice_coef: 0.1812 - f1_score: 0.1812 - loss: -0.1818 - val_accuracy: 0.9157 - val_dice_coef: 0.1991 - val_f1_score: 0.0991 - val_loss: -0.1991 - lr: 0.1000
# Epoch 6/50
# 88/88 [==============================] - 12s 131ms/step - accuracy: 0.9122 - dice_coef: 0.1850 - f1_score: 0.1850 - loss: -0.1864 - val_accuracy: 0.9084 - val_dice_coef: 0.2711 - val_f1_score: 0.1211 - val_loss: -0.2711 - lr: 0.1000
# Epoch 7/50
# 88/88 [==============================] - 12s 131ms/step - accuracy: 0.9134 - dice_coef: 0.1939 - f1_score: 0.1939 - loss: -0.1954 - val_accuracy: 0.9161 - val_dice_coef: 0.4585 - val_f1_score: 0.1085 - val_loss: -0.4585 - lr: 0.1000
# Epoch 8/50
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9123 - dice_coef: 0.1903 - f1_score: 0.1903 - loss: -0.1910 - val_accuracy: 0.6365 - val_dice_coef: 0.0469 - val_f1_score: 0.0469 - val_loss: -0.0469 - lr: 0.1000
# Epoch 9/50
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9142 - dice_coef: 0.1908 - f1_score: 0.1908 - loss: -0.1913 - val_accuracy: 0.8892 - val_dice_coef: 0.1081 - val_f1_score: 0.1081 - val_loss: -0.1081 - lr: 0.1000
# Epoch 10/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9137 - dice_coef: 0.1914 - f1_score: 0.1914 - loss: -0.1920 - val_accuracy: 0.8835 - val_dice_coef: 0.1128 - val_f1_score: 0.1128 - val_loss: -0.1128 - lr: 0.1000
# Epoch 11/50
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9110 - dice_coef: 0.1926 - f1_score: 0.1926 - loss: -0.1933 - val_accuracy: 0.9035 - val_dice_coef: 0.1705 - val_f1_score: 0.1205 - val_loss: -0.1705 - lr: 0.1000
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9129 - dice_coef: 0.1964 - f1_score: 0.1964 - loss: -0.1969
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9129 - dice_coef: 0.1964 - f1_score: 0.1964 - loss: -0.1969 - val_accuracy: 0.8984 - val_dice_coef: 0.1237 - val_f1_score: 0.1237 - val_loss: -0.1237 - lr: 0.1000
# Epoch 13/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9134 - dice_coef: 0.2004 - f1_score: 0.2004 - loss: -0.2002 - val_accuracy: 0.9068 - val_dice_coef: 0.1719 - val_f1_score: 0.1219 - val_loss: -0.1719 - lr: 0.0500
# Epoch 14/50
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9139 - dice_coef: 0.2017 - f1_score: 0.2017 - loss: -0.2034 - val_accuracy: 0.9097 - val_dice_coef: 0.3209 - val_f1_score: 0.1209 - val_loss: -0.3209 - lr: 0.0500
# Epoch 15/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9124 - dice_coef: 0.2038 - f1_score: 0.2038 - loss: -0.2045 - val_accuracy: 0.9042 - val_dice_coef: 0.1221 - val_f1_score: 0.1221 - val_loss: -0.1221 - lr: 0.0500
# Epoch 16/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9135 - dice_coef: 0.2049 - f1_score: 0.2049 - loss: -0.2060 - val_accuracy: 0.9153 - val_dice_coef: 0.3494 - val_f1_score: 0.1000 - val_loss: -0.3494 - lr: 0.0500
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9146 - dice_coef: 0.2051 - f1_score: 0.2051 - loss: -0.2061
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9146 - dice_coef: 0.2051 - f1_score: 0.2051 - loss: -0.2061 - val_accuracy: 0.9138 - val_dice_coef: 0.4130 - val_f1_score: 0.1131 - val_loss: -0.4130 - lr: 0.0500
# Epoch 18/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9135 - dice_coef: 0.2079 - f1_score: 0.2079 - loss: -0.2085 - val_accuracy: 0.9124 - val_dice_coef: 0.4150 - val_f1_score: 0.1150 - val_loss: -0.4150 - lr: 0.0250
# Epoch 19/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9144 - dice_coef: 0.2090 - f1_score: 0.2090 - loss: -0.2098 - val_accuracy: 0.9120 - val_dice_coef: 0.2118 - val_f1_score: 0.1118 - val_loss: -0.2118 - lr: 0.0250
# Epoch 20/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9131 - dice_coef: 0.2080 - f1_score: 0.2080 - loss: -0.2085 - val_accuracy: 0.9103 - val_dice_coef: 0.3213 - val_f1_score: 0.1213 - val_loss: -0.3213 - lr: 0.0250
# Epoch 21/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9139 - dice_coef: 0.2103 - f1_score: 0.2103 - loss: -0.2095 - val_accuracy: 0.9101 - val_dice_coef: 0.2649 - val_f1_score: 0.1149 - val_loss: -0.2649 - lr: 0.0250
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9144 - dice_coef: 0.2064 - f1_score: 0.2064 - loss: -0.2067
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9144 - dice_coef: 0.2064 - f1_score: 0.2064 - loss: -0.2067 - val_accuracy: 0.9148 - val_dice_coef: 0.3082 - val_f1_score: 0.1081 - val_loss: -0.3082 - lr: 0.0250
# Epoch 23/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9132 - dice_coef: 0.2109 - f1_score: 0.2109 - loss: -0.2116 - val_accuracy: 0.9127 - val_dice_coef: 0.3654 - val_f1_score: 0.1154 - val_loss: -0.3654 - lr: 0.0125
# Epoch 24/50
# 88/88 [==============================] - 11s 130ms/step - accuracy: 0.9153 - dice_coef: 0.2100 - f1_score: 0.2100 - loss: -0.2103 - val_accuracy: 0.9102 - val_dice_coef: 0.3170 - val_f1_score: 0.1170 - val_loss: -0.3170 - lr: 0.0125
# Epoch 25/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9138 - dice_coef: 0.2099 - f1_score: 0.2099 - loss: -0.2103 - val_accuracy: 0.9067 - val_dice_coef: 0.1149 - val_f1_score: 0.1149 - val_loss: -0.1149 - lr: 0.0125
# Epoch 26/50
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9149 - dice_coef: 0.2130 - f1_score: 0.2130 - loss: -0.2130 - val_accuracy: 0.9117 - val_dice_coef: 0.4148 - val_f1_score: 0.1148 - val_loss: -0.4148 - lr: 0.0125
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9159 - dice_coef: 0.2144 - f1_score: 0.2144 - loss: -0.2149
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9159 - dice_coef: 0.2144 - f1_score: 0.2144 - loss: -0.2149 - val_accuracy: 0.9119 - val_dice_coef: 0.3658 - val_f1_score: 0.1157 - val_loss: -0.3658 - lr: 0.0125
#
# Completed UNet Training. (Step 00)
# Wed at 11:00:40PM
# confusion_unet [[9750497  147480]
#  [  79854   57369]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99   9897977
#          1.0       0.28      0.42      0.34    137223
#
#     accuracy                           0.98  10035200
#    macro avg       0.64      0.70      0.66  10035200
# weighted avg       0.98      0.98      0.98  10035200
#
#
# Completed Unet Evaluation. (Step 00)
#
# Training Results (Step 00):
# - Dice Coef: 22.669%
# - F1 Score: 22.670%
#
# Validation Results (Step 00):
# - Dice Coef: 17.278%
# - F1 Score: 17.275%
#
# Testing Results (Step 00):
# - Dice Coef: 33.541%
# - F1 Score: 33.542%
# Wed at 11:01:44PM
#
# EM_Step 00 (03) Complete.
# - Precision: 22.45%
# - SourceDelta: -4.94%
# - StepDelta: -4.94%
# Wed at 11:01:44PM
# ----------------------------------
#
#
#
#
# EM Step 01 begun.
# Wed at 11:01:44PM
# Generated Probability Output Map from previous model. (Step 01)
# Wed at 11:02:08PM
#
# Created New Annotation. (Step 01)
# Wed at 11:02:56PM
#
# Created Y_train (2792, 224, 224, 1) and Y_val (160, 224, 224, 1). (Step 01)
# Wed at 11:03:05PM
#
# New Learning Rate: 0.050000. (Step 01)
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# 88/88 [==============================] - 14s 160ms/step - accuracy: 0.8961 - dice_coef: 0.2407 - f1_score: 0.2427 - loss: -0.2405 - val_accuracy: 0.0367 - val_dice_coef: 0.0343 - val_f1_score: 0.0343 - val_loss: -0.0343 - lr: 0.0500
# Epoch 2/50
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9224 - dice_coef: 0.3064 - f1_score: 0.3064 - loss: -0.3072 - val_accuracy: 0.3507 - val_dice_coef: 0.0275 - val_f1_score: 0.0275 - val_loss: -0.0275 - lr: 0.0500
# Epoch 3/50
# 88/88 [==============================] - 12s 132ms/step - accuracy: 0.9248 - dice_coef: 0.3338 - f1_score: 0.3339 - loss: -0.3340 - val_accuracy: 0.8949 - val_dice_coef: 0.1577 - val_f1_score: 0.1577 - val_loss: -0.1577 - lr: 0.0500
# Epoch 4/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9247 - dice_coef: 0.3358 - f1_score: 0.3359 - loss: -0.3370 - val_accuracy: 0.9204 - val_dice_coef: 0.0645 - val_f1_score: 0.0644 - val_loss: -0.0645 - lr: 0.0500
# Epoch 5/50
# 88/88 [==============================] - 12s 132ms/step - accuracy: 0.9253 - dice_coef: 0.3525 - f1_score: 0.3525 - loss: -0.3517 - val_accuracy: 0.9119 - val_dice_coef: 0.2107 - val_f1_score: 0.2107 - val_loss: -0.2107 - lr: 0.0500
# Epoch 6/50
# 88/88 [==============================] - 12s 132ms/step - accuracy: 0.9255 - dice_coef: 0.3575 - f1_score: 0.3575 - loss: -0.3580 - val_accuracy: 0.9213 - val_dice_coef: 0.2202 - val_f1_score: 0.2202 - val_loss: -0.2202 - lr: 0.0500
# Epoch 7/50
# 88/88 [==============================] - 12s 133ms/step - accuracy: 0.9264 - dice_coef: 0.3643 - f1_score: 0.3643 - loss: -0.3657 - val_accuracy: 0.9261 - val_dice_coef: 0.2397 - val_f1_score: 0.1666 - val_loss: -0.2397 - lr: 0.0500
# Epoch 8/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9262 - dice_coef: 0.3648 - f1_score: 0.3648 - loss: -0.3655 - val_accuracy: 0.9137 - val_dice_coef: 0.2125 - val_f1_score: 0.2125 - val_loss: -0.2125 - lr: 0.0500
# Epoch 9/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9264 - dice_coef: 0.3638 - f1_score: 0.3638 - loss: -0.3659 - val_accuracy: 0.9121 - val_dice_coef: 0.2114 - val_f1_score: 0.2114 - val_loss: -0.2114 - lr: 0.0500
# Epoch 10/50
# 88/88 [==============================] - 12s 132ms/step - accuracy: 0.9269 - dice_coef: 0.3704 - f1_score: 0.3704 - loss: -0.3726 - val_accuracy: 0.9256 - val_dice_coef: 0.2404 - val_f1_score: 0.1904 - val_loss: -0.2404 - lr: 0.0500
# Epoch 11/50
# 88/88 [==============================] - 12s 133ms/step - accuracy: 0.9265 - dice_coef: 0.3677 - f1_score: 0.3677 - loss: -0.3689 - val_accuracy: 0.9244 - val_dice_coef: 0.2625 - val_f1_score: 0.2126 - val_loss: -0.2625 - lr: 0.0500
# Epoch 12/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9268 - dice_coef: 0.3734 - f1_score: 0.3735 - loss: -0.3756 - val_accuracy: 0.9227 - val_dice_coef: 0.2156 - val_f1_score: 0.2156 - val_loss: -0.2156 - lr: 0.0500
# Epoch 13/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9270 - dice_coef: 0.3801 - f1_score: 0.3801 - loss: -0.3799 - val_accuracy: 0.9230 - val_dice_coef: 0.2171 - val_f1_score: 0.2172 - val_loss: -0.2171 - lr: 0.0500
# Epoch 14/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9269 - dice_coef: 0.3764 - f1_score: 0.3764 - loss: -0.3777 - val_accuracy: 0.9247 - val_dice_coef: 0.2465 - val_f1_score: 0.2097 - val_loss: -0.2465 - lr: 0.0500
# Epoch 15/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9272 - dice_coef: 0.3809 - f1_score: 0.3810 - loss: -0.3821 - val_accuracy: 0.9202 - val_dice_coef: 0.2254 - val_f1_score: 0.2254 - val_loss: -0.2254 - lr: 0.0500
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9266 - dice_coef: 0.3844 - f1_score: 0.3844 - loss: -0.3851
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9266 - dice_coef: 0.3844 - f1_score: 0.3844 - loss: -0.3851 - val_accuracy: 0.9141 - val_dice_coef: 0.2162 - val_f1_score: 0.2163 - val_loss: -0.2162 - lr: 0.0500
# Epoch 17/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9276 - dice_coef: 0.3894 - f1_score: 0.3894 - loss: -0.3904 - val_accuracy: 0.9097 - val_dice_coef: 0.2136 - val_f1_score: 0.2138 - val_loss: -0.2136 - lr: 0.0250
# Epoch 18/50
# 88/88 [==============================] - 11s 128ms/step - accuracy: 0.9276 - dice_coef: 0.3898 - f1_score: 0.3898 - loss: -0.3907 - val_accuracy: 0.9248 - val_dice_coef: 0.2144 - val_f1_score: 0.2141 - val_loss: -0.2144 - lr: 0.0250
# Epoch 19/50
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9274 - dice_coef: 0.3964 - f1_score: 0.3964 - loss: -0.3956 - val_accuracy: 0.9260 - val_dice_coef: 0.2023 - val_f1_score: 0.1954 - val_loss: -0.2023 - lr: 0.0250
# Epoch 20/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9278 - dice_coef: 0.3997 - f1_score: 0.3997 - loss: -0.3997 - val_accuracy: 0.9239 - val_dice_coef: 0.2188 - val_f1_score: 0.2185 - val_loss: -0.2188 - lr: 0.0250
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9276 - dice_coef: 0.3960 - f1_score: 0.3960 - loss: -0.3965
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9276 - dice_coef: 0.3960 - f1_score: 0.3960 - loss: -0.3965 - val_accuracy: 0.9233 - val_dice_coef: 0.2167 - val_f1_score: 0.2167 - val_loss: -0.2167 - lr: 0.0250
# Epoch 22/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9274 - dice_coef: 0.3959 - f1_score: 0.3959 - loss: -0.3981 - val_accuracy: 0.9246 - val_dice_coef: 0.2201 - val_f1_score: 0.2201 - val_loss: -0.2201 - lr: 0.0125
# Epoch 23/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9285 - dice_coef: 0.4122 - f1_score: 0.4122 - loss: -0.4123 - val_accuracy: 0.9240 - val_dice_coef: 0.2225 - val_f1_score: 0.2226 - val_loss: -0.2225 - lr: 0.0125
# Epoch 24/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9283 - dice_coef: 0.4060 - f1_score: 0.4060 - loss: -0.4076 - val_accuracy: 0.9244 - val_dice_coef: 0.2221 - val_f1_score: 0.2219 - val_loss: -0.2221 - lr: 0.0125
# Epoch 25/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9281 - dice_coef: 0.4083 - f1_score: 0.4083 - loss: -0.4089 - val_accuracy: 0.9251 - val_dice_coef: 0.2214 - val_f1_score: 0.2193 - val_loss: -0.2214 - lr: 0.0125
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9281 - dice_coef: 0.4044 - f1_score: 0.4044 - loss: -0.4054
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9281 - dice_coef: 0.4044 - f1_score: 0.4044 - loss: -0.4054 - val_accuracy: 0.9224 - val_dice_coef: 0.2234 - val_f1_score: 0.2233 - val_loss: -0.2234 - lr: 0.0125
# Epoch 27/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9285 - dice_coef: 0.4151 - f1_score: 0.4151 - loss: -0.4161 - val_accuracy: 0.9239 - val_dice_coef: 0.2250 - val_f1_score: 0.2248 - val_loss: -0.2250 - lr: 0.0063
# Epoch 28/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9286 - dice_coef: 0.4136 - f1_score: 0.4136 - loss: -0.4156 - val_accuracy: 0.9237 - val_dice_coef: 0.2215 - val_f1_score: 0.2215 - val_loss: -0.2215 - lr: 0.0063
# Epoch 29/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9287 - dice_coef: 0.4126 - f1_score: 0.4126 - loss: -0.4135 - val_accuracy: 0.9248 - val_dice_coef: 0.2194 - val_f1_score: 0.2194 - val_loss: -0.2194 - lr: 0.0063
# Epoch 30/50
# 88/88 [==============================] - 11s 128ms/step - accuracy: 0.9287 - dice_coef: 0.4165 - f1_score: 0.4165 - loss: -0.4172 - val_accuracy: 0.9245 - val_dice_coef: 0.2232 - val_f1_score: 0.2231 - val_loss: -0.2232 - lr: 0.0063
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9287 - dice_coef: 0.4192 - f1_score: 0.4193 - loss: -0.4196
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 88/88 [==============================] - 11s 128ms/step - accuracy: 0.9287 - dice_coef: 0.4192 - f1_score: 0.4193 - loss: -0.4196 - val_accuracy: 0.9248 - val_dice_coef: 0.2220 - val_f1_score: 0.2210 - val_loss: -0.2220 - lr: 0.0063
#
# Completed UNet Training. (Step 01)
# Wed at 11:09:24PM
# confusion_unet [[9801632   96345]
#  [  68297   68926]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99   9897977
#          1.0       0.42      0.50      0.46    137223
#
#     accuracy                           0.98  10035200
#    macro avg       0.71      0.75      0.72  10035200
# weighted avg       0.99      0.98      0.98  10035200
#
#
# Completed Unet Evaluation. (Step 01)
#
# Training Results (Step 01):
# - Dice Coef: 43.966%
# - F1 Score: 43.966%
#
# Validation Results (Step 01):
# - Dice Coef: 38.752%
# - F1 Score: 38.753%
#
# Testing Results (Step 01):
# - Dice Coef: 45.570%
# - F1 Score: 45.572%
# Wed at 11:10:29PM
#
# EM_Step 01 (04) Complete.
# - Precision: 41.87%
# - SourceDelta: 14.48%
# - StepDelta: 19.42%
# Wed at 11:10:29PM
# ----------------------------------

# %%
# Prepare EM iterator index.
EM_iterator = 2
EM_target = 4
print()
print("Target Steps:", EM_target)
print(rebuild_model)
learningRate = 0.1
import random

# -----------------------------------------------------------------------------
# Begin Iteration -------------------------------------------------------------
while EM_iterator < EM_target:   
    
    # ---------------------------
    # 0. Initialization
    # ---------------------------
    section_tstamp = time.time()
    section_name = 'EM_Step {:02}'.format(EM_iterator)

    # Create folder for em step
    emfolder = os.path.join(test.dir, 'Step_{:02}'.format(EM_iterator))
    if not os.path.exists(emfolder): os.mkdir(emfolder)

    print("\n\nEM Step {:02} begun.".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    anno_stamp = time.time()
    
    
    # ---------------------------
    # 1. Creating New Annotations
    # ---------------------------

    # 1.1 Get probability output map from last model (Skip first step since it was pre-generated)
    pmap_fp = os.path.join(emfolder, 'pmap_{:02}.tif'.format(EM_iterator))
    p_output = emt.Get_Pmap(train_raster, WinShape, unet_model, pmap_fp)
    
    print("\nGenerated Probability Output Map from previous model. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    
    # 1.2 Weight Candidate Frames
    newSegments = []
    for frame in candidateFrames:
        
        # Get Candidate Weights
        weightedFrame = emt.WeightCandidates(p_output, frame)
        
        # Select Likely or Top Candidate 
        if random.uniform(0,1) < random_candidate_chance:
            # Use 'likely' candidate (ENSURE Select_Candidate() FUNCTION IS UPDATED (lib/EMTools.py))
            newSegments.append(emt.Select_Candidate(weightedFrame, 'weight', weight_limit))
        else:
            # Use top candidate
            newSegments.append(emt.Top_Candidate(weightedFrame, 'weight'))
        
        
    # 1.3 Convert List of segments to GeoDataFrame
    newSegmentFrame = gpd.GeoDataFrame(geometry=newSegments, crs=candidateFrames[0].crs)
    newSegmentFrame.to_file(os.path.join(emfolder, 'segments_{:02}.shp'.format(EM_iterator)))

    # 1.4 Connect top segments:
    newAnnotation = emt.Connect_Lines(newSegmentFrame, maxRepairDist)
    newAnnotation.to_file(os.path.join(emfolder, 'annotation_{:02}.shp'.format(EM_iterator)))

    # 1.5 Save mean precision of this annotation.
    annoPrecision = emt.GDF_Precision(gt_labels, newAnnotation, precisionBuffer)


    
    print("\nCreated New Annotation. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    anno_time = time.time() - anno_stamp
    
    # ---------------------------
    # 2. Create new Label Tensors
    # ---------------------------
    
    # 2.1 Rasterize New Labels
    buff_anno = st.GDF_Buffer(newAnnotation, labelBuffer, flatten=True)
    anno_raster = st.GDF_Rasterize(buff_anno, train_raster)
    
    # 2.2 Read Y_train, Y_val
    Y_train = gt.ResampleTiles(anno_raster, train_offsets_fp)
    Y_val = gt.ResampleTiles(anno_raster, val_offsets_fp)
    
    # 2.2 Augment Y_train, Y_val
    Y_train = gt.AugmentImages(Y_train, h_flip=train_h_flip, v_flip=train_v_flip, rotate=train_rotate)
    Y_val = gt.AugmentImages(Y_val, h_flip=val_h_flip, v_flip=val_v_flip, rotate=val_rotate)
    
    print("\nCreated Y_train {} and Y_val {}. (Step {:02})".format(Y_train.shape, Y_val.shape, EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    
    
    # ---------------------------
    # 3. Re-Train U-Net 
    # ---------------------------
    
    # 3.1 Load Callbacks 
    callbacks = SetCallbacks(emfolder + '/model_{:02}.h5'.format(EM_iterator))
    
    # 3.2 Determine Learning Rate from schedule
    EM_learningRate = Step_LR_Schedule(learningRate, EM_iterator, EM_target, lr_const)
    print("\nNew Learning Rate: {:.6f}. (Step {:02})".format(EM_learningRate, EM_iterator))
        
    training_stamp = time.time()
    with mirror_strategy.scope():
        unet_model = UNET_7_224()
        unet_model.compile(optimizer=Adam(lr=EM_learningRate), loss=dice_coef_loss, metrics=metrics)
        TrainData = unet_model.fit(X_train, Y_train, validation_data=(X_val, Y_val), shuffle=useShuffle, batch_size=batchSize, epochs=epochs, callbacks=callbacks)
    training_time = time.time() - training_stamp
    
    training_metrics = {
        'f1': Get_Metric_Data(TrainData, 'f1_score'),
        'dice_coef': Get_Metric_Data(TrainData, 'dice_coef'),
        'loss': Get_Metric_Data(TrainData, 'loss')
    }

    train_metrics_fp = os.path.join(emfolder, 'train_curve_{:02}.csv'.format(EM_iterator))
    with open(train_metrics_fp, 'a+', newline='\n') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter= ',')
        for key, data in training_metrics.items():
            csvwriter.writerow(['Training {}'.format(key)])
            csvwriter.writerow(data)


    validation_metrics = {
        'f1': Get_Metric_Data(TrainData, 'val_f1_score'),
        'dice_coef': Get_Metric_Data(TrainData, 'val_dice_coef'),
        'loss': Get_Metric_Data(TrainData, 'val_loss')
    }   
    val_metrics_fp = os.path.join(emfolder, 'val_curve_{:02}.csv'.format(EM_iterator))
    with open(val_metrics_fp, 'a+', newline='\n') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter= ',')
        for key, data in training_metrics.items():
            csvwriter.writerow(['Validation {}'.format(key)])
            csvwriter.writerow(data)
            
    SaveHistory(TrainData, os.path.join(emfolder, 'trainingResults_{:02}'.format(EM_iterator)), test.end) # Save Plots
    
    print("\nCompleted UNet Training. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    


    # ---------------------------
    # 4. Evaluate Model
    # ---------------------------

    
    # Training Results
    train_results = emt.Evaluate(X_train, Y_train, unet_model)
    # Validation Results
    val_results = emt.Evaluate(X_val, Y_val, unet_model)
    # Testing Results
    test_results = emt.Evaluate(X_test, Y_test, unet_model)

    y_pred=np.copy(unet_model.predict(X_test))
    y_pred = np.round(y_pred)
    y_true=np.copy(Y_test)
    y_pred.shape = y_pred.shape[0]* y_pred.shape[1]*y_pred.shape[2]* y_pred.shape[3]
    y_true.shape = y_true.shape[0]* y_true.shape[1]*y_true.shape[2]* y_true.shape[3]

    c_matrix = confusion_matrix(y_true, y_pred, labels=[0, 1])
    print("confusion_unet", c_matrix)
    report_unet = classification_report(y_true, y_pred)
    print("report_unet", report_unet)
    
    # print
    print("\nCompleted Unet Evaluation. (Step {:02})".format(EM_iterator))
    print("\nTraining Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(train_results[0]))
    print("- {}".format(train_results[1]))
    print("\nValidation Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(val_results[0]))
    print("- {}".format(val_results[1]))   
    print("\nTesting Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(test_results[0]))
    print("- {}".format(test_results[1]))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    
    
    # ---------------------------
    # 5. Save Step Data
    # ---------------------------
    
    # Save to dict for seperate CSV
    dataMatrix['precision'].append(annoPrecision*100)
    dataMatrix['trainDice'].append(train_results[0]) 
    dataMatrix['trainF1Score'].append(train_results[1]) 
    dataMatrix['valDice'].append(val_results[0]) 
    dataMatrix['valF1Score'].append(val_results[1]) 
    dataMatrix['testDice'].append(test_results[0]) 
    dataMatrix['testF1Score'].append(test_results[1]) 
    

    # Save EM Step Data 
    test.Results("EM Data {:02}".format(EM_iterator), {
        
        'Time Elapsed: Re-training': training_time,
        'Time Elapsed: New Annotation': anno_time,
            
        'Precision': '{:.2f}%'.format(annoPrecision*100),
        'SourceDelta': '{:.2f}%'.format((annoPrecision-sourcePrecision)*100),
        'StepDelta': '{:.2f}%'.format((annoPrecision-prevPrecision)*100),
        
        'UNet: LR': str(EM_learningRate),
        'UNet: Epochs': str(len(TrainData.history['dice_coef'])),
        
        'UNet: Training Results': train_results,
        'UNet: Validation Results': val_results,
        'UNet: Testing Results': test_results,
        'UNet: Confusion Matrix': c_matrix,
        'UNet: Report': report_unet
    })
    # Save as section
    section_data = {'time': time.time()-section_tstamp, 'stamp': section_tstamp}
    test.Section(section_name, section_data)
    
    # Print step data
    print("\n{} ({:02}) Complete.".format(section_name, len(test.sectionNames)))
    print('- Precision: {:.2f}%'.format(annoPrecision*100))
    print('- SourceDelta: {:.2f}%'.format((annoPrecision-sourcePrecision)*100))
    print('- StepDelta: {:.2f}%'.format((annoPrecision-prevPrecision)*100))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    print("----------------------------------\n\n")
    
    # Increase iterator and save previous precision for step_delta
    EM_iterator += 1
    prevPrecision = annoPrecision
# Out:
# Target Steps: 4
# True
#
#
# EM Step 02 begun.
# Wed at 11:15:35PM
#
# Generated Probability Output Map from previous model. (Step 02)
# Wed at 11:15:59PM
#
# Created New Annotation. (Step 02)
# Wed at 11:16:42PM
#
# Created Y_train (2792, 224, 224, 1) and Y_val (160, 224, 224, 1). (Step 02)
# Wed at 11:16:52PM
#
# New Learning Rate: 0.100000. (Step 02)
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# 88/88 [==============================] - 14s 160ms/step - accuracy: 0.9108 - dice_coef: 0.2697 - f1_score: 0.2718 - loss: -0.2688 - val_accuracy: 0.0174 - val_dice_coef: 0.0336 - val_f1_score: 0.0336 - val_loss: -0.0336 - lr: 0.1000
# Epoch 2/50
# 88/88 [==============================] - 12s 132ms/step - accuracy: 0.9305 - dice_coef: 0.3686 - f1_score: 0.3687 - loss: -0.3684 - val_accuracy: 0.0957 - val_dice_coef: 0.0339 - val_f1_score: 0.0339 - val_loss: -0.0339 - lr: 0.1000
# Epoch 3/50
# 88/88 [==============================] - 12s 133ms/step - accuracy: 0.9311 - dice_coef: 0.3931 - f1_score: 0.3932 - loss: -0.3947 - val_accuracy: 0.7770 - val_dice_coef: 0.0605 - val_f1_score: 0.0606 - val_loss: -0.0605 - lr: 0.1000
# Epoch 4/50
# 88/88 [==============================] - 12s 133ms/step - accuracy: 0.9323 - dice_coef: 0.4164 - f1_score: 0.4164 - loss: -0.4173 - val_accuracy: 0.9075 - val_dice_coef: 0.1544 - val_f1_score: 0.1546 - val_loss: -0.1544 - lr: 0.1000
# Epoch 5/50
# 88/88 [==============================] - 12s 133ms/step - accuracy: 0.9326 - dice_coef: 0.4267 - f1_score: 0.4268 - loss: -0.4288 - val_accuracy: 0.9303 - val_dice_coef: 0.1632 - val_f1_score: 0.1138 - val_loss: -0.1632 - lr: 0.1000
# Epoch 6/50
# 88/88 [==============================] - 11s 129ms/step - accuracy: 0.9333 - dice_coef: 0.4398 - f1_score: 0.4399 - loss: -0.4403 - val_accuracy: 0.9301 - val_dice_coef: 0.0792 - val_f1_score: 0.0792 - val_loss: -0.0792 - lr: 0.1000
# Epoch 7/50
# 88/88 [==============================] - 12s 135ms/step - accuracy: 0.9334 - dice_coef: 0.4484 - f1_score: 0.4485 - loss: -0.4488 - val_accuracy: 0.9300 - val_dice_coef: 0.2301 - val_f1_score: 0.2301 - val_loss: -0.2301 - lr: 0.1000
# Epoch 8/50
# 88/88 [==============================] - 12s 134ms/step - accuracy: 0.9339 - dice_coef: 0.4542 - f1_score: 0.4542 - loss: -0.4581 - val_accuracy: 0.9233 - val_dice_coef: 0.2440 - val_f1_score: 0.2447 - val_loss: -0.2440 - lr: 0.1000
# Epoch 9/50
# 88/88 [==============================] - 12s 136ms/step - accuracy: 0.9341 - dice_coef: 0.4671 - f1_score: 0.4671 - loss: -0.4711 - val_accuracy: 0.9302 - val_dice_coef: 0.4021 - val_f1_score: 0.2110 - val_loss: -0.4021 - lr: 0.1000
# Epoch 10/50
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9347 - dice_coef: 0.4840 - f1_score: 0.4840 - loss: -0.4855 - val_accuracy: 0.9314 - val_dice_coef: 0.2767 - val_f1_score: 0.2767 - val_loss: -0.2767 - lr: 0.1000
# Epoch 11/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9344 - dice_coef: 0.4751 - f1_score: 0.4752 - loss: -0.4753 - val_accuracy: 0.9306 - val_dice_coef: 0.3305 - val_f1_score: 0.1304 - val_loss: -0.3305 - lr: 0.1000
# Epoch 12/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9348 - dice_coef: 0.4889 - f1_score: 0.4889 - loss: -0.4882 - val_accuracy: 0.9238 - val_dice_coef: 0.2621 - val_f1_score: 0.2621 - val_loss: -0.2621 - lr: 0.1000
# Epoch 13/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9352 - dice_coef: 0.4960 - f1_score: 0.4960 - loss: -0.4977 - val_accuracy: 0.9294 - val_dice_coef: 0.2914 - val_f1_score: 0.2914 - val_loss: -0.2914 - lr: 0.1000
# Epoch 14/50
# 88/88 [==============================] - 12s 132ms/step - accuracy: 0.9354 - dice_coef: 0.4957 - f1_score: 0.4957 - loss: -0.4963 - val_accuracy: 0.9320 - val_dice_coef: 0.5211 - val_f1_score: 0.2712 - val_loss: -0.5211 - lr: 0.1000
# Epoch 15/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9358 - dice_coef: 0.5121 - f1_score: 0.5121 - loss: -0.5108 - val_accuracy: 0.9275 - val_dice_coef: 0.2928 - val_f1_score: 0.2928 - val_loss: -0.2928 - lr: 0.1000
# Epoch 16/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9355 - dice_coef: 0.5099 - f1_score: 0.5098 - loss: -0.5122 - val_accuracy: 0.9310 - val_dice_coef: 0.2796 - val_f1_score: 0.2796 - val_loss: -0.2796 - lr: 0.1000
# Epoch 17/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9357 - dice_coef: 0.5088 - f1_score: 0.5088 - loss: -0.5105 - val_accuracy: 0.9302 - val_dice_coef: 0.2890 - val_f1_score: 0.2890 - val_loss: -0.2890 - lr: 0.1000
# Epoch 18/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9361 - dice_coef: 0.5173 - f1_score: 0.5174 - loss: -0.5177 - val_accuracy: 0.9317 - val_dice_coef: 0.2881 - val_f1_score: 0.2881 - val_loss: -0.2881 - lr: 0.1000
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9360 - dice_coef: 0.5173 - f1_score: 0.5173 - loss: -0.5191
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 88/88 [==============================] - 11s 128ms/step - accuracy: 0.9360 - dice_coef: 0.5173 - f1_score: 0.5173 - loss: -0.5191 - val_accuracy: 0.9269 - val_dice_coef: 0.2920 - val_f1_score: 0.2920 - val_loss: -0.2920 - lr: 0.1000
# Epoch 20/50
# 88/88 [==============================] - 11s 128ms/step - accuracy: 0.9365 - dice_coef: 0.5320 - f1_score: 0.5320 - loss: -0.5337 - val_accuracy: 0.9319 - val_dice_coef: 0.2945 - val_f1_score: 0.2945 - val_loss: -0.2945 - lr: 0.0500
# Epoch 21/50
# 88/88 [==============================] - 12s 138ms/step - accuracy: 0.9370 - dice_coef: 0.5465 - f1_score: 0.5465 - loss: -0.5488 - val_accuracy: 0.9326 - val_dice_coef: 0.5253 - val_f1_score: 0.2753 - val_loss: -0.5253 - lr: 0.0500
# Epoch 22/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9365 - dice_coef: 0.5369 - f1_score: 0.5369 - loss: -0.5377 - val_accuracy: 0.9318 - val_dice_coef: 0.2971 - val_f1_score: 0.2972 - val_loss: -0.2971 - lr: 0.0500
# Epoch 23/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9369 - dice_coef: 0.5418 - f1_score: 0.5419 - loss: -0.5444 - val_accuracy: 0.9318 - val_dice_coef: 0.2839 - val_f1_score: 0.2839 - val_loss: -0.2839 - lr: 0.0500
# Epoch 24/50
# 88/88 [==============================] - 12s 135ms/step - accuracy: 0.9368 - dice_coef: 0.5419 - f1_score: 0.5419 - loss: -0.5430 - val_accuracy: 0.9323 - val_dice_coef: 0.5263 - val_f1_score: 0.2763 - val_loss: -0.5263 - lr: 0.0500
# Epoch 25/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9370 - dice_coef: 0.5456 - f1_score: 0.5456 - loss: -0.5472 - val_accuracy: 0.9327 - val_dice_coef: 0.4996 - val_f1_score: 0.2996 - val_loss: -0.4996 - lr: 0.0500
# Epoch 26/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9368 - dice_coef: 0.5474 - f1_score: 0.5474 - loss: -0.5483 - val_accuracy: 0.9323 - val_dice_coef: 0.4819 - val_f1_score: 0.2820 - val_loss: -0.4819 - lr: 0.0500
# Epoch 27/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9372 - dice_coef: 0.5480 - f1_score: 0.5480 - loss: -0.5505 - val_accuracy: 0.9325 - val_dice_coef: 0.4986 - val_f1_score: 0.2986 - val_loss: -0.4986 - lr: 0.0500
# Epoch 28/50
# 88/88 [==============================] - 11s 128ms/step - accuracy: 0.9371 - dice_coef: 0.5489 - f1_score: 0.5489 - loss: -0.5509 - val_accuracy: 0.9323 - val_dice_coef: 0.4492 - val_f1_score: 0.2992 - val_loss: -0.4492 - lr: 0.0500
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9370 - dice_coef: 0.5480 - f1_score: 0.5480 - loss: -0.5493
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9370 - dice_coef: 0.5480 - f1_score: 0.5480 - loss: -0.5493 - val_accuracy: 0.9314 - val_dice_coef: 0.2980 - val_f1_score: 0.2980 - val_loss: -0.2980 - lr: 0.0500
# Epoch 30/50
# 88/88 [==============================] - 12s 135ms/step - accuracy: 0.9371 - dice_coef: 0.5513 - f1_score: 0.5513 - loss: -0.5515 - val_accuracy: 0.9324 - val_dice_coef: 0.5599 - val_f1_score: 0.2778 - val_loss: -0.5599 - lr: 0.0250
# Epoch 31/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9373 - dice_coef: 0.5615 - f1_score: 0.5615 - loss: -0.5633 - val_accuracy: 0.9326 - val_dice_coef: 0.5031 - val_f1_score: 0.3031 - val_loss: -0.5031 - lr: 0.0250
# Epoch 32/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9373 - dice_coef: 0.5563 - f1_score: 0.5563 - loss: -0.5594 - val_accuracy: 0.9323 - val_dice_coef: 0.5054 - val_f1_score: 0.3054 - val_loss: -0.5054 - lr: 0.0250
# Epoch 33/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9375 - dice_coef: 0.5586 - f1_score: 0.5586 - loss: -0.5602 - val_accuracy: 0.9326 - val_dice_coef: 0.5025 - val_f1_score: 0.3025 - val_loss: -0.5025 - lr: 0.0250
# Epoch 34/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9372 - dice_coef: 0.5508 - f1_score: 0.5508 - loss: -0.5526 - val_accuracy: 0.9327 - val_dice_coef: 0.5034 - val_f1_score: 0.3034 - val_loss: -0.5034 - lr: 0.0250
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9375 - dice_coef: 0.5640 - f1_score: 0.5640 - loss: -0.5648
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9375 - dice_coef: 0.5640 - f1_score: 0.5640 - loss: -0.5648 - val_accuracy: 0.9329 - val_dice_coef: 0.4938 - val_f1_score: 0.2938 - val_loss: -0.4938 - lr: 0.0250
# Epoch 36/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9374 - dice_coef: 0.5601 - f1_score: 0.5601 - loss: -0.5603 - val_accuracy: 0.9326 - val_dice_coef: 0.5063 - val_f1_score: 0.3063 - val_loss: -0.5063 - lr: 0.0125
# Epoch 37/50
# 88/88 [==============================] - 12s 131ms/step - accuracy: 0.9375 - dice_coef: 0.5579 - f1_score: 0.5579 - loss: -0.5594 - val_accuracy: 0.9319 - val_dice_coef: 0.3628 - val_f1_score: 0.3128 - val_loss: -0.3628 - lr: 0.0125
# Epoch 38/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9375 - dice_coef: 0.5648 - f1_score: 0.5648 - loss: -0.5658 - val_accuracy: 0.9326 - val_dice_coef: 0.4986 - val_f1_score: 0.2986 - val_loss: -0.4986 - lr: 0.0125
# Epoch 39/50
# 88/88 [==============================] - 11s 128ms/step - accuracy: 0.9377 - dice_coef: 0.5671 - f1_score: 0.5671 - loss: -0.5689 - val_accuracy: 0.9325 - val_dice_coef: 0.5032 - val_f1_score: 0.3032 - val_loss: -0.5032 - lr: 0.0125
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9375 - dice_coef: 0.5620 - f1_score: 0.5621 - loss: -0.5617
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 88/88 [==============================] - 11s 129ms/step - accuracy: 0.9375 - dice_coef: 0.5620 - f1_score: 0.5621 - loss: -0.5617 - val_accuracy: 0.9328 - val_dice_coef: 0.5003 - val_f1_score: 0.3003 - val_loss: -0.5003 - lr: 0.0125
# Epoch 41/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9378 - dice_coef: 0.5691 - f1_score: 0.5691 - loss: -0.5702 - val_accuracy: 0.9327 - val_dice_coef: 0.5040 - val_f1_score: 0.3040 - val_loss: -0.5040 - lr: 0.0063
# Epoch 42/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9378 - dice_coef: 0.5671 - f1_score: 0.5671 - loss: -0.5709 - val_accuracy: 0.9327 - val_dice_coef: 0.5016 - val_f1_score: 0.3015 - val_loss: -0.5016 - lr: 0.0063
# Epoch 43/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9378 - dice_coef: 0.5700 - f1_score: 0.5700 - loss: -0.5723 - val_accuracy: 0.9326 - val_dice_coef: 0.5048 - val_f1_score: 0.3048 - val_loss: -0.5048 - lr: 0.0063
# Epoch 44/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9379 - dice_coef: 0.5716 - f1_score: 0.5716 - loss: -0.5707 - val_accuracy: 0.9324 - val_dice_coef: 0.5020 - val_f1_score: 0.3019 - val_loss: -0.5020 - lr: 0.0063
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9379 - dice_coef: 0.5722 - f1_score: 0.5722 - loss: -0.5742
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 88/88 [==============================] - 11s 129ms/step - accuracy: 0.9379 - dice_coef: 0.5722 - f1_score: 0.5722 - loss: -0.5742 - val_accuracy: 0.9327 - val_dice_coef: 0.5053 - val_f1_score: 0.3052 - val_loss: -0.5053 - lr: 0.0063
# Epoch 46/50
# 88/88 [==============================] - 11s 128ms/step - accuracy: 0.9379 - dice_coef: 0.5775 - f1_score: 0.5775 - loss: -0.5767 - val_accuracy: 0.9327 - val_dice_coef: 0.5038 - val_f1_score: 0.3038 - val_loss: -0.5038 - lr: 0.0031
# Epoch 47/50
# 88/88 [==============================] - 11s 131ms/step - accuracy: 0.9379 - dice_coef: 0.5718 - f1_score: 0.5718 - loss: -0.5724 - val_accuracy: 0.9328 - val_dice_coef: 0.5035 - val_f1_score: 0.3035 - val_loss: -0.5035 - lr: 0.0031
# Epoch 48/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9378 - dice_coef: 0.5683 - f1_score: 0.5683 - loss: -0.5705 - val_accuracy: 0.9328 - val_dice_coef: 0.5040 - val_f1_score: 0.3041 - val_loss: -0.5040 - lr: 0.0031
# Epoch 49/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9379 - dice_coef: 0.5783 - f1_score: 0.5783 - loss: -0.5774 - val_accuracy: 0.9326 - val_dice_coef: 0.5048 - val_f1_score: 0.3048 - val_loss: -0.5048 - lr: 0.0031
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9380 - dice_coef: 0.5791 - f1_score: 0.5791 - loss: -0.5789
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.0015625000232830644.
# 88/88 [==============================] - 11s 130ms/step - accuracy: 0.9380 - dice_coef: 0.5791 - f1_score: 0.5791 - loss: -0.5789 - val_accuracy: 0.9327 - val_dice_coef: 0.5020 - val_f1_score: 0.3020 - val_loss: -0.5020 - lr: 0.0031
#
# Completed UNet Training. (Step 02)
# Wed at 11:26:51PM
# confusion_unet [[9838755   59222]
#  [  56571   80652]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99   9897977
#          1.0       0.58      0.59      0.58    137223
#
#     accuracy                           0.99  10035200
#    macro avg       0.79      0.79      0.79  10035200
# weighted avg       0.99      0.99      0.99  10035200
#
#
# Completed Unet Evaluation. (Step 02)
#
# Training Results (Step 02):
# - Dice Coef: 60.272%
# - F1 Score: 60.274%
#
# Validation Results (Step 02):
# - Dice Coef: 51.515%
# - F1 Score: 51.516%
#
# Testing Results (Step 02):
# - Dice Coef: 58.210%
# - F1 Score: 58.212%
# Wed at 11:27:55PM
#
# EM_Step 02 (05) Complete.
# - Precision: 46.53%
# - SourceDelta: 19.14%
# - StepDelta: 4.65%
# Wed at 11:27:55PM
# ----------------------------------
#
#
#
#
# EM Step 03 begun.
# Wed at 11:27:55PM
#
# Generated Probability Output Map from previous model. (Step 03)
# Wed at 11:28:20PM
#
# Created New Annotation. (Step 03)
# Wed at 11:29:01PM
#
# Created Y_train (2792, 224, 224, 1) and Y_val (160, 224, 224, 1). (Step 03)
# Wed at 11:29:10PM
#
# New Learning Rate: 0.050000. (Step 03)
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# 88/88 [==============================] - 14s 161ms/step - accuracy: 0.9157 - dice_coef: 0.2809 - f1_score: 0.2831 - loss: -0.2818 - val_accuracy: 0.9283 - val_dice_coef: 0.3744 - val_f1_score: 0.0000e+00 - val_loss: -0.3744 - lr: 0.0500
# Epoch 2/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9338 - dice_coef: 0.3964 - f1_score: 0.3965 - loss: -0.3977 - val_accuracy: 0.9189 - val_dice_coef: 0.0576 - val_f1_score: 0.0576 - val_loss: -0.0576 - lr: 0.0500
# Epoch 3/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9350 - dice_coef: 0.4298 - f1_score: 0.4299 - loss: -0.4289 - val_accuracy: 0.9270 - val_dice_coef: 0.0225 - val_f1_score: 0.0225 - val_loss: -0.0225 - lr: 0.0500
# Epoch 4/50
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9357 - dice_coef: 0.4442 - f1_score: 0.4443 - loss: -0.4444 - val_accuracy: 0.9295 - val_dice_coef: 0.1444 - val_f1_score: 0.1443 - val_loss: -0.1444 - lr: 0.0500
# Epoch 5/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9371 - dice_coef: 0.4798 - f1_score: 0.4799 - loss: -0.4807 - val_accuracy: 0.9299 - val_dice_coef: 0.2038 - val_f1_score: 0.2039 - val_loss: -0.2038 - lr: 0.0500
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9379 - dice_coef: 0.4997 - f1_score: 0.4998 - loss: -0.5000
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9379 - dice_coef: 0.4997 - f1_score: 0.4998 - loss: -0.5000 - val_accuracy: 0.9299 - val_dice_coef: 0.2329 - val_f1_score: 0.2329 - val_loss: -0.2329 - lr: 0.0500
# Epoch 7/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9387 - dice_coef: 0.5277 - f1_score: 0.5279 - loss: -0.5287 - val_accuracy: 0.9298 - val_dice_coef: 0.2912 - val_f1_score: 0.2913 - val_loss: -0.2912 - lr: 0.0250
# Epoch 8/50
# 88/88 [==============================] - 11s 128ms/step - accuracy: 0.9392 - dice_coef: 0.5351 - f1_score: 0.5352 - loss: -0.5339 - val_accuracy: 0.9307 - val_dice_coef: 0.2997 - val_f1_score: 0.2975 - val_loss: -0.2997 - lr: 0.0250
# Epoch 9/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9393 - dice_coef: 0.5480 - f1_score: 0.5481 - loss: -0.5490 - val_accuracy: 0.9293 - val_dice_coef: 0.2960 - val_f1_score: 0.2961 - val_loss: -0.2960 - lr: 0.0250
# Epoch 10/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9399 - dice_coef: 0.5616 - f1_score: 0.5617 - loss: -0.5630 - val_accuracy: 0.9307 - val_dice_coef: 0.2894 - val_f1_score: 0.2895 - val_loss: -0.2894 - lr: 0.0250
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9400 - dice_coef: 0.5637 - f1_score: 0.5638 - loss: -0.5641
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9400 - dice_coef: 0.5637 - f1_score: 0.5638 - loss: -0.5641 - val_accuracy: 0.9311 - val_dice_coef: 0.3482 - val_f1_score: 0.2984 - val_loss: -0.3482 - lr: 0.0250
# Epoch 12/50
# 88/88 [==============================] - 12s 135ms/step - accuracy: 0.9402 - dice_coef: 0.5731 - f1_score: 0.5731 - loss: -0.5742 - val_accuracy: 0.9318 - val_dice_coef: 0.4514 - val_f1_score: 0.3082 - val_loss: -0.4514 - lr: 0.0125
# Epoch 13/50
# 88/88 [==============================] - 12s 135ms/step - accuracy: 0.9404 - dice_coef: 0.5781 - f1_score: 0.5781 - loss: -0.5789 - val_accuracy: 0.9321 - val_dice_coef: 0.5400 - val_f1_score: 0.2906 - val_loss: -0.5400 - lr: 0.0125
# Epoch 14/50
# 88/88 [==============================] - 12s 134ms/step - accuracy: 0.9405 - dice_coef: 0.5799 - f1_score: 0.5800 - loss: -0.5816 - val_accuracy: 0.9324 - val_dice_coef: 0.5647 - val_f1_score: 0.3118 - val_loss: -0.5647 - lr: 0.0125
# Epoch 15/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9406 - dice_coef: 0.5808 - f1_score: 0.5809 - loss: -0.5833 - val_accuracy: 0.9319 - val_dice_coef: 0.4601 - val_f1_score: 0.3104 - val_loss: -0.4601 - lr: 0.0125
# Epoch 16/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9405 - dice_coef: 0.5835 - f1_score: 0.5835 - loss: -0.5826 - val_accuracy: 0.9318 - val_dice_coef: 0.3101 - val_f1_score: 0.3102 - val_loss: -0.3101 - lr: 0.0125
# Epoch 17/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9408 - dice_coef: 0.5921 - f1_score: 0.5922 - loss: -0.5940 - val_accuracy: 0.9315 - val_dice_coef: 0.4051 - val_f1_score: 0.3051 - val_loss: -0.4051 - lr: 0.0125
# Epoch 18/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9408 - dice_coef: 0.5895 - f1_score: 0.5896 - loss: -0.5918 - val_accuracy: 0.9316 - val_dice_coef: 0.3079 - val_f1_score: 0.3078 - val_loss: -0.3079 - lr: 0.0125
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9404 - dice_coef: 0.5792 - f1_score: 0.5793 - loss: -0.5796
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9404 - dice_coef: 0.5792 - f1_score: 0.5793 - loss: -0.5796 - val_accuracy: 0.9315 - val_dice_coef: 0.3139 - val_f1_score: 0.3139 - val_loss: -0.3139 - lr: 0.0125
# Epoch 20/50
# 88/88 [==============================] - 12s 132ms/step - accuracy: 0.9409 - dice_coef: 0.5927 - f1_score: 0.5928 - loss: -0.5962 - val_accuracy: 0.9324 - val_dice_coef: 0.6599 - val_f1_score: 0.3099 - val_loss: -0.6599 - lr: 0.0063
# Epoch 21/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9410 - dice_coef: 0.5988 - f1_score: 0.5989 - loss: -0.6007 - val_accuracy: 0.9323 - val_dice_coef: 0.3593 - val_f1_score: 0.3100 - val_loss: -0.3593 - lr: 0.0063
# Epoch 22/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9411 - dice_coef: 0.6002 - f1_score: 0.6002 - loss: -0.6021 - val_accuracy: 0.9322 - val_dice_coef: 0.3944 - val_f1_score: 0.2992 - val_loss: -0.3944 - lr: 0.0063
# Epoch 23/50
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9411 - dice_coef: 0.5979 - f1_score: 0.5980 - loss: -0.6002 - val_accuracy: 0.9321 - val_dice_coef: 0.4600 - val_f1_score: 0.3114 - val_loss: -0.4600 - lr: 0.0063
# Epoch 24/50
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9408 - dice_coef: 0.6050 - f1_score: 0.6050 - loss: -0.6066 - val_accuracy: 0.9322 - val_dice_coef: 0.4970 - val_f1_score: 0.2972 - val_loss: -0.4970 - lr: 0.0063
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9412 - dice_coef: 0.6023 - f1_score: 0.6024 - loss: -0.6060
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9412 - dice_coef: 0.6023 - f1_score: 0.6024 - loss: -0.6060 - val_accuracy: 0.9314 - val_dice_coef: 0.3150 - val_f1_score: 0.3150 - val_loss: -0.3150 - lr: 0.0063
# Epoch 26/50
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9412 - dice_coef: 0.6070 - f1_score: 0.6070 - loss: -0.6091 - val_accuracy: 0.9321 - val_dice_coef: 0.5094 - val_f1_score: 0.3144 - val_loss: -0.5094 - lr: 0.0031
# Epoch 27/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9412 - dice_coef: 0.5981 - f1_score: 0.5981 - loss: -0.6019 - val_accuracy: 0.9322 - val_dice_coef: 0.4027 - val_f1_score: 0.3137 - val_loss: -0.4027 - lr: 0.0031
# Epoch 28/50
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9413 - dice_coef: 0.6091 - f1_score: 0.6091 - loss: -0.6108 - val_accuracy: 0.9324 - val_dice_coef: 0.6285 - val_f1_score: 0.3139 - val_loss: -0.6285 - lr: 0.0031
# Epoch 29/50
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9413 - dice_coef: 0.6077 - f1_score: 0.6078 - loss: -0.6099 - val_accuracy: 0.9324 - val_dice_coef: 0.4135 - val_f1_score: 0.3132 - val_loss: -0.4135 - lr: 0.0031
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9415 - dice_coef: 0.6195 - f1_score: 0.6196 - loss: -0.6184
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0015625000232830644.
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9415 - dice_coef: 0.6195 - f1_score: 0.6196 - loss: -0.6184 - val_accuracy: 0.9321 - val_dice_coef: 0.4625 - val_f1_score: 0.3125 - val_loss: -0.4625 - lr: 0.0031
# Epoch 31/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9416 - dice_coef: 0.6177 - f1_score: 0.6177 - loss: -0.6199 - val_accuracy: 0.9322 - val_dice_coef: 0.4674 - val_f1_score: 0.3174 - val_loss: -0.4674 - lr: 0.0016
# Epoch 32/50
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9416 - dice_coef: 0.6141 - f1_score: 0.6141 - loss: -0.6172 - val_accuracy: 0.9323 - val_dice_coef: 0.4164 - val_f1_score: 0.3165 - val_loss: -0.4164 - lr: 0.0016
# Epoch 33/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9414 - dice_coef: 0.6121 - f1_score: 0.6122 - loss: -0.6138 - val_accuracy: 0.9324 - val_dice_coef: 0.5621 - val_f1_score: 0.3166 - val_loss: -0.5621 - lr: 0.0016
# Epoch 34/50
# 88/88 [==============================] - 11s 123ms/step - accuracy: 0.9416 - dice_coef: 0.6183 - f1_score: 0.6183 - loss: -0.6188 - val_accuracy: 0.9324 - val_dice_coef: 0.5668 - val_f1_score: 0.3133 - val_loss: -0.5668 - lr: 0.0016
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9416 - dice_coef: 0.6208 - f1_score: 0.6209 - loss: -0.6197
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0007812500116415322.
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9416 - dice_coef: 0.6208 - f1_score: 0.6209 - loss: -0.6197 - val_accuracy: 0.9324 - val_dice_coef: 0.5099 - val_f1_score: 0.3118 - val_loss: -0.5099 - lr: 0.0016
# Epoch 36/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9415 - dice_coef: 0.6133 - f1_score: 0.6133 - loss: -0.6173 - val_accuracy: 0.9323 - val_dice_coef: 0.4211 - val_f1_score: 0.3154 - val_loss: -0.4211 - lr: 7.8125e-04
# Epoch 37/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9416 - dice_coef: 0.6214 - f1_score: 0.6214 - loss: -0.6232 - val_accuracy: 0.9323 - val_dice_coef: 0.4673 - val_f1_score: 0.3173 - val_loss: -0.4673 - lr: 7.8125e-04
# Epoch 38/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9415 - dice_coef: 0.6162 - f1_score: 0.6162 - loss: -0.6162 - val_accuracy: 0.9323 - val_dice_coef: 0.5171 - val_f1_score: 0.3178 - val_loss: -0.5171 - lr: 7.8125e-04
# Epoch 39/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9416 - dice_coef: 0.6232 - f1_score: 0.6233 - loss: -0.6221 - val_accuracy: 0.9324 - val_dice_coef: 0.5673 - val_f1_score: 0.3174 - val_loss: -0.5673 - lr: 7.8125e-04
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9416 - dice_coef: 0.6215 - f1_score: 0.6215 - loss: -0.6214
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0003906250058207661.
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9416 - dice_coef: 0.6215 - f1_score: 0.6215 - loss: -0.6214 - val_accuracy: 0.9323 - val_dice_coef: 0.5664 - val_f1_score: 0.3164 - val_loss: -0.5664 - lr: 7.8125e-04
#
# Completed UNet Training. (Step 03)
# Wed at 11:37:09PM
# confusion_unet [[9848137   49840]
#  [  56035   81188]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99   9897977
#          1.0       0.62      0.59      0.61    137223
#
#     accuracy                           0.99  10035200
#    macro avg       0.81      0.79      0.80  10035200
# weighted avg       0.99      0.99      0.99  10035200
#
#
# Completed Unet Evaluation. (Step 03)
#
# Training Results (Step 03):
# - Dice Coef: 65.314%
# - F1 Score: 65.319%
#
# Validation Results (Step 03):
# - Dice Coef: 53.285%
# - F1 Score: 53.289%
#
# Testing Results (Step 03):
# - Dice Coef: 60.524%
# - F1 Score: 60.531%
# Wed at 11:38:13PM
#
# EM_Step 03 (06) Complete.
# - Precision: 43.20%
# - SourceDelta: 15.81%
# - StepDelta: -3.33%
# Wed at 11:38:13PM
# ----------------------------------

# %%
# Prepare EM iterator index.
EM_iterator = 6
print()
print("Target Steps:", EM_target)
print(rebuild_model)
EM_target = 8
learningRate = 0.1
import random

# -----------------------------------------------------------------------------
# Begin Iteration -------------------------------------------------------------
while EM_iterator < EM_target:   
    
    # ---------------------------
    # 0. Initialization
    # ---------------------------
    section_tstamp = time.time()
    section_name = 'EM_Step {:02}'.format(EM_iterator)

    # Create folder for em step
    emfolder = os.path.join(test.dir, 'Step_{:02}'.format(EM_iterator))
    if not os.path.exists(emfolder): os.mkdir(emfolder)

    print("\n\nEM Step {:02} begun.".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    anno_stamp = time.time()
    
    # ---------------------------
    # 1. Creating New Annotations
    # ---------------------------

    # 1.1 Get probability output map from last model (Skip first step since it was pre-generated)
    pmap_fp = os.path.join(emfolder, 'pmap_{:02}.tif'.format(EM_iterator))
    p_output = emt.Get_Pmap(train_raster, WinShape, unet_model, pmap_fp)
    
    print("\nGenerated Probability Output Map from previous model. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    
    # 1.2 Weight Candidate Frames
    newSegments = []
    for frame in candidateFrames:
        
        # Get Candidate Weights
        weightedFrame = emt.WeightCandidates(p_output, frame)
        
        # Select Likely or Top Candidate 
        if random.uniform(0,1) < random_candidate_chance:
            # Use 'likely' candidate (ENSURE Select_Candidate() FUNCTION IS UPDATED (lib/EMTools.py))
            newSegments.append(emt.Select_Candidate(weightedFrame, 'weight', weight_limit))
        else:
            # Use top candidate
            newSegments.append(emt.Top_Candidate(weightedFrame, 'weight'))
        
        
    # 1.3 Convert List of segments to GeoDataFrame
    newSegmentFrame = gpd.GeoDataFrame(geometry=newSegments, crs=candidateFrames[0].crs)
    newSegmentFrame.to_file(os.path.join(emfolder, 'segments_{:02}.shp'.format(EM_iterator)))

    # 1.4 Connect top segments:
    newAnnotation = emt.Connect_Lines(newSegmentFrame, maxRepairDist)
    newAnnotation.to_file(os.path.join(emfolder, 'annotation_{:02}.shp'.format(EM_iterator)))

    # 1.5 Save mean precision of this annotation.
    annoPrecision = emt.GDF_Precision(gt_labels, newAnnotation, precisionBuffer)

    
    print("\nCreated New Annotation. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    anno_time = time.time() - anno_stamp
    
    # ---------------------------
    # 2. Create new Label Tensors
    # ---------------------------
    
    # 2.1 Rasterize New Labels
    buff_anno = st.GDF_Buffer(newAnnotation, labelBuffer, flatten=True)
    anno_raster = st.GDF_Rasterize(buff_anno, train_raster)
    
    # 2.2 Read Y_train, Y_val
    Y_train = gt.ResampleTiles(anno_raster, train_offsets_fp)
    Y_val = gt.ResampleTiles(anno_raster, val_offsets_fp)
    
    # 2.2 Augment Y_train, Y_val
    Y_train = gt.AugmentImages(Y_train, h_flip=train_h_flip, v_flip=train_v_flip, rotate=train_rotate)
    Y_val = gt.AugmentImages(Y_val, h_flip=val_h_flip, v_flip=val_v_flip, rotate=val_rotate)
    
    print("\nCreated Y_train {} and Y_val {}. (Step {:02})".format(Y_train.shape, Y_val.shape, EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    
    
    # ---------------------------
    # 3. Re-Train U-Net 
    # ---------------------------
    
    # 3.1 Load Callbacks 
    callbacks = SetCallbacks(emfolder + '/model_{:02}.h5'.format(EM_iterator))
    
    # 3.2 Determine Learning Rate from schedule
    EM_learningRate = Step_LR_Schedule(learningRate, EM_iterator, EM_target, lr_const)
    print("\nNew Learning Rate: {:.6f}. (Step {:02})".format(EM_learningRate, EM_iterator))
        
    training_stamp = time.time()
    with mirror_strategy.scope():
        unet_model = UNET_7_224()
        unet_model.compile(optimizer=Adam(lr=EM_learningRate), loss=dice_coef_loss, metrics=metrics)
        TrainData = unet_model.fit(X_train, Y_train, validation_data=(X_val, Y_val), shuffle=useShuffle, batch_size=batchSize, epochs=epochs, callbacks=callbacks)
    training_time = time.time() - training_stamp
    
    training_metrics = {
        'f1': Get_Metric_Data(TrainData, 'f1_score'),
        'dice_coef': Get_Metric_Data(TrainData, 'dice_coef'),
        'loss': Get_Metric_Data(TrainData, 'loss')
    }

    train_metrics_fp = os.path.join(emfolder, 'train_curve_{:02}.csv'.format(EM_iterator))
    with open(train_metrics_fp, 'a+', newline='\n') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter= ',')
        for key, data in training_metrics.items():
            csvwriter.writerow(['Training {}'.format(key)])
            csvwriter.writerow(data)
            
    validation_metrics = {
        'f1': Get_Metric_Data(TrainData, 'val_f1_score'),
        'dice_coef': Get_Metric_Data(TrainData, 'val_dice_coef'),
        'loss': Get_Metric_Data(TrainData, 'val_loss')
    }   
    val_metrics_fp = os.path.join(emfolder, 'val_curve_{:02}.csv'.format(EM_iterator))
    with open(val_metrics_fp, 'a+', newline='\n') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter= ',')
        for key, data in training_metrics.items():
            csvwriter.writerow(['Validation {}'.format(key)])
            csvwriter.writerow(data)
    
    SaveHistory(TrainData, os.path.join(emfolder, 'trainingResults_{:02}'.format(EM_iterator)), test.end) # Save Plots
    
    print("\nCompleted UNet Training. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    


    # ---------------------------
    # 4. Evaluate Model
    # ---------------------------

    
    # Training Results
    train_results = emt.Evaluate(X_train, Y_train, unet_model)
    # Validation Results
    val_results = emt.Evaluate(X_val, Y_val, unet_model)
    # Testing Results
    test_results = emt.Evaluate(X_test, Y_test, unet_model)

    
    
    # print
    print("\nCompleted Unet Evaluation. (Step {:02})".format(EM_iterator))
    print("\nTraining Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(train_results[0]))
    print("- {}".format(train_results[1]))
    print("\nValidation Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(val_results[0]))
    print("- {}".format(val_results[1]))   
    print("\nTesting Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(test_results[0]))
    print("- {}".format(test_results[1]))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    y_pred=np.copy(unet_model.predict(X_test))
    y_pred = np.round(y_pred)
    y_true=np.copy(Y_test)
    y_pred.shape = y_pred.shape[0]* y_pred.shape[1]*y_pred.shape[2]* y_pred.shape[3]
    y_true.shape = y_true.shape[0]* y_true.shape[1]*y_true.shape[2]* y_true.shape[3]

    c_matrix = confusion_matrix(y_true, y_pred, labels=[0, 1])
    print("confusion_unet", c_matrix)
    report_unet = classification_report(y_true, y_pred)
    print("report_unet", report_unet)
    
    # ---------------------------
    # 5. Save Step Data
    # ---------------------------
    
    # Save to dict for seperate CSV
    dataMatrix['precision'].append(annoPrecision*100)
    dataMatrix['trainDice'].append(train_results[0]) 
    dataMatrix['trainF1Score'].append(train_results[1]) 
    dataMatrix['valDice'].append(val_results[0]) 
    dataMatrix['valF1Score'].append(val_results[1]) 
    dataMatrix['testDice'].append(test_results[0]) 
    dataMatrix['testF1Score'].append(test_results[1]) 
    
    
    # Save EM Step Data 
    test.Results("EM Data {:02}".format(EM_iterator), {
            
        'Time Elapsed: Re-training': training_time,
        'Time Elapsed: New Annotation': anno_time,
            
        'Precision': '{:.2f}%'.format(annoPrecision*100),
        'SourceDelta': '{:.2f}%'.format((annoPrecision-sourcePrecision)*100),
        'StepDelta': '{:.2f}%'.format((annoPrecision-prevPrecision)*100),
        
        'UNet: LR': str(EM_learningRate),
        'UNet: Epochs': str(len(TrainData.history['dice_coef'])),
        
        'UNet: Training Results': train_results,
        'UNet: Validation Results': val_results,
        'UNet: Testing Results': test_results,
        'UNet: Confusion Matrix': c_matrix,
        'UNet: Report': report_unet
    })
    # Save as section
    section_data = {'time': time.time()-section_tstamp, 'stamp': section_tstamp}
    test.Section(section_name, section_data)
    
    # Print step data
    print("\n{} ({:02}) Complete.".format(section_name, len(test.sectionNames)))
    print('- Precision: {:.2f}%'.format(annoPrecision*100))
    print('- SourceDelta: {:.2f}%'.format((annoPrecision-sourcePrecision)*100))
    print('- StepDelta: {:.2f}%'.format((annoPrecision-prevPrecision)*100))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    print("----------------------------------\n\n")
    
    # Increase iterator and save previous precision for step_delta
    EM_iterator += 1
    prevPrecision = annoPrecision
# Out:
# Target Steps: 6
# True
#
#
# EM Step 06 begun.
# Thu at 12:12:25AM
#
# Generated Probability Output Map from previous model. (Step 06)
# Thu at 12:12:51AM
#
# Created New Annotation. (Step 06)
# Thu at 12:13:31AM
#
# Created Y_train (2792, 224, 224, 1) and Y_val (160, 224, 224, 1). (Step 06)
# Thu at 12:13:40AM
#
# New Learning Rate: 0.100000. (Step 06)
# Epoch 1/50
# 88/88 [==============================] - 15s 166ms/step - accuracy: 0.9190 - dice_coef: 0.3081 - f1_score: 0.3101 - loss: -0.3082 - val_accuracy: 0.0173 - val_dice_coef: 0.0334 - val_f1_score: 0.0334 - val_loss: -0.0334 - lr: 0.1000
# Epoch 2/50
# 88/88 [==============================] - 12s 135ms/step - accuracy: 0.9331 - dice_coef: 0.3944 - f1_score: 0.3945 - loss: -0.3937 - val_accuracy: 0.0611 - val_dice_coef: 0.0340 - val_f1_score: 0.0340 - val_loss: -0.0340 - lr: 0.1000
# Epoch 3/50
# 88/88 [==============================] - 12s 133ms/step - accuracy: 0.9350 - dice_coef: 0.4344 - f1_score: 0.4345 - loss: -0.4349 - val_accuracy: 0.8779 - val_dice_coef: 0.0554 - val_f1_score: 0.0555 - val_loss: -0.0554 - lr: 0.1000
# Epoch 4/50
# 88/88 [==============================] - 12s 134ms/step - accuracy: 0.9362 - dice_coef: 0.4730 - f1_score: 0.4730 - loss: -0.4742 - val_accuracy: 0.9115 - val_dice_coef: 0.1164 - val_f1_score: 0.1171 - val_loss: -0.1164 - lr: 0.1000
# Epoch 5/50
# 88/88 [==============================] - 12s 135ms/step - accuracy: 0.9375 - dice_coef: 0.5063 - f1_score: 0.5064 - loss: -0.5082 - val_accuracy: 0.9325 - val_dice_coef: 0.2021 - val_f1_score: 0.2021 - val_loss: -0.2021 - lr: 0.1000
# Epoch 6/50
# 88/88 [==============================] - 12s 135ms/step - accuracy: 0.9381 - dice_coef: 0.5206 - f1_score: 0.5207 - loss: -0.5226 - val_accuracy: 0.9323 - val_dice_coef: 0.2185 - val_f1_score: 0.2185 - val_loss: -0.2185 - lr: 0.1000
# Epoch 7/50
# 88/88 [==============================] - 12s 135ms/step - accuracy: 0.9385 - dice_coef: 0.5379 - f1_score: 0.5379 - loss: -0.5367 - val_accuracy: 0.9333 - val_dice_coef: 0.2888 - val_f1_score: 0.2888 - val_loss: -0.2888 - lr: 0.1000
# Epoch 8/50
# 88/88 [==============================] - 12s 135ms/step - accuracy: 0.9391 - dice_coef: 0.5632 - f1_score: 0.5632 - loss: -0.5630 - val_accuracy: 0.9337 - val_dice_coef: 0.3399 - val_f1_score: 0.3399 - val_loss: -0.3399 - lr: 0.1000
# Epoch 9/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9394 - dice_coef: 0.5660 - f1_score: 0.5660 - loss: -0.5686 - val_accuracy: 0.9344 - val_dice_coef: 0.3380 - val_f1_score: 0.2880 - val_loss: -0.3380 - lr: 0.1000
# Epoch 10/50
# 88/88 [==============================] - 12s 135ms/step - accuracy: 0.9396 - dice_coef: 0.5695 - f1_score: 0.5696 - loss: -0.5731 - val_accuracy: 0.9349 - val_dice_coef: 0.4433 - val_f1_score: 0.2933 - val_loss: -0.4433 - lr: 0.1000
# Epoch 11/50
# 88/88 [==============================] - 11s 130ms/step - accuracy: 0.9399 - dice_coef: 0.5738 - f1_score: 0.5738 - loss: -0.5768 - val_accuracy: 0.9344 - val_dice_coef: 0.3116 - val_f1_score: 0.3116 - val_loss: -0.3116 - lr: 0.1000
# Epoch 12/50
# 88/88 [==============================] - 11s 128ms/step - accuracy: 0.9397 - dice_coef: 0.5818 - f1_score: 0.5818 - loss: -0.5818 - val_accuracy: 0.9352 - val_dice_coef: 0.3168 - val_f1_score: 0.3169 - val_loss: -0.3168 - lr: 0.1000
# Epoch 13/50
# 88/88 [==============================] - 12s 131ms/step - accuracy: 0.9402 - dice_coef: 0.5859 - f1_score: 0.5859 - loss: -0.5860 - val_accuracy: 0.9355 - val_dice_coef: 0.3208 - val_f1_score: 0.3208 - val_loss: -0.3208 - lr: 0.1000
# Epoch 14/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9402 - dice_coef: 0.5909 - f1_score: 0.5910 - loss: -0.5936 - val_accuracy: 0.9341 - val_dice_coef: 0.2936 - val_f1_score: 0.2936 - val_loss: -0.2936 - lr: 0.1000
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9402 - dice_coef: 0.5890 - f1_score: 0.5890 - loss: -0.5912
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 88/88 [==============================] - 12s 132ms/step - accuracy: 0.9402 - dice_coef: 0.5890 - f1_score: 0.5890 - loss: -0.5912 - val_accuracy: 0.9344 - val_dice_coef: 0.3155 - val_f1_score: 0.3155 - val_loss: -0.3155 - lr: 0.1000
# Epoch 16/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9409 - dice_coef: 0.6154 - f1_score: 0.6154 - loss: -0.6159 - val_accuracy: 0.9363 - val_dice_coef: 0.4221 - val_f1_score: 0.3222 - val_loss: -0.4221 - lr: 0.0500
# Epoch 17/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9409 - dice_coef: 0.6087 - f1_score: 0.6087 - loss: -0.6093 - val_accuracy: 0.9334 - val_dice_coef: 0.3404 - val_f1_score: 0.3403 - val_loss: -0.3404 - lr: 0.0500
# Epoch 18/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9411 - dice_coef: 0.6181 - f1_score: 0.6181 - loss: -0.6193 - val_accuracy: 0.9364 - val_dice_coef: 0.3311 - val_f1_score: 0.3311 - val_loss: -0.3311 - lr: 0.0500
# Epoch 19/50
# 88/88 [==============================] - 12s 132ms/step - accuracy: 0.9412 - dice_coef: 0.6234 - f1_score: 0.6234 - loss: -0.6252 - val_accuracy: 0.9363 - val_dice_coef: 0.5028 - val_f1_score: 0.3028 - val_loss: -0.5028 - lr: 0.0500
# Epoch 20/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9413 - dice_coef: 0.6265 - f1_score: 0.6266 - loss: -0.6294 - val_accuracy: 0.9366 - val_dice_coef: 0.4294 - val_f1_score: 0.3294 - val_loss: -0.4294 - lr: 0.0500
# Epoch 21/50
# 88/88 [==============================] - 12s 136ms/step - accuracy: 0.9414 - dice_coef: 0.6287 - f1_score: 0.6287 - loss: -0.6287 - val_accuracy: 0.9369 - val_dice_coef: 0.6332 - val_f1_score: 0.3332 - val_loss: -0.6332 - lr: 0.0500
# Epoch 22/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9415 - dice_coef: 0.6288 - f1_score: 0.6288 - loss: -0.6327 - val_accuracy: 0.9368 - val_dice_coef: 0.3538 - val_f1_score: 0.3518 - val_loss: -0.3538 - lr: 0.0500
# Epoch 23/50
# 88/88 [==============================] - 12s 131ms/step - accuracy: 0.9411 - dice_coef: 0.6230 - f1_score: 0.6230 - loss: -0.6251 - val_accuracy: 0.9368 - val_dice_coef: 0.3972 - val_f1_score: 0.3453 - val_loss: -0.3972 - lr: 0.0500
# Epoch 24/50
# 88/88 [==============================] - 11s 130ms/step - accuracy: 0.9413 - dice_coef: 0.6238 - f1_score: 0.6238 - loss: -0.6271 - val_accuracy: 0.9364 - val_dice_coef: 0.3893 - val_f1_score: 0.3392 - val_loss: -0.3893 - lr: 0.0500
# Epoch 25/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9415 - dice_coef: 0.6327 - f1_score: 0.6328 - loss: -0.6337 - val_accuracy: 0.9366 - val_dice_coef: 0.4355 - val_f1_score: 0.3355 - val_loss: -0.4355 - lr: 0.0500
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9416 - dice_coef: 0.6354 - f1_score: 0.6354 - loss: -0.6373
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9416 - dice_coef: 0.6354 - f1_score: 0.6354 - loss: -0.6373 - val_accuracy: 0.9366 - val_dice_coef: 0.3892 - val_f1_score: 0.3393 - val_loss: -0.3892 - lr: 0.0500
# Epoch 27/50
# 88/88 [==============================] - 11s 129ms/step - accuracy: 0.9417 - dice_coef: 0.6385 - f1_score: 0.6385 - loss: -0.6407 - val_accuracy: 0.9370 - val_dice_coef: 0.3982 - val_f1_score: 0.3483 - val_loss: -0.3982 - lr: 0.0250
# Epoch 28/50
# 88/88 [==============================] - 11s 128ms/step - accuracy: 0.9418 - dice_coef: 0.6451 - f1_score: 0.6451 - loss: -0.6462 - val_accuracy: 0.9370 - val_dice_coef: 0.5461 - val_f1_score: 0.3461 - val_loss: -0.5461 - lr: 0.0250
# Epoch 29/50
# 88/88 [==============================] - 12s 131ms/step - accuracy: 0.9418 - dice_coef: 0.6447 - f1_score: 0.6447 - loss: -0.6440 - val_accuracy: 0.9368 - val_dice_coef: 0.3788 - val_f1_score: 0.3288 - val_loss: -0.3788 - lr: 0.0250
# Epoch 30/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9418 - dice_coef: 0.6452 - f1_score: 0.6452 - loss: -0.6466 - val_accuracy: 0.9369 - val_dice_coef: 0.3361 - val_f1_score: 0.3360 - val_loss: -0.3361 - lr: 0.0250
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9420 - dice_coef: 0.6449 - f1_score: 0.6449 - loss: -0.6461
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9420 - dice_coef: 0.6449 - f1_score: 0.6449 - loss: -0.6461 - val_accuracy: 0.9372 - val_dice_coef: 0.4501 - val_f1_score: 0.3501 - val_loss: -0.4501 - lr: 0.0250
# Epoch 32/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9421 - dice_coef: 0.6481 - f1_score: 0.6481 - loss: -0.6496 - val_accuracy: 0.9373 - val_dice_coef: 0.5407 - val_f1_score: 0.3406 - val_loss: -0.5407 - lr: 0.0125
# Epoch 33/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9418 - dice_coef: 0.6334 - f1_score: 0.6334 - loss: -0.6377 - val_accuracy: 0.9371 - val_dice_coef: 0.3942 - val_f1_score: 0.3443 - val_loss: -0.3942 - lr: 0.0125
# Epoch 34/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9421 - dice_coef: 0.6492 - f1_score: 0.6492 - loss: -0.6499 - val_accuracy: 0.9373 - val_dice_coef: 0.5881 - val_f1_score: 0.3381 - val_loss: -0.5881 - lr: 0.0125
# Epoch 35/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9421 - dice_coef: 0.6491 - f1_score: 0.6491 - loss: -0.6521 - val_accuracy: 0.9372 - val_dice_coef: 0.4431 - val_f1_score: 0.3431 - val_loss: -0.4431 - lr: 0.0125
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9422 - dice_coef: 0.6585 - f1_score: 0.6585 - loss: -0.6597
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9422 - dice_coef: 0.6585 - f1_score: 0.6585 - loss: -0.6597 - val_accuracy: 0.9372 - val_dice_coef: 0.5447 - val_f1_score: 0.3447 - val_loss: -0.5447 - lr: 0.0125
# Epoch 37/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9423 - dice_coef: 0.6564 - f1_score: 0.6564 - loss: -0.6596 - val_accuracy: 0.9372 - val_dice_coef: 0.4947 - val_f1_score: 0.3447 - val_loss: -0.4947 - lr: 0.0063
# Epoch 38/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9423 - dice_coef: 0.6599 - f1_score: 0.6599 - loss: -0.6593 - val_accuracy: 0.9372 - val_dice_coef: 0.5007 - val_f1_score: 0.3507 - val_loss: -0.5007 - lr: 0.0063
# Epoch 39/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9423 - dice_coef: 0.6602 - f1_score: 0.6602 - loss: -0.6595 - val_accuracy: 0.9374 - val_dice_coef: 0.5108 - val_f1_score: 0.3608 - val_loss: -0.5108 - lr: 0.0063
# Epoch 40/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9423 - dice_coef: 0.6590 - f1_score: 0.6590 - loss: -0.6619 - val_accuracy: 0.9372 - val_dice_coef: 0.4505 - val_f1_score: 0.3506 - val_loss: -0.4505 - lr: 0.0063
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9425 - dice_coef: 0.6678 - f1_score: 0.6678 - loss: -0.6671
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9425 - dice_coef: 0.6678 - f1_score: 0.6678 - loss: -0.6671 - val_accuracy: 0.9372 - val_dice_coef: 0.5451 - val_f1_score: 0.3451 - val_loss: -0.5451 - lr: 0.0063
#
# Completed UNet Training. (Step 06)
# Thu at 12:22:01AM
#
# Completed Unet Evaluation. (Step 06)
#
# Training Results (Step 06):
# - Dice Coef: 69.530%
# - F1 Score: 69.531%
#
# Validation Results (Step 06):
# - Dice Coef: 59.867%
# - F1 Score: 59.871%
#
# Testing Results (Step 06):
# - Dice Coef: 66.657%
# - F1 Score: 66.657%
# Thu at 12:22:19AM
# confusion_unet [[9849319   48658]
#  [  44303   92920]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00   9897977
#          1.0       0.66      0.68      0.67    137223
#
#     accuracy                           0.99  10035200
#    macro avg       0.83      0.84      0.83  10035200
# weighted avg       0.99      0.99      0.99  10035200
#
#
# EM_Step 06 (09) Complete.
# - Precision: 49.41%
# - SourceDelta: 22.02%
# - StepDelta: 2.06%
# Thu at 12:23:06AM
# ----------------------------------
#
#
#
#
# EM Step 07 begun.
# Thu at 12:23:06AM
#
# Generated Probability Output Map from previous model. (Step 07)
# Thu at 12:23:30AM
#
# Created New Annotation. (Step 07)
# Thu at 12:24:11AM
#
# Created Y_train (2792, 224, 224, 1) and Y_val (160, 224, 224, 1). (Step 07)
# Thu at 12:24:21AM
#
# New Learning Rate: 0.050000. (Step 07)
# Epoch 1/50
# 88/88 [==============================] - 14s 158ms/step - accuracy: 0.9119 - dice_coef: 0.2934 - f1_score: 0.2976 - loss: -0.2938 - val_accuracy: 0.1431 - val_dice_coef: 0.0338 - val_f1_score: 0.0338 - val_loss: -0.0338 - lr: 0.0500
# Epoch 2/50
# 88/88 [==============================] - 12s 133ms/step - accuracy: 0.9326 - dice_coef: 0.3879 - f1_score: 0.3880 - loss: -0.3892 - val_accuracy: 0.8631 - val_dice_coef: 0.1157 - val_f1_score: 0.1156 - val_loss: -0.1157 - lr: 0.0500
# Epoch 3/50
# 88/88 [==============================] - 12s 134ms/step - accuracy: 0.9343 - dice_coef: 0.4230 - f1_score: 0.4232 - loss: -0.4245 - val_accuracy: 0.9285 - val_dice_coef: 0.3998 - val_f1_score: 0.0000e+00 - val_loss: -0.3998 - lr: 0.0500
# Epoch 4/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9353 - dice_coef: 0.4525 - f1_score: 0.4527 - loss: -0.4560 - val_accuracy: 0.9285 - val_dice_coef: 0.0151 - val_f1_score: 0.0150 - val_loss: -0.0151 - lr: 0.0500
# Epoch 5/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9363 - dice_coef: 0.4821 - f1_score: 0.4823 - loss: -0.4815 - val_accuracy: 0.9298 - val_dice_coef: 0.2586 - val_f1_score: 0.1983 - val_loss: -0.2586 - lr: 0.0500
# Epoch 6/50
# 88/88 [==============================] - 12s 134ms/step - accuracy: 0.9370 - dice_coef: 0.5010 - f1_score: 0.5010 - loss: -0.5028 - val_accuracy: 0.9303 - val_dice_coef: 0.5225 - val_f1_score: 0.1783 - val_loss: -0.5225 - lr: 0.0500
# Epoch 7/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9381 - dice_coef: 0.5297 - f1_score: 0.5298 - loss: -0.5290 - val_accuracy: 0.9306 - val_dice_coef: 0.3648 - val_f1_score: 0.2654 - val_loss: -0.3648 - lr: 0.0500
# Epoch 8/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9386 - dice_coef: 0.5552 - f1_score: 0.5553 - loss: -0.5569 - val_accuracy: 0.9298 - val_dice_coef: 0.2870 - val_f1_score: 0.2871 - val_loss: -0.2870 - lr: 0.0500
# Epoch 9/50
# 88/88 [==============================] - 12s 132ms/step - accuracy: 0.9387 - dice_coef: 0.5556 - f1_score: 0.5557 - loss: -0.5547 - val_accuracy: 0.9313 - val_dice_coef: 0.2881 - val_f1_score: 0.2881 - val_loss: -0.2881 - lr: 0.0500
# Epoch 10/50
# 88/88 [==============================] - 11s 130ms/step - accuracy: 0.9391 - dice_coef: 0.5708 - f1_score: 0.5708 - loss: -0.5713 - val_accuracy: 0.9320 - val_dice_coef: 0.2686 - val_f1_score: 0.2686 - val_loss: -0.2686 - lr: 0.0500
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9394 - dice_coef: 0.5747 - f1_score: 0.5747 - loss: -0.5761
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9394 - dice_coef: 0.5747 - f1_score: 0.5747 - loss: -0.5761 - val_accuracy: 0.9312 - val_dice_coef: 0.3004 - val_f1_score: 0.3005 - val_loss: -0.3004 - lr: 0.0500
# Epoch 12/50
# 88/88 [==============================] - 11s 124ms/step - accuracy: 0.9401 - dice_coef: 0.5981 - f1_score: 0.5982 - loss: -0.5993 - val_accuracy: 0.9331 - val_dice_coef: 0.3720 - val_f1_score: 0.3222 - val_loss: -0.3720 - lr: 0.0250
# Epoch 13/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9402 - dice_coef: 0.6049 - f1_score: 0.6049 - loss: -0.6042 - val_accuracy: 0.9330 - val_dice_coef: 0.3007 - val_f1_score: 0.3007 - val_loss: -0.3007 - lr: 0.0250
# Epoch 14/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9400 - dice_coef: 0.5946 - f1_score: 0.5946 - loss: -0.5972 - val_accuracy: 0.9335 - val_dice_coef: 0.4505 - val_f1_score: 0.3036 - val_loss: -0.4505 - lr: 0.0250
# Epoch 15/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9403 - dice_coef: 0.6048 - f1_score: 0.6048 - loss: -0.6048 - val_accuracy: 0.9318 - val_dice_coef: 0.3144 - val_f1_score: 0.3144 - val_loss: -0.3144 - lr: 0.0250
# Epoch 16/50
# 88/88 [==============================] - 12s 136ms/step - accuracy: 0.9403 - dice_coef: 0.6037 - f1_score: 0.6037 - loss: -0.6043 - val_accuracy: 0.9333 - val_dice_coef: 0.6470 - val_f1_score: 0.2971 - val_loss: -0.6470 - lr: 0.0250
# Epoch 17/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9406 - dice_coef: 0.6171 - f1_score: 0.6171 - loss: -0.6200 - val_accuracy: 0.9334 - val_dice_coef: 0.3662 - val_f1_score: 0.3227 - val_loss: -0.3662 - lr: 0.0250
# Epoch 18/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9406 - dice_coef: 0.6172 - f1_score: 0.6172 - loss: -0.6176 - val_accuracy: 0.9332 - val_dice_coef: 0.4905 - val_f1_score: 0.2907 - val_loss: -0.4905 - lr: 0.0250
# Epoch 19/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9407 - dice_coef: 0.6196 - f1_score: 0.6196 - loss: -0.6217 - val_accuracy: 0.9326 - val_dice_coef: 0.3740 - val_f1_score: 0.2996 - val_loss: -0.3740 - lr: 0.0250
# Epoch 20/50
# 88/88 [==============================] - 11s 128ms/step - accuracy: 0.9405 - dice_coef: 0.6173 - f1_score: 0.6174 - loss: -0.6171 - val_accuracy: 0.9330 - val_dice_coef: 0.3300 - val_f1_score: 0.3300 - val_loss: -0.3300 - lr: 0.0250
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9407 - dice_coef: 0.6144 - f1_score: 0.6144 - loss: -0.6166
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9407 - dice_coef: 0.6144 - f1_score: 0.6144 - loss: -0.6166 - val_accuracy: 0.9327 - val_dice_coef: 0.3205 - val_f1_score: 0.3204 - val_loss: -0.3205 - lr: 0.0250
# Epoch 22/50
# 88/88 [==============================] - 11s 128ms/step - accuracy: 0.9409 - dice_coef: 0.6232 - f1_score: 0.6232 - loss: -0.6242 - val_accuracy: 0.9332 - val_dice_coef: 0.3323 - val_f1_score: 0.3324 - val_loss: -0.3323 - lr: 0.0125
# Epoch 23/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9411 - dice_coef: 0.6327 - f1_score: 0.6327 - loss: -0.6354 - val_accuracy: 0.9334 - val_dice_coef: 0.5204 - val_f1_score: 0.3205 - val_loss: -0.5204 - lr: 0.0125
# Epoch 24/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9411 - dice_coef: 0.6276 - f1_score: 0.6276 - loss: -0.6293 - val_accuracy: 0.9338 - val_dice_coef: 0.4811 - val_f1_score: 0.3311 - val_loss: -0.4811 - lr: 0.0125
# Epoch 25/50
# 88/88 [==============================] - 12s 135ms/step - accuracy: 0.9412 - dice_coef: 0.6375 - f1_score: 0.6375 - loss: -0.6365 - val_accuracy: 0.9339 - val_dice_coef: 0.7309 - val_f1_score: 0.3310 - val_loss: -0.7309 - lr: 0.0125
# Epoch 26/50
# 88/88 [==============================] - 11s 128ms/step - accuracy: 0.9412 - dice_coef: 0.6356 - f1_score: 0.6357 - loss: -0.6352 - val_accuracy: 0.9336 - val_dice_coef: 0.5705 - val_f1_score: 0.3207 - val_loss: -0.5705 - lr: 0.0125
# Epoch 27/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9413 - dice_coef: 0.6369 - f1_score: 0.6369 - loss: -0.6400 - val_accuracy: 0.9338 - val_dice_coef: 0.4418 - val_f1_score: 0.3417 - val_loss: -0.4418 - lr: 0.0125
# Epoch 28/50
# 88/88 [==============================] - 11s 128ms/step - accuracy: 0.9414 - dice_coef: 0.6422 - f1_score: 0.6422 - loss: -0.6442 - val_accuracy: 0.9338 - val_dice_coef: 0.7278 - val_f1_score: 0.3279 - val_loss: -0.7278 - lr: 0.0125
# Epoch 29/50
# 88/88 [==============================] - 11s 129ms/step - accuracy: 0.9413 - dice_coef: 0.6379 - f1_score: 0.6379 - loss: -0.6415 - val_accuracy: 0.9340 - val_dice_coef: 0.6342 - val_f1_score: 0.3350 - val_loss: -0.6342 - lr: 0.0125
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9413 - dice_coef: 0.6333 - f1_score: 0.6334 - loss: -0.6362
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9413 - dice_coef: 0.6333 - f1_score: 0.6334 - loss: -0.6362 - val_accuracy: 0.9336 - val_dice_coef: 0.4261 - val_f1_score: 0.3261 - val_loss: -0.4261 - lr: 0.0125
# Epoch 31/50
# 88/88 [==============================] - 11s 128ms/step - accuracy: 0.9416 - dice_coef: 0.6469 - f1_score: 0.6469 - loss: -0.6509 - val_accuracy: 0.9339 - val_dice_coef: 0.5205 - val_f1_score: 0.3356 - val_loss: -0.5205 - lr: 0.0063
# Epoch 32/50
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9416 - dice_coef: 0.6414 - f1_score: 0.6414 - loss: -0.6461 - val_accuracy: 0.9333 - val_dice_coef: 0.4298 - val_f1_score: 0.3298 - val_loss: -0.4298 - lr: 0.0063
# Epoch 33/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9418 - dice_coef: 0.6585 - f1_score: 0.6585 - loss: -0.6594 - val_accuracy: 0.9339 - val_dice_coef: 0.5816 - val_f1_score: 0.3317 - val_loss: -0.5816 - lr: 0.0063
# Epoch 34/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9416 - dice_coef: 0.6462 - f1_score: 0.6462 - loss: -0.6481 - val_accuracy: 0.9336 - val_dice_coef: 0.5347 - val_f1_score: 0.3348 - val_loss: -0.5347 - lr: 0.0063
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9417 - dice_coef: 0.6493 - f1_score: 0.6493 - loss: -0.6519
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 88/88 [==============================] - 11s 127ms/step - accuracy: 0.9417 - dice_coef: 0.6493 - f1_score: 0.6493 - loss: -0.6519 - val_accuracy: 0.9335 - val_dice_coef: 0.3841 - val_f1_score: 0.3341 - val_loss: -0.3841 - lr: 0.0063
# Epoch 36/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9418 - dice_coef: 0.6546 - f1_score: 0.6547 - loss: -0.6566 - val_accuracy: 0.9337 - val_dice_coef: 0.3325 - val_f1_score: 0.3325 - val_loss: -0.3325 - lr: 0.0031
# Epoch 37/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9418 - dice_coef: 0.6526 - f1_score: 0.6526 - loss: -0.6528 - val_accuracy: 0.9338 - val_dice_coef: 0.4315 - val_f1_score: 0.3360 - val_loss: -0.4315 - lr: 0.0031
# Epoch 38/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9418 - dice_coef: 0.6534 - f1_score: 0.6534 - loss: -0.6548 - val_accuracy: 0.9339 - val_dice_coef: 0.4913 - val_f1_score: 0.3355 - val_loss: -0.4913 - lr: 0.0031
# Epoch 39/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9419 - dice_coef: 0.6616 - f1_score: 0.6617 - loss: -0.6634 - val_accuracy: 0.9339 - val_dice_coef: 0.5894 - val_f1_score: 0.3342 - val_loss: -0.5894 - lr: 0.0031
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9418 - dice_coef: 0.6566 - f1_score: 0.6566 - loss: -0.6571
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0015625000232830644.
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9418 - dice_coef: 0.6566 - f1_score: 0.6566 - loss: -0.6571 - val_accuracy: 0.9339 - val_dice_coef: 0.4319 - val_f1_score: 0.3357 - val_loss: -0.4319 - lr: 0.0031
# Epoch 41/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9419 - dice_coef: 0.6597 - f1_score: 0.6598 - loss: -0.6613 - val_accuracy: 0.9338 - val_dice_coef: 0.4367 - val_f1_score: 0.3364 - val_loss: -0.4367 - lr: 0.0016
# Epoch 42/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9420 - dice_coef: 0.6607 - f1_score: 0.6607 - loss: -0.6633 - val_accuracy: 0.9338 - val_dice_coef: 0.4358 - val_f1_score: 0.3358 - val_loss: -0.4358 - lr: 0.0016
# Epoch 43/50
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9419 - dice_coef: 0.6512 - f1_score: 0.6512 - loss: -0.6518 - val_accuracy: 0.9338 - val_dice_coef: 0.4441 - val_f1_score: 0.3360 - val_loss: -0.4441 - lr: 0.0016
# Epoch 44/50
# 88/88 [==============================] - 11s 125ms/step - accuracy: 0.9419 - dice_coef: 0.6582 - f1_score: 0.6582 - loss: -0.6580 - val_accuracy: 0.9338 - val_dice_coef: 0.4363 - val_f1_score: 0.3363 - val_loss: -0.4363 - lr: 0.0016
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - accuracy: 0.9421 - dice_coef: 0.6638 - f1_score: 0.6638 - loss: -0.6650
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.0007812500116415322.
# 88/88 [==============================] - 11s 126ms/step - accuracy: 0.9421 - dice_coef: 0.6638 - f1_score: 0.6638 - loss: -0.6650 - val_accuracy: 0.9339 - val_dice_coef: 0.4865 - val_f1_score: 0.3366 - val_loss: -0.4865 - lr: 0.0016
#
# Completed UNet Training. (Step 07)
# Thu at 12:33:23AM
#
# Completed Unet Evaluation. (Step 07)
#
# Training Results (Step 07):
# - Dice Coef: 68.798%
# - F1 Score: 68.800%
#
# Validation Results (Step 07):
# - Dice Coef: 58.533%
# - F1 Score: 58.540%
#
# Testing Results (Step 07):
# - Dice Coef: 64.523%
# - F1 Score: 64.521%
# Thu at 12:33:41AM
# confusion_unet [[9851314   46663]
#  [  49648   87575]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00   9897977
#          1.0       0.65      0.64      0.65    137223
#
#     accuracy                           0.99  10035200
#    macro avg       0.82      0.82      0.82  10035200
# weighted avg       0.99      0.99      0.99  10035200
#
#
# EM_Step 07 (10) Complete.
# - Precision: 47.71%
# - SourceDelta: 20.32%
# - StepDelta: -1.70%
# Thu at 12:34:28AM
# ----------------------------------

# %%
""" Save EM step data to csv
with open(os.path.join(test.dir, 'EM_Data.csv'), 'a+', newline='\n') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter= ',')
    csvwriter.writerow([test.name, 'Line Precisions (delta)', 'Train Dice Coef (delta)', 'Train F1 Score (delta)', 'Val Dice Coef (delta)', 'Val F1 Score (delta)', 'Test Dice Coef (delta)', 'Test F1 Score (delta)'])
    for i in range(len(dataMatrix['precision'])):
        row = ['step {:02}'.format(i)]
        for key, item in dataMatrix.items():
            row.append('{} ({})'.format(item[i], item[i]-item[0]))
        csvwriter.writerow(row)
"""

# Index test in master csv
test.index()

# Write test Info to Markdown
test.markdown()

# Print Completion
print("Data successfully saved to markdown file, indexed on csv.") 
print(dt.now().strftime('%a at %I:%M:%S%p'))
# Out:
# Data successfully saved to markdown file, indexed on csv.
# Thu at 12:05:20AM

# %%
# Prepare EM iterator index.
EM_iterator = 6
print()
print("Target Steps:", EM_target)
print(rebuild_model)
EM_target = 8
learningRate = 0.1
import random

# -----------------------------------------------------------------------------
# Begin Iteration -------------------------------------------------------------
while EM_iterator < EM_target:   
    
    # ---------------------------
    # 0. Initialization
    # ---------------------------
    section_tstamp = time.time()
    section_name = 'EM_Step {:02}'.format(EM_iterator)

    # Create folder for em step
    emfolder = os.path.join(test.dir, 'Step_{:02}'.format(EM_iterator))
    if not os.path.exists(emfolder): os.mkdir(emfolder)

    print("\n\nEM Step {:02} begun.".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    anno_stamp = time.time()
    
    # ---------------------------
    # 1. Creating New Annotations
    # ---------------------------

    # 1.1 Get probability output map from last model (Skip first step since it was pre-generated)
    pmap_fp = os.path.join(emfolder, 'pmap_{:02}.tif'.format(EM_iterator))
    p_output = emt.Get_Pmap(train_raster, WinShape, unet_model, pmap_fp)
    
    print("\nGenerated Probability Output Map from previous model. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    
    # 1.2 Weight Candidate Frames
    newSegments = []
    for frame in candidateFrames:
        
        # Get Candidate Weights
        weightedFrame = emt.WeightCandidates(p_output, frame)
        
        # Select Likely or Top Candidate 
        if random.uniform(0,1) < random_candidate_chance:
            # Use 'likely' candidate (ENSURE Select_Candidate() FUNCTION IS UPDATED (lib/EMTools.py))
            newSegments.append(emt.Select_Candidate(weightedFrame, 'weight', weight_limit))
        else:
            # Use top candidate
            newSegments.append(emt.Top_Candidate(weightedFrame, 'weight'))
        
        
    # 1.3 Convert List of segments to GeoDataFrame
    newSegmentFrame = gpd.GeoDataFrame(geometry=newSegments, crs=candidateFrames[0].crs)
    newSegmentFrame.to_file(os.path.join(emfolder, 'segments_{:02}.shp'.format(EM_iterator)))

    # 1.4 Connect top segments:
    newAnnotation = emt.Connect_Lines(newSegmentFrame, maxRepairDist)
    newAnnotation.to_file(os.path.join(emfolder, 'annotation_{:02}.shp'.format(EM_iterator)))

    # 1.5 Save mean precision of this annotation.
    annoPrecision = emt.GDF_Precision(gt_labels, newAnnotation, precisionBuffer)

    
    print("\nCreated New Annotation. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    
    
    # ---------------------------
    # 2. Create new Label Tensors
    # ---------------------------
    
    # 2.1 Rasterize New Labels
    buff_anno = st.GDF_Buffer(newAnnotation, labelBuffer, flatten=True)
    anno_raster = st.GDF_Rasterize(buff_anno, train_raster)
    
    # 2.2 Read Y_train, Y_val
    Y_train = gt.ResampleTiles(anno_raster, train_offsets_fp)
    Y_val = gt.ResampleTiles(anno_raster, val_offsets_fp)
    
    # 2.2 Augment Y_train, Y_val
    Y_train = gt.AugmentImages(Y_train, h_flip=train_h_flip, v_flip=train_v_flip, rotate=train_rotate)
    Y_val = gt.AugmentImages(Y_val, h_flip=val_h_flip, v_flip=val_v_flip, rotate=val_rotate)
    
    print("\nCreated Y_train {} and Y_val {}. (Step {:02})".format(Y_train.shape, Y_val.shape, EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    
    anno_time = time.time() - anno_stamp
    
    # ---------------------------
    # 3. Re-Train U-Net 
    # ---------------------------
    
    # 3.1 Load Callbacks 
    callbacks = SetCallbacks(emfolder + '/model_{:02}.h5'.format(EM_iterator))
    
    # 3.2 Determine Learning Rate from schedule
    EM_learningRate = Step_LR_Schedule(learningRate, EM_iterator, EM_target, lr_const)
    print("\nNew Learning Rate: {:.6f}. (Step {:02})".format(EM_learningRate, EM_iterator))
        
    training_stamp = time.time()
    with mirror_strategy.scope():
        unet_model = UNET_7_224()
        unet_model.compile(optimizer=Adam(lr=EM_learningRate), loss=dice_coef_loss, metrics=metrics)
        TrainData = unet_model.fit(X_train, Y_train, validation_data=(X_val, Y_val), shuffle=useShuffle, batch_size=batchSize, epochs=epochs, callbacks=callbacks)
    training_time = time.time() - training_stamp
    
    training_metrics = {
        'f1': Get_Metric_Data(TrainData, 'f1_score'),
        'dice_coef': Get_Metric_Data(TrainData, 'dice_coef'),
        'loss': Get_Metric_Data(TrainData, 'loss')
    }

    train_metrics_fp = os.path.join(emfolder, 'train_curve_{:02}.csv'.format(EM_iterator))
    with open(train_metrics_fp, 'a+', newline='\n') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter= ',')
        for key, data in training_metrics.items():
            csvwriter.writerow('Training {}'.format(key))
            csvwriter.writerow(data)


    validation_metrics = {
        'f1': Get_Metric_Data(TrainData, 'val_f1_score'),
        'dice_coef': Get_Metric_Data(TrainData, 'val_dice_coef'),
        'loss': Get_Metric_Data(TrainData, 'val_loss')
    }  
    val_metrics_fp = os.path.join(emfolder, 'val_curve_{:02}.csv'.format(m_step_iterator))
    with open(val_metrics_fp, 'a+', newline='\n') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter= ',')
        for key, data in training_metrics.items():
            csvwriter.writerow('Training {}'.format(key))
            csvwriter.writerow(data)
            
            
    SaveHistory(TrainData, os.path.join(emfolder, 'trainingResults_{:02}'.format(EM_iterator)), test.end) # Save Plots
    
    print("\nCompleted UNet Training. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    


    # ---------------------------
    # 4. Evaluate Model
    # ---------------------------

    
    # Training Results
    train_results = emt.Evaluate(X_train, Y_train, unet_model)
    # Validation Results
    val_results = emt.Evaluate(X_val, Y_val, unet_model)
    # Testing Results
    test_results = emt.Evaluate(X_test, Y_test, unet_model)

    # print
    print("\nCompleted Unet Evaluation. (Step {:02})".format(EM_iterator))
    print("\nTraining Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(train_results[0]))
    print("- {}".format(train_results[1]))
    print("\nValidation Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(val_results[0]))
    print("- {}".format(val_results[1]))   
    print("\nTesting Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(test_results[0]))
    print("- {}".format(test_results[1]))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    
    
    # ---------------------------
    # 5. Save Step Data
    # ---------------------------
    
    # Save to dict for seperate CSV
    dataMatrix['precision'].append(annoPrecision*100)
    dataMatrix['trainDice'].append(train_results[0]) 
    dataMatrix['trainF1Score'].append(train_results[1]) 
    dataMatrix['valDice'].append(val_results[0]) 
    dataMatrix['valF1Score'].append(val_results[1]) 
    dataMatrix['testDice'].append(test_results[0]) 
    dataMatrix['testF1Score'].append(test_results[1]) 
    
    
    # Save EM Step Data 
    test.Results("EM Data {:02}".format(EM_iterator), {
        
            
        'Time Elapsed: Re-training': training_time,
        'Time Elapsed: New Annotation': anno_time,
            
        'Precision': '{:.2f}%'.format(annoPrecision*100),
        'SourceDelta': '{:.2f}%'.format((annoPrecision-sourcePrecision)*100),
        'StepDelta': '{:.2f}%'.format((annoPrecision-prevPrecision)*100),
        
        'UNet: LR': str(EM_learningRate),
        'UNet: Epochs': str(len(TrainData.history['dice_coef'])),
        
        'UNet: Training Results': train_results,
        'UNet: Validation Results': val_results,
        'UNet: Testing Results': test_results
    })
    # Save as section
    section_data = {'time': time.time()-section_tstamp, 'stamp': section_tstamp}
    test.Section(section_name, section_data)
    
    # Print step data
    print("\n{} ({:02}) Complete.".format(section_name, len(test.sectionNames)))
    print('- Precision: {:.2f}%'.format(annoPrecision*100))
    print('- SourceDelta: {:.2f}%'.format((annoPrecision-sourcePrecision)*100))
    print('- StepDelta: {:.2f}%'.format((annoPrecision-prevPrecision)*100))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    print("----------------------------------\n\n")
    
    # Increase iterator and save previous precision for step_delta
    EM_iterator += 1
    prevPrecision = annoPrecision
# Out:
#   File "<ipython-input-7-e58325acc77e>", line 132
#     with open(val_metrics_fp), 'a+', newline='\n') as csvfile:
#                                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Save Test Data

# %%
import os

print(os.listdir('/home/jiang-ws1/'))
# Out:
# ['GeometricErrors', '.pki', '.config', '.sudo_as_admin_successful', 'learning', '.ssh', '.ICEauthority', 'crop_window.shp', 'tensorflow_datasets', '.bash_logout', '0.01', 'examples.desktop', '.ipynb_checkpoints', '.viminfo', '.plotly', '.python_history', 'cudnn_samples_v7', 'git', '.xsession-errors', 'DataFromLarry', 'lib\\UnetTools.py', '.bash_history', '.mozilla', 'Desktop', '.wget-hsts', '.conda', '.keras', 'crop_window.dbf', 'Documents', 'tf1', 'Music', '.local', 'Pictures', '.nvidia-settings-rc', '.thunderbird', '.dbus', '.gnupg', '.nv', '.Xauthority', 'venvinfo.md', 'temp_geoerrors', 'crop_window.qpj', 'Public', '.virtualenvs', 'HMT_BigDataTest', 'StreetView_DeepLearning', 'Untitled.ipynb', 'Teaching', '.gdal', '.bashrc', '.ipython', 'crop_window.shx', '.anydesk', 'Videos', '.profile', 'crop_window.prj', '.emacs.d', '.jupyter', 'Untitled1.ipynb', 'NVIDIA_CUDA-9.2_Samples', '.cache', 'Logs', '.lesshst', '.vim', 'Templates', 'Downloads']
