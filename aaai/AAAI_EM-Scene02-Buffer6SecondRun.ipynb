# %% [markdown]
# # AAAI EM Iteration Notebook
#
# Slightly modified for current system.
#
#
# ---
#
# ### Required:
# - Tensors:
#     - `X_test`: Testing Image Tensor
#     - `Y_test`: Testing Label Tensor
#     - `X_train`: Training Image Tensor
#     - `X_val`: Validation Image Tensor
#     - `train_offsets`: Window offsets for scanning `Y_train` as path to csv.
#     - `val_offsets`: Window offsets for scanning `Y_val` as path to csv.
#
# - `segments`: Candidate line segments accross training raster in directory
#
# - `preweights`: pre-trained Weights for U-Net model on the passed `X_train`, `X_val` tensors
#
# - `initial_pmap`: pmap output from baseline data

# %%
# -- All Imports --
import os, sys, time, csv

import tensorflow as tf
import numpy as np
import random as rand
import geopandas as gpd
import matplotlib.pyplot as plt

from lib.ModuleTools import *
from lib.UnetTools import *
import lib.GeoTools as gt
import lib.ShapeTools as st
import lib.EMTools as emt
import lib.LineGen as lg

# Parameters, Files
from lib.EMconfigScene02 import *
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# -- Module Information --
module_data = {
    'name': 'EM_Iteration_s02', # Module Name
    'desc': 'Iterate over EM process using the second dataset', # Module Description
    'test_name': 'aaai_emtest_s02', # Default test name
    'csv': 'master_s02.csv', # Csv path
    'verbose': True # Default verbosity
}
test = ModuleTest(module_data)
# -------------------------


# -- Iteration Parameters --
iteration = {}

# Number of EM iterations
EM_target = wrap(2, iteration) 
 
# Constant Value for Learning Rate Schedule 
lr_const = wrap(2, iteration)

# optionally reset layer weights between iterations
rebuild_model = wrap( True, iteration)

# (epsilon) Chance that a candidate will be selected outside of the top candidate, within the K top candidates.
random_candidate_chance = wrap( 0, iteration)

# (K) Consider K top-weighted segments. set 1 for top candidate, set 0 to consider all.
weight_limit = wrap( 13, iteration)


# Option to load candidates, generally set to true
load_candidates = True

# The parameters below are defined in the /lib/EMconfig.py file. 
test.Pgroup("Iteration", iteration)
test.Pgroup("Environment", env)
test.Pgroup("Tensor Data", TensorConfig)
test.Pgroup("Annotation Configuration", Annotations)
test.Pgroup("UNet Config", unetcfg)
test.Pgroup('Baseline Directories', inputDirs)
test.Fgroup('Input Arrays', InputArrays)
test.Fgroup('Source_Data', sourceData)


""" Test Parameters """

# UNET configuration
learningRate = 0.05
learningRateReduced = 0.1

# Candidate Segment Directory - Generate with other notebook
#CandidateDirectory = '/data/GeometricErrors/aaai_data/segments'
CandidateDirectory = '/data/GeometricErrors/tests/aaai_system/Candidates-Scene02/segment_sets_scene02_04/segments_04'
#04_new exp increase interval 15 1.5, 1.2 candidates
#03_No exp, equal interval, 20, 1.5 candidates
#02_No exp, equal interval, 15, 1.5

# Total number of EM steps
EM_target = 6

# Use random choice when selecting candidates below weight threshold (Implemented here)
default_random = False


mirror_strategy = tf.distribute.MirroredStrategy(devices=['/gpu:0', '/gpu:1', '/gpu:2', '/gpu:3'])

# ---------------
print(dt.now().strftime('Hyperparameters saved on %a at %I:%M:%S %p.'))
# Out:
# /home/jiang-ws1/.virtualenvs/geo_errors/lib/python3.7/site-packages/geopandas/_compat.py:88: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.8.1-CAPI-1.13.3). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string
# aaai_emtest_s02_06 was already run, delete old folder? ('y' to delete).y
# Describe aaai_emtest_s02_06:test again
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# Hyperparameters saved on Thu at 02:05:46 PM.

# %%
print(inputDirs)
inputDirs.update({"CandidateDirectory": CandidateDirectory})
unetcfg.update({"learningRate": learningRate})
# Out:
# {'CandidateDirectory': '/data/GeometricErrors/aaai_data/scene02/segments', 'train_offsets_fp': '/data/GeometricErrors/aaai_data/scene02/train_offsets.csv', 'val_offsets_fp': '/data/GeometricErrors/aaai_data/scene02/val_offsets.csv'}

# %% [markdown]
# ## Load Baseline Data

# %%
section_tstamp = time.time()
section_name = 'Prepare Base Data'
# --------------------

# 1. Shapefile Precisions
imp_labels = st.Flatten_Frame(imp_labels)
sourcePrecision = emt.GDF_Precision(gt_labels, imp_labels, precisionBuffer)
prevPrecision = sourcePrecision

emfolder = os.path.join(test.dir, 'Baseline')
if not os.path.exists(emfolder): os.mkdir(emfolder)
    
section_tstamp = time.time()
section_name = 'Prepare Model'
# --------------------

callbacks = SetCallbacks(test.dir + '/baseline_model.h5')

# 5. Load Unet Model
from tensorflow.keras.optimizers import Adam

# %%
with mirror_strategy.scope():
    unet_model = UNET_7_224()
    unet_model.compile(optimizer=Adam(lr=learningRate), loss=dice_coef_loss, metrics=metrics)
    unet_model.fit(X_train, Y_train, validation_data=(X_val, Y_val), shuffle=useShuffle, batch_size=batchSize, epochs=epochs, callbacks=callbacks)
pmap_fp = os.path.join(emfolder, 'pmap_baseline.tif')
initial_pmap = emt.Get_Pmap(train_raster, WinShape, unet_model, pmap_fp)
    
print("\nInitialized U_Net model.")
print(dt.now().strftime('%a at %I:%M:%S%p'))

# 6. Evaluate Unet Model
# Save Training Results
train_results = emt.Evaluate(X_train, Y_train, unet_model)
# Save Validation Results
val_results = emt.Evaluate(X_val, Y_val, unet_model)
# Save Testing Results
test_results = emt.Evaluate(X_test, Y_test, unet_model)

y_pred=np.copy(unet_model.predict(X_test))
y_pred = np.round(y_pred)
y_true=np.copy(Y_test)
y_pred.shape = y_pred.shape[0]* y_pred.shape[1]*y_pred.shape[2]* y_pred.shape[3]
y_true.shape = y_true.shape[0]* y_true.shape[1]*y_true.shape[2]* y_true.shape[3]

c_matrix = confusion_matrix(y_true, y_pred, labels=[0, 1])
print("Confusion Matrix", c_matrix)
report_unet = classification_report(y_true, y_pred)
print("report_unet", report_unet)

# Print the baseline metrics
print("\nRan Initial U_Net evaluation:")
print("\nBaseline Training Results:")
print("- {}".format(train_results[0]))
print("- {}".format(train_results[1]))
print("\nBaseline Validation Results:")
print("- {}".format(val_results[0]))
print("- {}".format(val_results[1]))
print("\nBaseline Testing Results:")
print("- {}".format(test_results[0]))
print("- {}".format(test_results[1]))
print("\nBaseline Shape Metrics")
print("- Precision: {:.2f}".format(sourcePrecision*100))
print(dt.now().strftime('%a at %I:%M:%S%p'))


# Save initial EM Data 
test.Results("Baseline Data", {
    'Precision': '{:.2f}%'.format(sourcePrecision*100),
    'UNet: Training Results': train_results,
    'UNet: Validation Results': val_results,
    'UNet: Testing Results': test_results,
    'UNet: Report': report_unet, 
    'UNet: Confusion Matrix': c_matrix
})


# Create Matrix to save step data in seperate CSV
dataMatrix = {
    'precision': [sourcePrecision*100],
    
    'trainDice': [train_results[0]],
    'trainF1Score': [train_results[1]],
    
    'valDice': [val_results[0]],
    'valF1Score': [val_results[1]],
    
    'testDice': [test_results[0]],
    'testF1Score': [test_results[1]]
}

# --------------------
section_data = {'time': time.time()-section_tstamp, 'stamp': section_tstamp}
test.Section(section_name, section_data)
# --------------------
if test.verbose:
    print("\n{} ({:02}) Complete.".format(section_name, len(test.sectionNames)))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# 32/32 [==============================] - 10s 299ms/step - accuracy: 0.7116 - loss: -0.3462 - dice_coef: 0.3471 - f1_score: 0.3522 - val_accuracy: 0.0836 - val_loss: -0.1488 - val_dice_coef: 0.1461 - val_f1_score: 0.1461 - lr: 0.0500
# Epoch 2/50
# 32/32 [==============================] - 4s 125ms/step - accuracy: 0.8553 - loss: -0.4773 - dice_coef: 0.4780 - f1_score: 0.4787 - val_accuracy: 0.0836 - val_loss: -0.1488 - val_dice_coef: 0.1461 - val_f1_score: 0.1461 - lr: 0.0500
# Epoch 3/50
# 32/32 [==============================] - 5s 168ms/step - accuracy: 0.8574 - loss: -0.5038 - dice_coef: 0.5022 - f1_score: 0.5024 - val_accuracy: 0.1409 - val_loss: -0.1528 - val_dice_coef: 0.1501 - val_f1_score: 0.1501 - lr: 0.0500
# Epoch 4/50
# 32/32 [==============================] - 5s 168ms/step - accuracy: 0.8643 - loss: -0.5278 - dice_coef: 0.5283 - f1_score: 0.5287 - val_accuracy: 0.1505 - val_loss: -0.1544 - val_dice_coef: 0.1517 - val_f1_score: 0.1517 - lr: 0.0500
# Epoch 5/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8628 - loss: -0.5306 - dice_coef: 0.5295 - f1_score: 0.5297 - val_accuracy: 0.1293 - val_loss: -0.1533 - val_dice_coef: 0.1505 - val_f1_score: 0.1505 - lr: 0.0500
# Epoch 6/50
# 32/32 [==============================] - 5s 167ms/step - accuracy: 0.8582 - loss: -0.5167 - dice_coef: 0.5152 - f1_score: 0.5154 - val_accuracy: 0.2485 - val_loss: -0.1627 - val_dice_coef: 0.1598 - val_f1_score: 0.1598 - lr: 0.0500
# Epoch 7/50
# 32/32 [==============================] - 5s 171ms/step - accuracy: 0.8654 - loss: -0.5425 - dice_coef: 0.5409 - f1_score: 0.5416 - val_accuracy: 0.8294 - val_loss: -0.2656 - val_dice_coef: 0.2596 - val_f1_score: 0.2599 - lr: 0.0500
# Epoch 8/50
# 32/32 [==============================] - 5s 167ms/step - accuracy: 0.8661 - loss: -0.5474 - dice_coef: 0.5482 - f1_score: 0.5483 - val_accuracy: 0.8481 - val_loss: -0.4470 - val_dice_coef: 0.4592 - val_f1_score: 0.2122 - lr: 0.0500
# Epoch 9/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8702 - loss: -0.5553 - dice_coef: 0.5564 - f1_score: 0.5566 - val_accuracy: 0.8537 - val_loss: -0.2403 - val_dice_coef: 0.2357 - val_f1_score: 0.2357 - lr: 0.0500
# Epoch 10/50
# 32/32 [==============================] - 5s 168ms/step - accuracy: 0.8701 - loss: -0.5645 - dice_coef: 0.5645 - f1_score: 0.5646 - val_accuracy: 0.8354 - val_loss: -0.4822 - val_dice_coef: 0.4958 - val_f1_score: 0.2463 - lr: 0.0500
# Epoch 11/50
# 32/32 [==============================] - 6s 172ms/step - accuracy: 0.8708 - loss: -0.5687 - dice_coef: 0.5681 - f1_score: 0.5682 - val_accuracy: 0.8529 - val_loss: -0.5153 - val_dice_coef: 0.5262 - val_f1_score: 0.2767 - lr: 0.0500
# Epoch 12/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8710 - loss: -0.5620 - dice_coef: 0.5618 - f1_score: 0.5619 - val_accuracy: 0.8335 - val_loss: -0.2418 - val_dice_coef: 0.2389 - val_f1_score: 0.2249 - lr: 0.0500
# Epoch 13/50
# 32/32 [==============================] - 6s 173ms/step - accuracy: 0.8737 - loss: -0.5858 - dice_coef: 0.5875 - f1_score: 0.5886 - val_accuracy: 0.8386 - val_loss: -0.5321 - val_dice_coef: 0.5445 - val_f1_score: 0.2946 - lr: 0.0500
# Epoch 14/50
# 32/32 [==============================] - 4s 130ms/step - accuracy: 0.8732 - loss: -0.5781 - dice_coef: 0.5772 - f1_score: 0.5773 - val_accuracy: 0.8556 - val_loss: -0.3789 - val_dice_coef: 0.3917 - val_f1_score: 0.1418 - lr: 0.0500
# Epoch 15/50
# 32/32 [==============================] - 5s 170ms/step - accuracy: 0.8750 - loss: -0.5820 - dice_coef: 0.5822 - f1_score: 0.5826 - val_accuracy: 0.8505 - val_loss: -0.5592 - val_dice_coef: 0.5704 - val_f1_score: 0.3204 - lr: 0.0500
# Epoch 16/50
# 32/32 [==============================] - 4s 129ms/step - accuracy: 0.8767 - loss: -0.5975 - dice_coef: 0.5977 - f1_score: 0.5980 - val_accuracy: 0.8559 - val_loss: -0.2943 - val_dice_coef: 0.3092 - val_f1_score: 0.0592 - lr: 0.0500
# Epoch 17/50
# 32/32 [==============================] - 6s 174ms/step - accuracy: 0.8764 - loss: -0.5839 - dice_coef: 0.5841 - f1_score: 0.5841 - val_accuracy: 0.8563 - val_loss: -0.5707 - val_dice_coef: 0.5798 - val_f1_score: 0.3298 - lr: 0.0500
# Epoch 18/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8778 - loss: -0.6067 - dice_coef: 0.6066 - f1_score: 0.6066 - val_accuracy: 0.8589 - val_loss: -0.2365 - val_dice_coef: 0.2532 - val_f1_score: 0.0032 - lr: 0.0500
# Epoch 19/50
# 32/32 [==============================] - 6s 180ms/step - accuracy: 0.8724 - loss: -0.5765 - dice_coef: 0.5768 - f1_score: 0.5768 - val_accuracy: 0.8564 - val_loss: -0.5753 - val_dice_coef: 0.5848 - val_f1_score: 0.3348 - lr: 0.0500
# Epoch 20/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8776 - loss: -0.5937 - dice_coef: 0.5941 - f1_score: 0.5953 - val_accuracy: 0.8080 - val_loss: -0.3329 - val_dice_coef: 0.3265 - val_f1_score: 0.3265 - lr: 0.0500
# Epoch 21/50
# 32/32 [==============================] - 4s 129ms/step - accuracy: 0.8796 - loss: -0.6134 - dice_coef: 0.6137 - f1_score: 0.6141 - val_accuracy: 0.8584 - val_loss: -0.4807 - val_dice_coef: 0.4916 - val_f1_score: 0.2417 - lr: 0.0500
# Epoch 22/50
# 32/32 [==============================] - 4s 130ms/step - accuracy: 0.8806 - loss: -0.6112 - dice_coef: 0.6107 - f1_score: 0.6107 - val_accuracy: 0.8564 - val_loss: -0.4903 - val_dice_coef: 0.5019 - val_f1_score: 0.2519 - lr: 0.0500
# Epoch 23/50
# 32/32 [==============================] - 4s 135ms/step - accuracy: 0.8821 - loss: -0.6183 - dice_coef: 0.6196 - f1_score: 0.6196 - val_accuracy: 0.8625 - val_loss: -0.4463 - val_dice_coef: 0.4582 - val_f1_score: 0.2083 - lr: 0.0500
# Epoch 24/50
# 32/32 [==============================] - 5s 170ms/step - accuracy: 0.8822 - loss: -0.6197 - dice_coef: 0.6199 - f1_score: 0.6199 - val_accuracy: 0.8627 - val_loss: -0.6371 - val_dice_coef: 0.6449 - val_f1_score: 0.3949 - lr: 0.0500
# Epoch 25/50
# 32/32 [==============================] - 4s 133ms/step - accuracy: 0.8841 - loss: -0.6313 - dice_coef: 0.6318 - f1_score: 0.6318 - val_accuracy: 0.8644 - val_loss: -0.4849 - val_dice_coef: 0.4947 - val_f1_score: 0.2447 - lr: 0.0500
# Epoch 26/50
# 32/32 [==============================] - 4s 129ms/step - accuracy: 0.8865 - loss: -0.6367 - dice_coef: 0.6386 - f1_score: 0.6386 - val_accuracy: 0.8591 - val_loss: -0.2333 - val_dice_coef: 0.2500 - val_f1_score: 0.0000e+00 - lr: 0.0500
# Epoch 27/50
# 32/32 [==============================] - 4s 129ms/step - accuracy: 0.8869 - loss: -0.6446 - dice_coef: 0.6430 - f1_score: 0.6431 - val_accuracy: 0.8652 - val_loss: -0.5204 - val_dice_coef: 0.5285 - val_f1_score: 0.2785 - lr: 0.0500
# Epoch 28/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8873 - loss: -0.6424 - dice_coef: 0.6421 - f1_score: 0.6421 - val_accuracy: 0.8519 - val_loss: -0.5687 - val_dice_coef: 0.5770 - val_f1_score: 0.3269 - lr: 0.0500
# Epoch 29/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8890 - loss: -0.6513 - dice_coef: 0.6508 - f1_score: 0.6510
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8890 - loss: -0.6513 - dice_coef: 0.6508 - f1_score: 0.6510 - val_accuracy: 0.8591 - val_loss: -0.2333 - val_dice_coef: 0.2500 - val_f1_score: 0.0000e+00 - lr: 0.0500
# Epoch 30/50
# 32/32 [==============================] - 4s 138ms/step - accuracy: 0.8915 - loss: -0.6662 - dice_coef: 0.6670 - f1_score: 0.6670 - val_accuracy: 0.8602 - val_loss: -0.3316 - val_dice_coef: 0.3462 - val_f1_score: 0.0962 - lr: 0.0250
# Epoch 31/50
# 32/32 [==============================] - 4s 136ms/step - accuracy: 0.8920 - loss: -0.6677 - dice_coef: 0.6649 - f1_score: 0.6649 - val_accuracy: 0.8676 - val_loss: -0.5708 - val_dice_coef: 0.5790 - val_f1_score: 0.3290 - lr: 0.0250
# Epoch 32/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8921 - loss: -0.6685 - dice_coef: 0.6678 - f1_score: 0.6678 - val_accuracy: 0.8594 - val_loss: -0.3592 - val_dice_coef: 0.3738 - val_f1_score: 0.1238 - lr: 0.0250
# Epoch 33/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8948 - loss: -0.6846 - dice_coef: 0.6856 - f1_score: 0.6856 - val_accuracy: 0.8633 - val_loss: -0.5935 - val_dice_coef: 0.6019 - val_f1_score: 0.3520 - lr: 0.0250
# Epoch 34/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8959 - loss: -0.6880 - dice_coef: 0.6891 - f1_score: 0.6891
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 32/32 [==============================] - 4s 130ms/step - accuracy: 0.8959 - loss: -0.6880 - dice_coef: 0.6891 - f1_score: 0.6891 - val_accuracy: 0.8578 - val_loss: -0.2478 - val_dice_coef: 0.2642 - val_f1_score: 0.0160 - lr: 0.0250
# Epoch 35/50
# 32/32 [==============================] - 4s 131ms/step - accuracy: 0.8977 - loss: -0.6968 - dice_coef: 0.6966 - f1_score: 0.6967 - val_accuracy: 0.8668 - val_loss: -0.5002 - val_dice_coef: 0.5074 - val_f1_score: 0.2828 - lr: 0.0125
# Epoch 36/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8994 - loss: -0.7123 - dice_coef: 0.7125 - f1_score: 0.7125 - val_accuracy: 0.8658 - val_loss: -0.5114 - val_dice_coef: 0.5164 - val_f1_score: 0.3186 - lr: 0.0125
# Epoch 37/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8998 - loss: -0.7086 - dice_coef: 0.7098 - f1_score: 0.7099 - val_accuracy: 0.8648 - val_loss: -0.4405 - val_dice_coef: 0.4428 - val_f1_score: 0.2907 - lr: 0.0125
# Epoch 38/50
# 32/32 [==============================] - 4s 140ms/step - accuracy: 0.9004 - loss: -0.7150 - dice_coef: 0.7158 - f1_score: 0.7158 - val_accuracy: 0.8563 - val_loss: -0.0854 - val_dice_coef: 0.0905 - val_f1_score: 0.0107 - lr: 0.0125
# Epoch 39/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.9009 - loss: -0.7149 - dice_coef: 0.7150 - f1_score: 0.7164
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.9009 - loss: -0.7149 - dice_coef: 0.7150 - f1_score: 0.7164 - val_accuracy: 0.8577 - val_loss: -0.1952 - val_dice_coef: 0.2047 - val_f1_score: 0.0516 - lr: 0.0125
# Epoch 40/50
# 32/32 [==============================] - 4s 133ms/step - accuracy: 0.9013 - loss: -0.7228 - dice_coef: 0.7225 - f1_score: 0.7225 - val_accuracy: 0.8624 - val_loss: -0.3261 - val_dice_coef: 0.3274 - val_f1_score: 0.2104 - lr: 0.0063
# Epoch 41/50
# 32/32 [==============================] - 4s 129ms/step - accuracy: 0.9005 - loss: -0.7181 - dice_coef: 0.7138 - f1_score: 0.7138 - val_accuracy: 0.8677 - val_loss: -0.4016 - val_dice_coef: 0.3991 - val_f1_score: 0.3072 - lr: 0.0063
# Epoch 42/50
# 32/32 [==============================] - 4s 132ms/step - accuracy: 0.9029 - loss: -0.7232 - dice_coef: 0.7233 - f1_score: 0.7234 - val_accuracy: 0.8680 - val_loss: -0.4412 - val_dice_coef: 0.4391 - val_f1_score: 0.3403 - lr: 0.0063
# Epoch 43/50
# 32/32 [==============================] - 4s 134ms/step - accuracy: 0.9036 - loss: -0.7342 - dice_coef: 0.7329 - f1_score: 0.7330 - val_accuracy: 0.8680 - val_loss: -0.3994 - val_dice_coef: 0.3944 - val_f1_score: 0.3354 - lr: 0.0063
# Epoch 44/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.9024 - loss: -0.7229 - dice_coef: 0.7225 - f1_score: 0.7225
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 32/32 [==============================] - 4s 129ms/step - accuracy: 0.9024 - loss: -0.7229 - dice_coef: 0.7225 - f1_score: 0.7225 - val_accuracy: 0.8675 - val_loss: -0.3840 - val_dice_coef: 0.3771 - val_f1_score: 0.3498 - lr: 0.0063
#
# Initialized U_Net model.
# Thu at 02:09:54PM
# Confusion Matrix [[13520818   198068]
#  [  815398   518516]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.94      0.99      0.96  13718886
#          1.0       0.72      0.39      0.51   1333914
#
#     accuracy                           0.93  15052800
#    macro avg       0.83      0.69      0.73  15052800
# weighted avg       0.92      0.93      0.92  15052800
#
#
# Ran Initial U_Net evaluation:
#
# Baseline Training Results:
# - Dice Coef: 73.595%
# - F1 Score: 73.595%
#
# Baseline Validation Results:
# - Dice Coef: 45.248%
# - F1 Score: 45.249%
#
# Baseline Testing Results:
# - Dice Coef: 50.572%
# - F1 Score: 50.575%
#
# Baseline Shape Metrics
# - Precision: 14.21
# Thu at 02:11:12PM
#
# Prepare Model (01) Complete.
# Thu at 02:11:12PM

# %%
# preTrainedPath = '/data/GeometricErrors/tests/aaai_system/EM_Iteration_s02/aaai_emtest_s02_03/baseline_model.h5'
# unet_model = UNET_7_224()
# unet_model.compile(optimizer=Adam(lr=learningRate), loss=dice_coef_loss, metrics=metrics)
# unet_model.load_weights(preTrainedPath)

# pmap_fp = os.path.join(emfolder, 'pmap_baseline.tif')
# initial_pmap = emt.Get_Pmap(train_raster, WinShape, unet_model, pmap_fp)
    
# print("\nInitialized U_Net model.")
# print(dt.now().strftime('%a at %I:%M:%S%p'))

# # 6. Evaluate Unet Model
# # Save Training Results
# train_results = emt.Evaluate(X_train, Y_train, unet_model)
# # Save Validation Results
# val_results = emt.Evaluate(X_val, Y_val, unet_model)
# # Save Testing Results
# test_results = emt.Evaluate(X_test, Y_test, unet_model)

# y_pred=np.copy(unet_model.predict(X_test))
# y_pred = np.round(y_pred)
# y_true=np.copy(Y_test)
# y_pred.shape = y_pred.shape[0]* y_pred.shape[1]*y_pred.shape[2]* y_pred.shape[3]
# y_true.shape = y_true.shape[0]* y_true.shape[1]*y_true.shape[2]* y_true.shape[3]

# c_matrix = confusion_matrix(y_true, y_pred, labels=[0, 1])
# print("Confusion Matrix", c_matrix)
# report_unet = classification_report(y_true, y_pred)
# print("report_unet", report_unet)

# # Print the baseline metrics
# print("\nRan Initial U_Net evaluation:")
# print("\nBaseline Training Results:")
# print("- {}".format(train_results[0]))
# print("- {}".format(train_results[1]))
# print("\nBaseline Validation Results:")
# print("- {}".format(val_results[0]))
# print("- {}".format(val_results[1]))
# print("\nBaseline Testing Results:")
# print("- {}".format(test_results[0]))
# print("- {}".format(test_results[1]))
# print("\nBaseline Shape Metrics")
# print("- Precision: {:.2f}".format(sourcePrecision*100))
# print(dt.now().strftime('%a at %I:%M:%S%p'))


# # Save initial EM Data 
# test.Results("Baseline Data", {
#     'Precision': '{:.2f}%'.format(sourcePrecision*100),
#     'UNet: Training Results': train_results,
#     'UNet: Validation Results': val_results,
#     'UNet: Testing Results': test_results,
#     'UNet: Report': report_unet, 
#     'UNet: Confusion Matrix': c_matrix
# })


# # Create Matrix to save step data in seperate CSV
# dataMatrix = {
#     'precision': [sourcePrecision*100],
    
#     'trainDice': [train_results[0]],
#     'trainF1Score': [train_results[1]],
    
#     'valDice': [val_results[0]],
#     'valF1Score': [val_results[1]],
    
#     'testDice': [test_results[0]],
#     'testF1Score': [test_results[1]]
# }

# # --------------------
# section_data = {'time': time.time()-section_tstamp, 'stamp': section_tstamp}
# test.Section(section_name, section_data)
# # --------------------
# if test.verbose:
#     print("\n{} ({:02}) Complete.".format(section_name, len(test.sectionNames)))
#     print(dt.now().strftime('%a at %I:%M:%S%p'))

# %%
# 2. Check Array Shapes
print("-- Inputs  --")
for (title, arr) in [('X_train',X_train), ('X_val',X_val), ('X_test',X_test), ('Y_test',Y_test)]:
    print("{} Shape: {}".format(title, arr.shape))

if load_candidates:
    # 3. Load Candidates 
    candidateFrames = lg.LoadCandidates(CandidateDirectory)
    print("\n-- Candidates  --")
    print("Loaded Candidate Frames: {}".format(len(candidateFrames)))
    print("Candidates Per Segment (~): {}".format(len(candidateFrames[0].geometry)))

    # 4. Add Windows and Masks to candidates
    tstamp = time.time()
    candidateFrames = [emt.CandidateWindows(initial_pmap, c_frame, weightBuffer, convert_crs=False) for c_frame in candidateFrames]
    # %store candidateFrames
else:
    # %store -r candidateFrames
    print("Recalled {} candidate frames.".format(len(candidateFrames)))


# --------------------
section_data = {'time': time.time()-section_tstamp, 'stamp': section_tstamp}
test.Section(section_name, section_data)
# --------------------
if test.verbose:
    print("\n{} ({:02}) Complete.".format(section_name, len(test.sectionNames)))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
# Out:
# -- Inputs  --
# X_train Shape: (1008, 224, 224, 7)
# X_val Shape: (60, 224, 224, 7)
# X_test Shape: (300, 224, 224, 7)
# Y_test Shape: (300, 224, 224, 1)
#
# -- Candidates  --
# Loaded Candidate Frames: 547
# Candidates Per Segment (~): 61
# Stored 'candidateFrames' (list)
#
# Prepare Model (02) Complete.
# Thu at 02:12:07PM

# %%
print(candidateFrames[0].crs)
print(train_raster.crs)
# Out:
# epsg:26915
# EPSG:26915

# %% [markdown]
# ## EM Iteration

# %%
# Prepare EM iterator index.
EM_iterator = 0
dropval = 0.5
learningRate = 0.1

labelBuffer = wrap( 4 , iteration)
print("Target Steps:", EM_target)
print(rebuild_model)

import random

# -----------------------------------------------------------------------------
# Begin Iteration -------------------------------------------------------------
while EM_iterator < EM_target:   
    
    # ---------------------------
    # 0. Initialization
    # ---------------------------
    section_tstamp = time.time()
    section_name = 'EM_Step {:02}'.format(EM_iterator)

    # Create folder for em step
    emfolder = os.path.join(test.dir, 'Step_{:02}'.format(EM_iterator))
    if not os.path.exists(emfolder): os.mkdir(emfolder)

    print("\n\nEM Step {:02} begun.".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    anno_stamp = time.time()
    
    # ---------------------------
    # 1. Creating New Annotations
    # ---------------------------

    # 1.1 Get probability output map from last model (Skip first step since it was pre-generated)
    pmap_fp = os.path.join(emfolder, 'pmap_{:02}.tif'.format(EM_iterator))
    p_output = emt.Get_Pmap(train_raster, WinShape, unet_model, pmap_fp)
    
    print("\nGenerated Probability Output Map from previous model. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    
    # 1.2 Weight Candidate Frames
    newSegments = []
    for frame in candidateFrames:
        
        # Get Candidate Weights
        weightedFrame = emt.WeightCandidates(p_output, frame)
        
        # Select Likely or Top Candidate 
        if random.uniform(0,1) < random_candidate_chance:
            # Use 'likely' candidate (ENSURE Select_Candidate() FUNCTION IS UPDATED (lib/EMTools.py))
            newSegments.append(emt.Select_Candidate(weightedFrame, 'weight', weight_limit, default_random=default_random))
        else:
            # Use top candidate
            newSegments.append(emt.Top_Candidate(weightedFrame, 'weight', default_random=default_random))
            
            
        
    # 1.3 Convert List of segments to GeoDataFrame
    newSegmentFrame = gpd.GeoDataFrame(geometry=newSegments, crs=candidateFrames[0].crs)
    newSegmentFrame.to_file(os.path.join(emfolder, 'segments_{:02}.shp'.format(EM_iterator)))

    # 1.4 Connect top segments:
    newAnnotation = emt.Connect_Lines(newSegmentFrame, maxRepairDist)
    newAnnotation.to_file(os.path.join(emfolder, 'annotation_{:02}.shp'.format(EM_iterator)))

    # 1.5 Save mean precision of this annotation.
    annoPrecision = emt.GDF_Precision(gt_labels, newAnnotation, precisionBuffer)

    
    print("\nCreated New Annotation. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    anno_time = time.time() - anno_stamp
    
    # ---------------------------
    # 2. Create new Label Tensors
    # ---------------------------
    
    # 2.1 Rasterize New Labels
    buff_anno = st.GDF_Buffer(newAnnotation, labelBuffer, flatten=True)
    anno_raster = st.GDF_Rasterize(buff_anno, train_raster)
    
    # 2.2 Read Y_train, Y_val
    Y_train = gt.ResampleTiles(anno_raster, train_offsets_fp)
    Y_val = gt.ResampleTiles(anno_raster, val_offsets_fp)
    
    # 2.2 Augment Y_train, Y_val - NOTE: set horizontal flip to FALSE from Sultan's Setup
    Y_train = gt.AugmentImages(Y_train, h_flip=False, v_flip=train_v_flip, rotate=train_rotate)
    Y_val = gt.AugmentImages(Y_val, h_flip=False, v_flip=val_v_flip, rotate=val_rotate)
    
    print("\nCreated Y_train {} and Y_val {}. (Step {:02})".format(Y_train.shape, Y_val.shape, EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    
    
    # ---------------------------
    # 3. Re-Train U-Net 
    # ---------------------------
    
    # 3.1 Load Callbacks 
    callbacks = SetCallbacks(emfolder + '/model_{:02}.h5'.format(EM_iterator))
    
    # 3.2 Determine Learning Rate from schedule
    #EM_learningRate = Step_LR_Schedule(learningRate, EM_iterator, EM_target, lr_const)
    EM_learningRate = learningRate #(EM_iterator%2 + 1)*learningRate/2
    if EM_iterator > 5:
        EM_learningRate = learningRateReduced
    print("\nNew Learning Rate: {:.6f}. (Step {:02})".format(EM_learningRate, EM_iterator))
        
    training_stamp = time.time()
    with mirror_strategy.scope():
        unet_model = UNET_7_224(dropout_val = dropval)
        unet_model.compile(optimizer=Adam(lr=EM_learningRate), loss=dice_coef_loss, metrics=metrics)
        TrainData = unet_model.fit(X_train, Y_train, validation_data=(X_val, Y_val), shuffle=useShuffle, batch_size=batchSize, epochs=epochs, callbacks=callbacks)
    training_time = time.time() - training_stamp
    
    training_metrics = {
        'f1': Get_Metric_Data(TrainData, 'f1_score'),
        'dice_coef': Get_Metric_Data(TrainData, 'dice_coef'),
        'loss': Get_Metric_Data(TrainData, 'loss')
    }

    train_metrics_fp = os.path.join(emfolder, 'train_curve_{:02}.csv'.format(EM_iterator))
    with open(train_metrics_fp, 'a+', newline='\n') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter= ',')
        for key, data in training_metrics.items():
            csvwriter.writerow(['Training {}'.format(key)])
            csvwriter.writerow(data)
            
    validation_metrics = {
        'f1': Get_Metric_Data(TrainData, 'val_f1_score'),
        'dice_coef': Get_Metric_Data(TrainData, 'val_dice_coef'),
        'loss': Get_Metric_Data(TrainData, 'val_loss')
    }   
    val_metrics_fp = os.path.join(emfolder, 'val_curve_{:02}.csv'.format(EM_iterator))
    with open(val_metrics_fp, 'a+', newline='\n') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter= ',')
        for key, data in training_metrics.items():
            csvwriter.writerow(['Validation {}'.format(key)])
            csvwriter.writerow(data)
    
    SaveHistory(TrainData, os.path.join(emfolder, 'trainingResults_{:02}'.format(EM_iterator)), test.end) # Save Plots
    
    print("\nCompleted UNet Training. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    


    # ---------------------------
    # 4. Evaluate Model
    # ---------------------------

    
    # Training Results
    train_results = emt.Evaluate(X_train, Y_train, unet_model)
    # Validation Results
    val_results = emt.Evaluate(X_val, Y_val, unet_model)
    # Testing Results
    test_results = emt.Evaluate(X_test, Y_test, unet_model)

    
    
    # print
    print("\nCompleted Unet Evaluation. (Step {:02})".format(EM_iterator))
    print("\nTraining Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(train_results[0]))
    print("- {}".format(train_results[1]))
    print("\nValidation Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(val_results[0]))
    print("- {}".format(val_results[1]))   
    print("\nTesting Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(test_results[0]))
    print("- {}".format(test_results[1]))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    y_pred=np.copy(unet_model.predict(X_test))
    y_pred = np.round(y_pred)
    y_true=np.copy(Y_test)
    y_pred.shape = y_pred.shape[0]* y_pred.shape[1]*y_pred.shape[2]* y_pred.shape[3]
    y_true.shape = y_true.shape[0]* y_true.shape[1]*y_true.shape[2]* y_true.shape[3]

    c_matrix = confusion_matrix(y_true, y_pred, labels=[0, 1])
    print("confusion_unet", c_matrix)
    report_unet = classification_report(y_true, y_pred)
    print("report_unet", report_unet)
    
    # ---------------------------
    # 5. Save Step Data
    # ---------------------------
    
    # Save to dict for seperate CSV
    dataMatrix['precision'].append(annoPrecision*100)
    dataMatrix['trainDice'].append(train_results[0]) 
    dataMatrix['trainF1Score'].append(train_results[1]) 
    dataMatrix['valDice'].append(val_results[0]) 
    dataMatrix['valF1Score'].append(val_results[1]) 
    dataMatrix['testDice'].append(test_results[0]) 
    dataMatrix['testF1Score'].append(test_results[1]) 
    
    
    # Save EM Step Data 
    test.Results("EM Data {:02}".format(EM_iterator), {
            
        'Time Elapsed: Re-training': training_time,
        'Time Elapsed: New Annotation': anno_time,
            
        'Precision': '{:.2f}%'.format(annoPrecision*100),
        'SourceDelta': '{:.2f}%'.format((annoPrecision-sourcePrecision)*100),
        'StepDelta': '{:.2f}%'.format((annoPrecision-prevPrecision)*100),
        
        'UNet: LR': str(EM_learningRate),
        'UNet: Epochs': str(len(TrainData.history['dice_coef'])),
        
        'UNet: Training Results': train_results,
        'UNet: Validation Results': val_results,
        'UNet: Testing Results': test_results,
        'UNet: Confusion Matrix': c_matrix,
        'UNet: Report': report_unet
    })
    # Save as section
    section_data = {'time': time.time()-section_tstamp, 'stamp': section_tstamp}
    test.Section(section_name, section_data)
    
    # Print step data
    print("\n{} ({:02}) Complete.".format(section_name, len(test.sectionNames)))
    print('- Precision: {:.2f}%'.format(annoPrecision*100))
    print('- SourceDelta: {:.2f}%'.format((annoPrecision-sourcePrecision)*100))
    print('- StepDelta: {:.2f}%'.format((annoPrecision-prevPrecision)*100))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    print("----------------------------------\n\n")
    
    # Increase iterator and save previous precision for step_delta
    EM_iterator += 1
    prevPrecision = annoPrecision
# Out:
# Target Steps: 6
# True
#
#
# EM Step 00 begun.
# Thu at 02:12:08PM
#
# Generated Probability Output Map from previous model. (Step 00)
# Thu at 02:12:09PM
#
# Created New Annotation. (Step 00)
# Thu at 02:12:47PM
# /home/jiang-ws1/.virtualenvs/geo_errors/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# Created Y_train (1008, 224, 224, 1) and Y_val (60, 224, 224, 1). (Step 00)
# Thu at 02:12:50PM
#
# New Learning Rate: 0.100000. (Step 00)
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# 32/32 [==============================] - 7s 227ms/step - accuracy: 0.8602 - loss: -0.3679 - dice_coef: 0.3667 - f1_score: 0.3741 - val_accuracy: 0.0407 - val_loss: -0.0768 - val_dice_coef: 0.0754 - val_f1_score: 0.0754 - lr: 0.1000
# Epoch 2/50
# 32/32 [==============================] - 4s 123ms/step - accuracy: 0.8904 - loss: -0.4489 - dice_coef: 0.4476 - f1_score: 0.4479 - val_accuracy: 0.0407 - val_loss: -0.0768 - val_dice_coef: 0.0754 - val_f1_score: 0.0754 - lr: 0.1000
# Epoch 3/50
# 32/32 [==============================] - 5s 165ms/step - accuracy: 0.8888 - loss: -0.4555 - dice_coef: 0.4555 - f1_score: 0.4554 - val_accuracy: 0.0875 - val_loss: -0.0784 - val_dice_coef: 0.0770 - val_f1_score: 0.0770 - lr: 0.1000
# Epoch 4/50
# 32/32 [==============================] - 5s 165ms/step - accuracy: 0.8914 - loss: -0.4674 - dice_coef: 0.4677 - f1_score: 0.4676 - val_accuracy: 0.5464 - val_loss: -0.1170 - val_dice_coef: 0.1145 - val_f1_score: 0.1145 - lr: 0.1000
# Epoch 5/50
# 32/32 [==============================] - 4s 125ms/step - accuracy: 0.8911 - loss: -0.4665 - dice_coef: 0.4669 - f1_score: 0.4670 - val_accuracy: 0.1819 - val_loss: -0.0898 - val_dice_coef: 0.0882 - val_f1_score: 0.0882 - lr: 0.1000
# Epoch 6/50
# 32/32 [==============================] - 5s 169ms/step - accuracy: 0.8903 - loss: -0.4674 - dice_coef: 0.4676 - f1_score: 0.4675 - val_accuracy: 0.6072 - val_loss: -0.1310 - val_dice_coef: 0.1282 - val_f1_score: 0.1282 - lr: 0.1000
# Epoch 7/50
# 32/32 [==============================] - 5s 168ms/step - accuracy: 0.8931 - loss: -0.4806 - dice_coef: 0.4802 - f1_score: 0.4803 - val_accuracy: 0.8934 - val_loss: -0.2333 - val_dice_coef: 0.2500 - val_f1_score: 0.0000e+00 - lr: 0.1000
# Epoch 8/50
# 32/32 [==============================] - 5s 168ms/step - accuracy: 0.8931 - loss: -0.4709 - dice_coef: 0.4699 - f1_score: 0.4699 - val_accuracy: 0.8925 - val_loss: -0.4096 - val_dice_coef: 0.4227 - val_f1_score: 0.1725 - lr: 0.1000
# Epoch 9/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.8919 - loss: -0.4773 - dice_coef: 0.4761 - f1_score: 0.4761 - val_accuracy: 0.8348 - val_loss: -0.2606 - val_dice_coef: 0.2554 - val_f1_score: 0.2555 - lr: 0.1000
# Epoch 10/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8920 - loss: -0.4861 - dice_coef: 0.4854 - f1_score: 0.4850 - val_accuracy: 0.8906 - val_loss: -0.0192 - val_dice_coef: 0.0191 - val_f1_score: 0.0191 - lr: 0.1000
# Epoch 11/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8932 - loss: -0.4740 - dice_coef: 0.4734 - f1_score: 0.4732 - val_accuracy: 0.4286 - val_loss: -0.1064 - val_dice_coef: 0.1043 - val_f1_score: 0.1043 - lr: 0.1000
# Epoch 12/50
# 32/32 [==============================] - 5s 170ms/step - accuracy: 0.8905 - loss: -0.4627 - dice_coef: 0.4591 - f1_score: 0.4592 - val_accuracy: 0.8914 - val_loss: -0.5519 - val_dice_coef: 0.5622 - val_f1_score: 0.3122 - lr: 0.1000
# Epoch 13/50
# 32/32 [==============================] - 4s 125ms/step - accuracy: 0.8930 - loss: -0.4825 - dice_coef: 0.4812 - f1_score: 0.4812 - val_accuracy: 0.7565 - val_loss: -0.2089 - val_dice_coef: 0.2051 - val_f1_score: 0.2051 - lr: 0.1000
# Epoch 14/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8917 - loss: -0.4803 - dice_coef: 0.4780 - f1_score: 0.4782 - val_accuracy: 0.8648 - val_loss: -0.2892 - val_dice_coef: 0.2831 - val_f1_score: 0.2831 - lr: 0.1000
# Epoch 15/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8944 - loss: -0.4722 - dice_coef: 0.4717 - f1_score: 0.4717 - val_accuracy: 0.8902 - val_loss: -0.3173 - val_dice_coef: 0.3213 - val_f1_score: 0.1963 - lr: 0.1000
# Epoch 16/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8904 - loss: -0.4732 - dice_coef: 0.4748 - f1_score: 0.4747 - val_accuracy: 0.8941 - val_loss: -0.5321 - val_dice_coef: 0.5431 - val_f1_score: 0.2930 - lr: 0.1000
# Epoch 17/50
# 32/32 [==============================] - 5s 168ms/step - accuracy: 0.8953 - loss: -0.4929 - dice_coef: 0.4943 - f1_score: 0.4943 - val_accuracy: 0.8933 - val_loss: -0.5612 - val_dice_coef: 0.5712 - val_f1_score: 0.3212 - lr: 0.1000
# Epoch 18/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.8951 - loss: -0.4905 - dice_coef: 0.4881 - f1_score: 0.4882 - val_accuracy: 0.8667 - val_loss: -0.2861 - val_dice_coef: 0.2803 - val_f1_score: 0.2803 - lr: 0.1000
# Epoch 19/50
# 32/32 [==============================] - 4s 135ms/step - accuracy: 0.8946 - loss: -0.4841 - dice_coef: 0.4828 - f1_score: 0.4827 - val_accuracy: 0.8648 - val_loss: -0.2804 - val_dice_coef: 0.2745 - val_f1_score: 0.2745 - lr: 0.1000
# Epoch 20/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.8945 - loss: -0.4877 - dice_coef: 0.4884 - f1_score: 0.4882 - val_accuracy: 0.8882 - val_loss: -0.5566 - val_dice_coef: 0.5664 - val_f1_score: 0.3165 - lr: 0.1000
# Epoch 21/50
# 32/32 [==============================] - 5s 171ms/step - accuracy: 0.8936 - loss: -0.4881 - dice_coef: 0.4874 - f1_score: 0.4874 - val_accuracy: 0.8919 - val_loss: -0.5813 - val_dice_coef: 0.5906 - val_f1_score: 0.3406 - lr: 0.1000
# Epoch 22/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8934 - loss: -0.4855 - dice_coef: 0.4849 - f1_score: 0.4849 - val_accuracy: 0.8935 - val_loss: -0.2342 - val_dice_coef: 0.2508 - val_f1_score: 8.5115e-04 - lr: 0.1000
# Epoch 23/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8953 - loss: -0.4987 - dice_coef: 0.4987 - f1_score: 0.4987 - val_accuracy: 0.8934 - val_loss: -0.5608 - val_dice_coef: 0.5705 - val_f1_score: 0.3204 - lr: 0.1000
# Epoch 24/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8936 - loss: -0.4777 - dice_coef: 0.4784 - f1_score: 0.4785 - val_accuracy: 0.8912 - val_loss: -0.4412 - val_dice_coef: 0.4427 - val_f1_score: 0.3177 - lr: 0.1000
# Epoch 25/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8940 - loss: -0.4869 - dice_coef: 0.4869 - f1_score: 0.4869 - val_accuracy: 0.8938 - val_loss: -0.5493 - val_dice_coef: 0.5595 - val_f1_score: 0.3095 - lr: 0.1000
# Epoch 26/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8940 - loss: -0.5008 - dice_coef: 0.4998 - f1_score: 0.4995
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 32/32 [==============================] - 4s 133ms/step - accuracy: 0.8940 - loss: -0.5008 - dice_coef: 0.4998 - f1_score: 0.4995 - val_accuracy: 0.8925 - val_loss: -0.3939 - val_dice_coef: 0.4073 - val_f1_score: 0.1573 - lr: 0.1000
# Epoch 27/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8946 - loss: -0.5051 - dice_coef: 0.5006 - f1_score: 0.5006 - val_accuracy: 0.8925 - val_loss: -0.2941 - val_dice_coef: 0.3095 - val_f1_score: 0.0595 - lr: 0.0500
# Epoch 28/50
# 32/32 [==============================] - 4s 136ms/step - accuracy: 0.8938 - loss: -0.5015 - dice_coef: 0.4994 - f1_score: 0.4994 - val_accuracy: 0.8934 - val_loss: -0.4489 - val_dice_coef: 0.4612 - val_f1_score: 0.2111 - lr: 0.0500
# Epoch 29/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8975 - loss: -0.5187 - dice_coef: 0.5183 - f1_score: 0.5183 - val_accuracy: 0.8942 - val_loss: -0.3713 - val_dice_coef: 0.3850 - val_f1_score: 0.1350 - lr: 0.0500
# Epoch 30/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8956 - loss: -0.5118 - dice_coef: 0.5101 - f1_score: 0.5101 - val_accuracy: 0.8947 - val_loss: -0.4589 - val_dice_coef: 0.4706 - val_f1_score: 0.2207 - lr: 0.0500
# Epoch 31/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8971 - loss: -0.5165 - dice_coef: 0.5168 - f1_score: 0.5165
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8971 - loss: -0.5165 - dice_coef: 0.5168 - f1_score: 0.5165 - val_accuracy: 0.8932 - val_loss: -0.2802 - val_dice_coef: 0.2748 - val_f1_score: 0.2747 - lr: 0.0500
# Epoch 32/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8980 - loss: -0.5204 - dice_coef: 0.5216 - f1_score: 0.5213 - val_accuracy: 0.8946 - val_loss: -0.4892 - val_dice_coef: 0.5010 - val_f1_score: 0.2510 - lr: 0.0250
# Epoch 33/50
# 32/32 [==============================] - 4s 131ms/step - accuracy: 0.8989 - loss: -0.5180 - dice_coef: 0.5184 - f1_score: 0.5185 - val_accuracy: 0.8950 - val_loss: -0.4785 - val_dice_coef: 0.4903 - val_f1_score: 0.2403 - lr: 0.0250
# Epoch 34/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8986 - loss: -0.5262 - dice_coef: 0.5248 - f1_score: 0.5248 - val_accuracy: 0.8947 - val_loss: -0.3053 - val_dice_coef: 0.3210 - val_f1_score: 0.0710 - lr: 0.0250
# Epoch 35/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8973 - loss: -0.5193 - dice_coef: 0.5211 - f1_score: 0.5211 - val_accuracy: 0.8957 - val_loss: -0.4561 - val_dice_coef: 0.4682 - val_f1_score: 0.2182 - lr: 0.0250
# Epoch 36/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8978 - loss: -0.5223 - dice_coef: 0.5212 - f1_score: 0.5212
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8978 - loss: -0.5223 - dice_coef: 0.5212 - f1_score: 0.5212 - val_accuracy: 0.8936 - val_loss: -0.2443 - val_dice_coef: 0.2611 - val_f1_score: 0.0111 - lr: 0.0250
# Epoch 37/50
# 32/32 [==============================] - 4s 131ms/step - accuracy: 0.8966 - loss: -0.5225 - dice_coef: 0.5231 - f1_score: 0.5231 - val_accuracy: 0.8938 - val_loss: -0.2654 - val_dice_coef: 0.2817 - val_f1_score: 0.0318 - lr: 0.0125
# Epoch 38/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.8992 - loss: -0.5319 - dice_coef: 0.5317 - f1_score: 0.5317 - val_accuracy: 0.8948 - val_loss: -0.3905 - val_dice_coef: 0.4031 - val_f1_score: 0.1531 - lr: 0.0125
# Epoch 39/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8982 - loss: -0.5268 - dice_coef: 0.5263 - f1_score: 0.5268 - val_accuracy: 0.8947 - val_loss: -0.5280 - val_dice_coef: 0.5399 - val_f1_score: 0.2899 - lr: 0.0125
# Epoch 40/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8987 - loss: -0.5290 - dice_coef: 0.5288 - f1_score: 0.5290 - val_accuracy: 0.8938 - val_loss: -0.2712 - val_dice_coef: 0.2875 - val_f1_score: 0.0375 - lr: 0.0125
# Epoch 41/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.9002 - loss: -0.5322 - dice_coef: 0.5322 - f1_score: 0.5322
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.9002 - loss: -0.5322 - dice_coef: 0.5322 - f1_score: 0.5322 - val_accuracy: 0.8937 - val_loss: -0.2470 - val_dice_coef: 0.2638 - val_f1_score: 0.0138 - lr: 0.0125
#
# Completed UNet Training. (Step 00)
# Thu at 02:16:18PM
#
# Completed Unet Evaluation. (Step 00)
#
# Training Results (Step 00):
# - Dice Coef: 3.250%
# - F1 Score: 3.247%
#
# Validation Results (Step 00):
# - Dice Coef: 1.897%
# - F1 Score: 1.902%
#
# Testing Results (Step 00):
# - Dice Coef: 0.003%
# - F1 Score: 0.003%
# Thu at 02:16:26PM
# confusion_unet [[13718886        0]
#  [ 1333894       20]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95  13718886
#          1.0       1.00      0.00      0.00   1333914
#
#     accuracy                           0.91  15052800
#    macro avg       0.96      0.50      0.48  15052800
# weighted avg       0.92      0.91      0.87  15052800
#
#
# EM_Step 00 (03) Complete.
# - Precision: 26.41%
# - SourceDelta: 12.20%
# - StepDelta: 12.20%
# Thu at 02:17:37PM
# ----------------------------------
#
#
#
#
# EM Step 01 begun.
# Thu at 02:17:37PM
#
# Generated Probability Output Map from previous model. (Step 01)
# Thu at 02:17:38PM
#
# Created New Annotation. (Step 01)
# Thu at 02:18:17PM
#
# Created Y_train (1008, 224, 224, 1) and Y_val (60, 224, 224, 1). (Step 01)
# Thu at 02:18:19PM
#
# New Learning Rate: 0.100000. (Step 01)
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# 32/32 [==============================] - 7s 227ms/step - accuracy: 0.8291 - loss: -0.3125 - dice_coef: 0.3135 - f1_score: 0.3162 - val_accuracy: 0.0435 - val_loss: -0.0818 - val_dice_coef: 0.0803 - val_f1_score: 0.0803 - lr: 0.1000
# Epoch 2/50
# 32/32 [==============================] - 4s 122ms/step - accuracy: 0.8655 - loss: -0.3738 - dice_coef: 0.3724 - f1_score: 0.3724 - val_accuracy: 0.0435 - val_loss: -0.0818 - val_dice_coef: 0.0803 - val_f1_score: 0.0803 - lr: 0.1000
# Epoch 3/50
# 32/32 [==============================] - 5s 165ms/step - accuracy: 0.8703 - loss: -0.4057 - dice_coef: 0.4067 - f1_score: 0.4067 - val_accuracy: 0.0437 - val_loss: -0.0818 - val_dice_coef: 0.0803 - val_f1_score: 0.0803 - lr: 0.1000
# Epoch 4/50
# 32/32 [==============================] - 5s 166ms/step - accuracy: 0.8695 - loss: -0.3966 - dice_coef: 0.3961 - f1_score: 0.3961 - val_accuracy: 0.7397 - val_loss: -0.1225 - val_dice_coef: 0.1200 - val_f1_score: 0.1202 - lr: 0.1000
# Epoch 5/50
# 32/32 [==============================] - 4s 125ms/step - accuracy: 0.8698 - loss: -0.4026 - dice_coef: 0.4016 - f1_score: 0.4017 - val_accuracy: 0.8773 - val_loss: -2.0465e-10 - val_dice_coef: 2.1884e-10 - val_f1_score: 0.0000e+00 - lr: 0.1000
# Epoch 6/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8707 - loss: -0.4135 - dice_coef: 0.4095 - f1_score: 0.4096 - val_accuracy: 0.8575 - val_loss: -0.0014 - val_dice_coef: 0.0013 - val_f1_score: 0.0013 - lr: 0.1000
# Epoch 7/50
# 32/32 [==============================] - 4s 134ms/step - accuracy: 0.8749 - loss: -0.4187 - dice_coef: 0.4190 - f1_score: 0.4193 - val_accuracy: 0.8632 - val_loss: -1.2007e-11 - val_dice_coef: 1.1988e-11 - val_f1_score: 0.0000e+00 - lr: 0.1000
# Epoch 8/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.8737 - loss: -0.4160 - dice_coef: 0.4145 - f1_score: 0.4146 - val_accuracy: 0.8441 - val_loss: -0.0243 - val_dice_coef: 0.0237 - val_f1_score: 0.0235 - lr: 0.1000
# Epoch 9/50
# 32/32 [==============================] - 5s 168ms/step - accuracy: 0.8758 - loss: -0.4187 - dice_coef: 0.4189 - f1_score: 0.4190 - val_accuracy: 0.8634 - val_loss: -0.4347 - val_dice_coef: 0.4469 - val_f1_score: 0.1971 - lr: 0.1000
# Epoch 10/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8760 - loss: -0.4250 - dice_coef: 0.4247 - f1_score: 0.4247 - val_accuracy: 0.8754 - val_loss: -0.3931 - val_dice_coef: 0.4067 - val_f1_score: 0.1567 - lr: 0.1000
# Epoch 11/50
# 32/32 [==============================] - 4s 132ms/step - accuracy: 0.8776 - loss: -0.4389 - dice_coef: 0.4382 - f1_score: 0.4380 - val_accuracy: 0.8697 - val_loss: -0.2896 - val_dice_coef: 0.3047 - val_f1_score: 0.0547 - lr: 0.1000
# Epoch 12/50
# 32/32 [==============================] - 4s 139ms/step - accuracy: 0.8778 - loss: -0.4342 - dice_coef: 0.4316 - f1_score: 0.4319 - val_accuracy: 0.5613 - val_loss: -0.3604 - val_dice_coef: 0.3744 - val_f1_score: 0.1244 - lr: 0.1000
# Epoch 13/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8752 - loss: -0.4022 - dice_coef: 0.4033 - f1_score: 0.4031 - val_accuracy: 0.7028 - val_loss: -0.2808 - val_dice_coef: 0.2854 - val_f1_score: 0.1604 - lr: 0.1000
# Epoch 14/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8754 - loss: -0.4217 - dice_coef: 0.4198 - f1_score: 0.4199
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 32/32 [==============================] - 4s 131ms/step - accuracy: 0.8754 - loss: -0.4217 - dice_coef: 0.4198 - f1_score: 0.4199 - val_accuracy: 0.8743 - val_loss: -0.3151 - val_dice_coef: 0.3302 - val_f1_score: 0.0802 - lr: 0.1000
# Epoch 15/50
# 32/32 [==============================] - 5s 168ms/step - accuracy: 0.8789 - loss: -0.4484 - dice_coef: 0.4493 - f1_score: 0.4493 - val_accuracy: 0.8765 - val_loss: -0.4693 - val_dice_coef: 0.4808 - val_f1_score: 0.2308 - lr: 0.0500
# Epoch 16/50
# 32/32 [==============================] - 4s 133ms/step - accuracy: 0.8802 - loss: -0.4209 - dice_coef: 0.4202 - f1_score: 0.4205 - val_accuracy: 0.8706 - val_loss: -0.4160 - val_dice_coef: 0.4289 - val_f1_score: 0.1789 - lr: 0.0500
# Epoch 17/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8804 - loss: -0.4297 - dice_coef: 0.4302 - f1_score: 0.4303 - val_accuracy: 0.8686 - val_loss: -0.3340 - val_dice_coef: 0.3487 - val_f1_score: 0.0987 - lr: 0.0500
# Epoch 18/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8786 - loss: -0.4385 - dice_coef: 0.4370 - f1_score: 0.4369 - val_accuracy: 0.8664 - val_loss: -0.2658 - val_dice_coef: 0.2817 - val_f1_score: 0.0316 - lr: 0.0500
# Epoch 19/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8801 - loss: -0.4482 - dice_coef: 0.4483 - f1_score: 0.4483 - val_accuracy: 0.8699 - val_loss: -0.2333 - val_dice_coef: 0.2500 - val_f1_score: 0.0000e+00 - lr: 0.0500
# Epoch 20/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8821 - loss: -0.4555 - dice_coef: 0.4540 - f1_score: 0.4541
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 32/32 [==============================] - 4s 133ms/step - accuracy: 0.8821 - loss: -0.4555 - dice_coef: 0.4540 - f1_score: 0.4541 - val_accuracy: 0.8254 - val_loss: -0.4369 - val_dice_coef: 0.4494 - val_f1_score: 0.1993 - lr: 0.0500
# Epoch 21/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.8816 - loss: -0.4610 - dice_coef: 0.4591 - f1_score: 0.4592 - val_accuracy: 0.8577 - val_loss: -0.3640 - val_dice_coef: 0.3779 - val_f1_score: 0.1279 - lr: 0.0250
# Epoch 22/50
# 32/32 [==============================] - 4s 133ms/step - accuracy: 0.8829 - loss: -0.4703 - dice_coef: 0.4687 - f1_score: 0.4691 - val_accuracy: 0.8661 - val_loss: -0.3254 - val_dice_coef: 0.3400 - val_f1_score: 0.0900 - lr: 0.0250
# Epoch 23/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8834 - loss: -0.4746 - dice_coef: 0.4756 - f1_score: 0.4756 - val_accuracy: 0.8680 - val_loss: -0.3041 - val_dice_coef: 0.3192 - val_f1_score: 0.0691 - lr: 0.0250
# Epoch 24/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8833 - loss: -0.4799 - dice_coef: 0.4771 - f1_score: 0.4771 - val_accuracy: 0.8683 - val_loss: -0.2956 - val_dice_coef: 0.3111 - val_f1_score: 0.0611 - lr: 0.0250
# Epoch 25/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8864 - loss: -0.4947 - dice_coef: 0.4958 - f1_score: 0.4958
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8864 - loss: -0.4947 - dice_coef: 0.4958 - f1_score: 0.4958 - val_accuracy: 0.8692 - val_loss: -0.2423 - val_dice_coef: 0.2587 - val_f1_score: 0.0087 - lr: 0.0250
# Epoch 26/50
# 32/32 [==============================] - 4s 132ms/step - accuracy: 0.8854 - loss: -0.4863 - dice_coef: 0.4837 - f1_score: 0.4837 - val_accuracy: 0.8647 - val_loss: -0.3334 - val_dice_coef: 0.3476 - val_f1_score: 0.0976 - lr: 0.0125
# Epoch 27/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8856 - loss: -0.4976 - dice_coef: 0.4979 - f1_score: 0.4981 - val_accuracy: 0.8586 - val_loss: -0.3725 - val_dice_coef: 0.3857 - val_f1_score: 0.1357 - lr: 0.0125
# Epoch 28/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8867 - loss: -0.4951 - dice_coef: 0.4947 - f1_score: 0.4947 - val_accuracy: 0.8667 - val_loss: -0.3090 - val_dice_coef: 0.3239 - val_f1_score: 0.0740 - lr: 0.0125
# Epoch 29/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8858 - loss: -0.5025 - dice_coef: 0.5010 - f1_score: 0.5010 - val_accuracy: 0.8646 - val_loss: -0.3401 - val_dice_coef: 0.3546 - val_f1_score: 0.1046 - lr: 0.0125
# Epoch 30/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8854 - loss: -0.4991 - dice_coef: 0.4980 - f1_score: 0.4980
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 32/32 [==============================] - 4s 136ms/step - accuracy: 0.8854 - loss: -0.4991 - dice_coef: 0.4980 - f1_score: 0.4980 - val_accuracy: 0.8617 - val_loss: -0.3705 - val_dice_coef: 0.3839 - val_f1_score: 0.1339 - lr: 0.0125
# Epoch 31/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8872 - loss: -0.5033 - dice_coef: 0.5045 - f1_score: 0.5045 - val_accuracy: 0.8635 - val_loss: -0.3564 - val_dice_coef: 0.3702 - val_f1_score: 0.1202 - lr: 0.0063
# Epoch 32/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8870 - loss: -0.5010 - dice_coef: 0.5006 - f1_score: 0.5009 - val_accuracy: 0.8635 - val_loss: -0.3551 - val_dice_coef: 0.3689 - val_f1_score: 0.1189 - lr: 0.0063
# Epoch 33/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8860 - loss: -0.5056 - dice_coef: 0.5056 - f1_score: 0.5068 - val_accuracy: 0.8649 - val_loss: -0.3346 - val_dice_coef: 0.3493 - val_f1_score: 0.0993 - lr: 0.0063
# Epoch 34/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8867 - loss: -0.5057 - dice_coef: 0.5025 - f1_score: 0.5025 - val_accuracy: 0.8626 - val_loss: -0.4033 - val_dice_coef: 0.4159 - val_f1_score: 0.1659 - lr: 0.0063
# Epoch 35/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8869 - loss: -0.5098 - dice_coef: 0.5103 - f1_score: 0.5104
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 32/32 [==============================] - 4s 129ms/step - accuracy: 0.8869 - loss: -0.5098 - dice_coef: 0.5103 - f1_score: 0.5104 - val_accuracy: 0.8636 - val_loss: -0.3852 - val_dice_coef: 0.3985 - val_f1_score: 0.1485 - lr: 0.0063
#
# Completed UNet Training. (Step 01)
# Thu at 02:21:17PM
#
# Completed Unet Evaluation. (Step 01)
#
# Training Results (Step 01):
# - Dice Coef: 47.751%
# - F1 Score: 47.752%
#
# Validation Results (Step 01):
# - Dice Coef: 19.607%
# - F1 Score: 19.607%
#
# Testing Results (Step 01):
# - Dice Coef: 64.453%
# - F1 Score: 64.453%
# Thu at 02:21:25PM
# confusion_unet [[13455426   263460]
#  [  574354   759560]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97  13718886
#          1.0       0.74      0.57      0.64   1333914
#
#     accuracy                           0.94  15052800
#    macro avg       0.85      0.78      0.81  15052800
# weighted avg       0.94      0.94      0.94  15052800
#
#
# EM_Step 01 (04) Complete.
# - Precision: 17.80%
# - SourceDelta: 3.60%
# - StepDelta: -8.61%
# Thu at 02:22:36PM
# ----------------------------------
#
#
#
#
# EM Step 02 begun.
# Thu at 02:22:36PM
#
# Generated Probability Output Map from previous model. (Step 02)
# Thu at 02:22:38PM
#
# Created New Annotation. (Step 02)
# Thu at 02:23:16PM
#
# Created Y_train (1008, 224, 224, 1) and Y_val (60, 224, 224, 1). (Step 02)
# Thu at 02:23:19PM
#
# New Learning Rate: 0.100000. (Step 02)
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# 32/32 [==============================] - 8s 236ms/step - accuracy: 0.8184 - loss: -0.3544 - dice_coef: 0.3566 - f1_score: 0.3623 - val_accuracy: 0.0412 - val_loss: -0.0777 - val_dice_coef: 0.0763 - val_f1_score: 0.0763 - lr: 0.1000
# Epoch 2/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8925 - loss: -0.4891 - dice_coef: 0.4900 - f1_score: 0.4901 - val_accuracy: 0.0412 - val_loss: -0.0777 - val_dice_coef: 0.0763 - val_f1_score: 0.0763 - lr: 0.1000
# Epoch 3/50
# 32/32 [==============================] - 5s 169ms/step - accuracy: 0.8939 - loss: -0.5070 - dice_coef: 0.5064 - f1_score: 0.5065 - val_accuracy: 0.0412 - val_loss: -0.0777 - val_dice_coef: 0.0763 - val_f1_score: 0.0763 - lr: 0.1000
# Epoch 4/50
# 32/32 [==============================] - 5s 171ms/step - accuracy: 0.8933 - loss: -0.5133 - dice_coef: 0.5128 - f1_score: 0.5130 - val_accuracy: 0.3349 - val_loss: -0.0892 - val_dice_coef: 0.0874 - val_f1_score: 0.0874 - lr: 0.1000
# Epoch 5/50
# 32/32 [==============================] - 5s 170ms/step - accuracy: 0.8961 - loss: -0.5320 - dice_coef: 0.5313 - f1_score: 0.5315 - val_accuracy: 0.5624 - val_loss: -0.1210 - val_dice_coef: 0.1183 - val_f1_score: 0.1183 - lr: 0.1000
# Epoch 6/50
# 32/32 [==============================] - 5s 170ms/step - accuracy: 0.8950 - loss: -0.5252 - dice_coef: 0.5234 - f1_score: 0.5233 - val_accuracy: 0.8943 - val_loss: -0.2333 - val_dice_coef: 0.2500 - val_f1_score: 0.0000e+00 - lr: 0.1000
# Epoch 7/50
# 32/32 [==============================] - 5s 169ms/step - accuracy: 0.8984 - loss: -0.5393 - dice_coef: 0.5374 - f1_score: 0.5377 - val_accuracy: 0.8941 - val_loss: -0.2369 - val_dice_coef: 0.2533 - val_f1_score: 0.0033 - lr: 0.1000
# Epoch 8/50
# 32/32 [==============================] - 4s 131ms/step - accuracy: 0.8988 - loss: -0.5500 - dice_coef: 0.5507 - f1_score: 0.5508 - val_accuracy: 0.8942 - val_loss: -0.1167 - val_dice_coef: 0.1250 - val_f1_score: 0.0000e+00 - lr: 0.1000
# Epoch 9/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8996 - loss: -0.5581 - dice_coef: 0.5536 - f1_score: 0.5536 - val_accuracy: 0.8943 - val_loss: -0.2333 - val_dice_coef: 0.2500 - val_f1_score: 0.0000e+00 - lr: 0.1000
# Epoch 10/50
# 32/32 [==============================] - 5s 169ms/step - accuracy: 0.9010 - loss: -0.5697 - dice_coef: 0.5676 - f1_score: 0.5676 - val_accuracy: 0.8964 - val_loss: -0.3290 - val_dice_coef: 0.3443 - val_f1_score: 0.0944 - lr: 0.1000
# Epoch 11/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9010 - loss: -0.5654 - dice_coef: 0.5631 - f1_score: 0.5632 - val_accuracy: 0.2629 - val_loss: -0.0940 - val_dice_coef: 0.0923 - val_f1_score: 0.0923 - lr: 0.1000
# Epoch 12/50
# 32/32 [==============================] - 5s 169ms/step - accuracy: 0.8992 - loss: -0.5574 - dice_coef: 0.5568 - f1_score: 0.5568 - val_accuracy: 0.8996 - val_loss: -0.4379 - val_dice_coef: 0.4505 - val_f1_score: 0.2006 - lr: 0.1000
# Epoch 13/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8998 - loss: -0.5728 - dice_coef: 0.5732 - f1_score: 0.5732 - val_accuracy: 0.8880 - val_loss: -0.1976 - val_dice_coef: 0.1910 - val_f1_score: 0.1910 - lr: 0.1000
# Epoch 14/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8977 - loss: -0.5325 - dice_coef: 0.5318 - f1_score: 0.5324 - val_accuracy: 0.4422 - val_loss: -0.1018 - val_dice_coef: 0.0997 - val_f1_score: 0.0997 - lr: 0.1000
# Epoch 15/50
# 32/32 [==============================] - 4s 129ms/step - accuracy: 0.8933 - loss: -0.5040 - dice_coef: 0.5034 - f1_score: 0.5034 - val_accuracy: 0.6297 - val_loss: -0.1430 - val_dice_coef: 0.1401 - val_f1_score: 0.1400 - lr: 0.1000
# Epoch 16/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8986 - loss: -0.5412 - dice_coef: 0.5416 - f1_score: 0.5417 - val_accuracy: 0.6140 - val_loss: -0.1391 - val_dice_coef: 0.1360 - val_f1_score: 0.1360 - lr: 0.1000
# Epoch 17/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8995 - loss: -0.5563 - dice_coef: 0.5535 - f1_score: 0.5540
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8995 - loss: -0.5563 - dice_coef: 0.5535 - f1_score: 0.5540 - val_accuracy: 0.8821 - val_loss: -0.3316 - val_dice_coef: 0.3374 - val_f1_score: 0.2124 - lr: 0.1000
# Epoch 18/50
# 32/32 [==============================] - 4s 133ms/step - accuracy: 0.9014 - loss: -0.5694 - dice_coef: 0.5699 - f1_score: 0.5699 - val_accuracy: 0.8943 - val_loss: -0.2333 - val_dice_coef: 0.2500 - val_f1_score: 0.0000e+00 - lr: 0.0500
# Epoch 19/50
# 32/32 [==============================] - 4s 132ms/step - accuracy: 0.9015 - loss: -0.5753 - dice_coef: 0.5747 - f1_score: 0.5747 - val_accuracy: 0.8943 - val_loss: -0.2335 - val_dice_coef: 0.2502 - val_f1_score: 2.2378e-04 - lr: 0.0500
# Epoch 20/50
# 32/32 [==============================] - 4s 129ms/step - accuracy: 0.9029 - loss: -0.5821 - dice_coef: 0.5829 - f1_score: 0.5829 - val_accuracy: 0.8943 - val_loss: -0.2333 - val_dice_coef: 0.2500 - val_f1_score: 0.0000e+00 - lr: 0.0500
# Epoch 21/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.9032 - loss: -0.5814 - dice_coef: 0.5817 - f1_score: 0.5817 - val_accuracy: 0.8943 - val_loss: -0.2333 - val_dice_coef: 0.2500 - val_f1_score: 0.0000e+00 - lr: 0.0500
# Epoch 22/50
# 32/32 [==============================] - 6s 177ms/step - accuracy: 0.9045 - loss: -0.6037 - dice_coef: 0.6032 - f1_score: 0.6032 - val_accuracy: 0.8997 - val_loss: -0.4513 - val_dice_coef: 0.4635 - val_f1_score: 0.2134 - lr: 0.0500
# Epoch 23/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9036 - loss: -0.5968 - dice_coef: 0.5969 - f1_score: 0.5964 - val_accuracy: 0.8943 - val_loss: -0.2333 - val_dice_coef: 0.2500 - val_f1_score: 0.0000e+00 - lr: 0.0500
# Epoch 24/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.9035 - loss: -0.5837 - dice_coef: 0.5835 - f1_score: 0.5835 - val_accuracy: 0.8961 - val_loss: -0.3012 - val_dice_coef: 0.3167 - val_f1_score: 0.0667 - lr: 0.0500
# Epoch 25/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.9041 - loss: -0.5996 - dice_coef: 0.5946 - f1_score: 0.5947 - val_accuracy: 0.8955 - val_loss: -0.2784 - val_dice_coef: 0.2945 - val_f1_score: 0.0445 - lr: 0.0500
# Epoch 26/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.9025 - loss: -0.5838 - dice_coef: 0.5809 - f1_score: 0.5817 - val_accuracy: 0.8943 - val_loss: -0.2344 - val_dice_coef: 0.2510 - val_f1_score: 0.0010 - lr: 0.0500
# Epoch 27/50
# 32/32 [==============================] - 6s 172ms/step - accuracy: 0.9047 - loss: -0.5976 - dice_coef: 0.5982 - f1_score: 0.5982 - val_accuracy: 0.9008 - val_loss: -0.4980 - val_dice_coef: 0.5088 - val_f1_score: 0.2589 - lr: 0.0500
# Epoch 28/50
# 32/32 [==============================] - 5s 166ms/step - accuracy: 0.9051 - loss: -0.6024 - dice_coef: 0.6006 - f1_score: 0.6006 - val_accuracy: 0.9025 - val_loss: -0.5607 - val_dice_coef: 0.5697 - val_f1_score: 0.3197 - lr: 0.0500
# Epoch 29/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.9055 - loss: -0.6187 - dice_coef: 0.6188 - f1_score: 0.6188 - val_accuracy: 0.8952 - val_loss: -0.2718 - val_dice_coef: 0.2880 - val_f1_score: 0.0380 - lr: 0.0500
# Epoch 30/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9062 - loss: -0.6226 - dice_coef: 0.6213 - f1_score: 0.6214 - val_accuracy: 0.8960 - val_loss: -0.3031 - val_dice_coef: 0.3184 - val_f1_score: 0.0684 - lr: 0.0500
# Epoch 31/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.9064 - loss: -0.6224 - dice_coef: 0.6241 - f1_score: 0.6241 - val_accuracy: 0.8987 - val_loss: -0.4988 - val_dice_coef: 0.4986 - val_f1_score: 0.3736 - lr: 0.0500
# Epoch 32/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.9057 - loss: -0.6191 - dice_coef: 0.6186 - f1_score: 0.6191 - val_accuracy: 0.8973 - val_loss: -0.3697 - val_dice_coef: 0.3837 - val_f1_score: 0.1337 - lr: 0.0500
# Epoch 33/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.9065 - loss: -0.6297 - dice_coef: 0.6295 - f1_score: 0.6295
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.9065 - loss: -0.6297 - dice_coef: 0.6295 - f1_score: 0.6295 - val_accuracy: 0.9005 - val_loss: -0.4975 - val_dice_coef: 0.5082 - val_f1_score: 0.2582 - lr: 0.0500
# Epoch 34/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.9068 - loss: -0.6258 - dice_coef: 0.6266 - f1_score: 0.6263 - val_accuracy: 0.8980 - val_loss: -0.3993 - val_dice_coef: 0.4128 - val_f1_score: 0.1627 - lr: 0.0250
# Epoch 35/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.9075 - loss: -0.6419 - dice_coef: 0.6401 - f1_score: 0.6401 - val_accuracy: 0.8967 - val_loss: -0.3645 - val_dice_coef: 0.3783 - val_f1_score: 0.1283 - lr: 0.0250
# Epoch 36/50
# 32/32 [==============================] - 4s 130ms/step - accuracy: 0.9078 - loss: -0.6436 - dice_coef: 0.6430 - f1_score: 0.6430 - val_accuracy: 0.8971 - val_loss: -0.3793 - val_dice_coef: 0.3928 - val_f1_score: 0.1428 - lr: 0.0250
# Epoch 37/50
# 32/32 [==============================] - 4s 132ms/step - accuracy: 0.9072 - loss: -0.6349 - dice_coef: 0.6331 - f1_score: 0.6331 - val_accuracy: 0.8961 - val_loss: -0.3358 - val_dice_coef: 0.3506 - val_f1_score: 0.1006 - lr: 0.0250
# Epoch 38/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.9071 - loss: -0.6318 - dice_coef: 0.6318 - f1_score: 0.6319
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.9071 - loss: -0.6318 - dice_coef: 0.6318 - f1_score: 0.6319 - val_accuracy: 0.8976 - val_loss: -0.4129 - val_dice_coef: 0.4255 - val_f1_score: 0.1754 - lr: 0.0250
# Epoch 39/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.9080 - loss: -0.6437 - dice_coef: 0.6436 - f1_score: 0.6436 - val_accuracy: 0.8967 - val_loss: -0.3546 - val_dice_coef: 0.3687 - val_f1_score: 0.1187 - lr: 0.0125
# Epoch 40/50
# 32/32 [==============================] - 4s 131ms/step - accuracy: 0.9081 - loss: -0.6505 - dice_coef: 0.6508 - f1_score: 0.6508 - val_accuracy: 0.8977 - val_loss: -0.3909 - val_dice_coef: 0.4041 - val_f1_score: 0.1541 - lr: 0.0125
# Epoch 41/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.9086 - loss: -0.6545 - dice_coef: 0.6534 - f1_score: 0.6534 - val_accuracy: 0.8974 - val_loss: -0.3854 - val_dice_coef: 0.3985 - val_f1_score: 0.1485 - lr: 0.0125
# Epoch 42/50
# 32/32 [==============================] - 4s 130ms/step - accuracy: 0.9088 - loss: -0.6578 - dice_coef: 0.6577 - f1_score: 0.6577 - val_accuracy: 0.8980 - val_loss: -0.4076 - val_dice_coef: 0.4200 - val_f1_score: 0.1700 - lr: 0.0125
# Epoch 43/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.9088 - loss: -0.6531 - dice_coef: 0.6520 - f1_score: 0.6520
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 32/32 [==============================] - 5s 144ms/step - accuracy: 0.9088 - loss: -0.6531 - dice_coef: 0.6520 - f1_score: 0.6520 - val_accuracy: 0.8959 - val_loss: -0.3160 - val_dice_coef: 0.3312 - val_f1_score: 0.0811 - lr: 0.0125
# Epoch 44/50
# 32/32 [==============================] - 4s 124ms/step - accuracy: 0.9088 - loss: -0.6629 - dice_coef: 0.6635 - f1_score: 0.6635 - val_accuracy: 0.8981 - val_loss: -0.3931 - val_dice_coef: 0.4061 - val_f1_score: 0.1560 - lr: 0.0063
# Epoch 45/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9095 - loss: -0.6704 - dice_coef: 0.6704 - f1_score: 0.6703 - val_accuracy: 0.8985 - val_loss: -0.4187 - val_dice_coef: 0.4309 - val_f1_score: 0.1809 - lr: 0.0063
# Epoch 46/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9097 - loss: -0.6712 - dice_coef: 0.6703 - f1_score: 0.6703 - val_accuracy: 0.8992 - val_loss: -0.4520 - val_dice_coef: 0.4632 - val_f1_score: 0.2132 - lr: 0.0063
# Epoch 47/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9086 - loss: -0.6597 - dice_coef: 0.6605 - f1_score: 0.6610 - val_accuracy: 0.8996 - val_loss: -0.4646 - val_dice_coef: 0.4759 - val_f1_score: 0.2258 - lr: 0.0063
# Epoch 48/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.9085 - loss: -0.6631 - dice_coef: 0.6631 - f1_score: 0.6631
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.9085 - loss: -0.6631 - dice_coef: 0.6631 - f1_score: 0.6631 - val_accuracy: 0.8991 - val_loss: -0.4218 - val_dice_coef: 0.4338 - val_f1_score: 0.1838 - lr: 0.0063
#
# Completed UNet Training. (Step 02)
# Thu at 02:27:21PM
#
# Completed Unet Evaluation. (Step 02)
#
# Training Results (Step 02):
# - Dice Coef: 40.873%
# - F1 Score: 40.871%
#
# Validation Results (Step 02):
# - Dice Coef: 26.101%
# - F1 Score: 26.108%
#
# Testing Results (Step 02):
# - Dice Coef: 42.940%
# - F1 Score: 42.944%
# Thu at 02:27:30PM
# confusion_unet [[13669688    49198]
#  [  955732   378182]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.96  13718886
#          1.0       0.88      0.28      0.43   1333914
#
#     accuracy                           0.93  15052800
#    macro avg       0.91      0.64      0.70  15052800
# weighted avg       0.93      0.93      0.92  15052800
#
#
# EM_Step 02 (05) Complete.
# - Precision: 24.34%
# - SourceDelta: 10.13%
# - StepDelta: 6.53%
# Thu at 02:28:40PM
# ----------------------------------
#
#
#
#
# EM Step 03 begun.
# Thu at 02:28:40PM
#
# Generated Probability Output Map from previous model. (Step 03)
# Thu at 02:28:41PM
#
# Created New Annotation. (Step 03)
# Thu at 02:29:20PM
#
# Created Y_train (1008, 224, 224, 1) and Y_val (60, 224, 224, 1). (Step 03)
# Thu at 02:29:23PM
#
# New Learning Rate: 0.100000. (Step 03)
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 90 all-reduces with algorithm = nccl, num_packs = 1
# 32/32 [==============================] - 7s 225ms/step - accuracy: 0.8112 - loss: -0.3475 - dice_coef: 0.3478 - f1_score: 0.3575 - val_accuracy: 0.0412 - val_loss: -0.0777 - val_dice_coef: 0.0763 - val_f1_score: 0.0763 - lr: 0.1000
# Epoch 2/50
# 32/32 [==============================] - 4s 123ms/step - accuracy: 0.8828 - loss: -0.4477 - dice_coef: 0.4477 - f1_score: 0.4479 - val_accuracy: 0.0412 - val_loss: -0.0777 - val_dice_coef: 0.0763 - val_f1_score: 0.0763 - lr: 0.1000
# Epoch 3/50
# 32/32 [==============================] - 5s 161ms/step - accuracy: 0.8842 - loss: -0.4487 - dice_coef: 0.4492 - f1_score: 0.4494 - val_accuracy: 0.0412 - val_loss: -0.0777 - val_dice_coef: 0.0763 - val_f1_score: 0.0763 - lr: 0.1000
# Epoch 4/50
# 32/32 [==============================] - 5s 162ms/step - accuracy: 0.8848 - loss: -0.4561 - dice_coef: 0.4544 - f1_score: 0.4567 - val_accuracy: 0.5742 - val_loss: -0.1233 - val_dice_coef: 0.1207 - val_f1_score: 0.1207 - lr: 0.1000
# Epoch 5/50
# 32/32 [==============================] - 4s 125ms/step - accuracy: 0.8862 - loss: -0.4675 - dice_coef: 0.4677 - f1_score: 0.4678 - val_accuracy: 0.0761 - val_loss: -0.0787 - val_dice_coef: 0.0773 - val_f1_score: 0.0773 - lr: 0.1000
# Epoch 6/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8859 - loss: -0.4632 - dice_coef: 0.4638 - f1_score: 0.4648 - val_accuracy: 0.3188 - val_loss: -0.0874 - val_dice_coef: 0.0858 - val_f1_score: 0.0858 - lr: 0.1000
# Epoch 7/50
# 32/32 [==============================] - 5s 169ms/step - accuracy: 0.8871 - loss: -0.4570 - dice_coef: 0.4582 - f1_score: 0.4591 - val_accuracy: 0.8297 - val_loss: -0.3131 - val_dice_coef: 0.3275 - val_f1_score: 0.0775 - lr: 0.1000
# Epoch 8/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8923 - loss: -0.4985 - dice_coef: 0.4974 - f1_score: 0.4974 - val_accuracy: 0.8887 - val_loss: -0.2336 - val_dice_coef: 0.2503 - val_f1_score: 3.1618e-04 - lr: 0.1000
# Epoch 9/50
# 32/32 [==============================] - 4s 132ms/step - accuracy: 0.8923 - loss: -0.5076 - dice_coef: 0.5076 - f1_score: 0.5078 - val_accuracy: 0.8901 - val_loss: -0.2534 - val_dice_coef: 0.2699 - val_f1_score: 0.0198 - lr: 0.1000
# Epoch 10/50
# 32/32 [==============================] - 4s 132ms/step - accuracy: 0.8925 - loss: -0.5136 - dice_coef: 0.5126 - f1_score: 0.5126 - val_accuracy: 0.8903 - val_loss: -0.2581 - val_dice_coef: 0.2754 - val_f1_score: 0.0254 - lr: 0.1000
# Epoch 11/50
# 32/32 [==============================] - 5s 166ms/step - accuracy: 0.8929 - loss: -0.5182 - dice_coef: 0.5180 - f1_score: 0.5188 - val_accuracy: 0.6095 - val_loss: -0.3651 - val_dice_coef: 0.3789 - val_f1_score: 0.1289 - lr: 0.1000
# Epoch 12/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.8813 - loss: -0.4230 - dice_coef: 0.4209 - f1_score: 0.4209 - val_accuracy: 0.0886 - val_loss: -0.0788 - val_dice_coef: 0.0774 - val_f1_score: 0.0774 - lr: 0.1000
# Epoch 13/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8893 - loss: -0.4873 - dice_coef: 0.4884 - f1_score: 0.4884 - val_accuracy: 0.8903 - val_loss: -0.3038 - val_dice_coef: 0.3190 - val_f1_score: 0.0691 - lr: 0.1000
# Epoch 14/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8918 - loss: -0.4998 - dice_coef: 0.5014 - f1_score: 0.5020 - val_accuracy: 0.8907 - val_loss: -0.3546 - val_dice_coef: 0.3690 - val_f1_score: 0.1190 - lr: 0.1000
# Epoch 15/50
# 32/32 [==============================] - 5s 171ms/step - accuracy: 0.8927 - loss: -0.5056 - dice_coef: 0.5056 - f1_score: 0.5060 - val_accuracy: 0.8917 - val_loss: -0.5593 - val_dice_coef: 0.5690 - val_f1_score: 0.3189 - lr: 0.1000
# Epoch 16/50
# 32/32 [==============================] - 5s 165ms/step - accuracy: 0.8925 - loss: -0.5066 - dice_coef: 0.5055 - f1_score: 0.5062 - val_accuracy: 0.8918 - val_loss: -0.5912 - val_dice_coef: 0.6000 - val_f1_score: 0.3500 - lr: 0.1000
# Epoch 17/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.8949 - loss: -0.5196 - dice_coef: 0.5202 - f1_score: 0.5203 - val_accuracy: 0.8934 - val_loss: -0.5578 - val_dice_coef: 0.5677 - val_f1_score: 0.3176 - lr: 0.1000
# Epoch 18/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8934 - loss: -0.5197 - dice_coef: 0.5208 - f1_score: 0.5208 - val_accuracy: 0.8946 - val_loss: -0.5656 - val_dice_coef: 0.5752 - val_f1_score: 0.3252 - lr: 0.1000
# Epoch 19/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8952 - loss: -0.5307 - dice_coef: 0.5283 - f1_score: 0.5283 - val_accuracy: 0.8960 - val_loss: -0.5421 - val_dice_coef: 0.5525 - val_f1_score: 0.3025 - lr: 0.1000
# Epoch 20/50
# 32/32 [==============================] - 4s 132ms/step - accuracy: 0.8952 - loss: -0.5387 - dice_coef: 0.5388 - f1_score: 0.5388 - val_accuracy: 0.8965 - val_loss: -0.5477 - val_dice_coef: 0.5577 - val_f1_score: 0.3077 - lr: 0.1000
# Epoch 21/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8957 - loss: -0.5396 - dice_coef: 0.5396 - f1_score: 0.5397
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8957 - loss: -0.5396 - dice_coef: 0.5396 - f1_score: 0.5397 - val_accuracy: 0.8969 - val_loss: -0.5454 - val_dice_coef: 0.5558 - val_f1_score: 0.3058 - lr: 0.1000
# Epoch 22/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8951 - loss: -0.5359 - dice_coef: 0.5356 - f1_score: 0.5359 - val_accuracy: 0.8913 - val_loss: -0.2995 - val_dice_coef: 0.3153 - val_f1_score: 0.0654 - lr: 0.0500
# Epoch 23/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8960 - loss: -0.5439 - dice_coef: 0.5446 - f1_score: 0.5446 - val_accuracy: 0.8971 - val_loss: -0.5420 - val_dice_coef: 0.5522 - val_f1_score: 0.3023 - lr: 0.0500
# Epoch 24/50
# 32/32 [==============================] - 4s 131ms/step - accuracy: 0.8954 - loss: -0.5496 - dice_coef: 0.5507 - f1_score: 0.5507 - val_accuracy: 0.8980 - val_loss: -0.5657 - val_dice_coef: 0.5756 - val_f1_score: 0.3256 - lr: 0.0500
# Epoch 25/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8903 - loss: -0.5014 - dice_coef: 0.4989 - f1_score: 0.5004 - val_accuracy: 0.8589 - val_loss: -0.2797 - val_dice_coef: 0.2731 - val_f1_score: 0.2733 - lr: 0.0500
# Epoch 26/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8897 - loss: -0.4950 - dice_coef: 0.4943 - f1_score: 0.4944
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8897 - loss: -0.4950 - dice_coef: 0.4943 - f1_score: 0.4944 - val_accuracy: 0.8424 - val_loss: -0.2358 - val_dice_coef: 0.2303 - val_f1_score: 0.2304 - lr: 0.0500
# Epoch 27/50
# 32/32 [==============================] - 5s 169ms/step - accuracy: 0.8963 - loss: -0.5422 - dice_coef: 0.5420 - f1_score: 0.5420 - val_accuracy: 0.8887 - val_loss: -0.6028 - val_dice_coef: 0.6114 - val_f1_score: 0.3614 - lr: 0.0250
# Epoch 28/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8966 - loss: -0.5440 - dice_coef: 0.5419 - f1_score: 0.5419 - val_accuracy: 0.8956 - val_loss: -0.5207 - val_dice_coef: 0.5315 - val_f1_score: 0.2815 - lr: 0.0250
# Epoch 29/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.8967 - loss: -0.5423 - dice_coef: 0.5402 - f1_score: 0.5402 - val_accuracy: 0.8925 - val_loss: -0.3410 - val_dice_coef: 0.3564 - val_f1_score: 0.1063 - lr: 0.0250
# Epoch 30/50
# 32/32 [==============================] - 4s 130ms/step - accuracy: 0.8968 - loss: -0.5466 - dice_coef: 0.5444 - f1_score: 0.5444 - val_accuracy: 0.8959 - val_loss: -0.4988 - val_dice_coef: 0.5103 - val_f1_score: 0.2603 - lr: 0.0250
# Epoch 31/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8971 - loss: -0.5486 - dice_coef: 0.5483 - f1_score: 0.5483 - val_accuracy: 0.8970 - val_loss: -0.5241 - val_dice_coef: 0.5350 - val_f1_score: 0.2849 - lr: 0.0250
# Epoch 32/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8972 - loss: -0.5525 - dice_coef: 0.5522 - f1_score: 0.5522
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8972 - loss: -0.5525 - dice_coef: 0.5522 - f1_score: 0.5522 - val_accuracy: 0.8950 - val_loss: -0.4565 - val_dice_coef: 0.4691 - val_f1_score: 0.2191 - lr: 0.0250
# Epoch 33/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8971 - loss: -0.5541 - dice_coef: 0.5553 - f1_score: 0.5553 - val_accuracy: 0.8937 - val_loss: -0.3867 - val_dice_coef: 0.4011 - val_f1_score: 0.1511 - lr: 0.0125
# Epoch 34/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8978 - loss: -0.5604 - dice_coef: 0.5610 - f1_score: 0.5610 - val_accuracy: 0.8953 - val_loss: -0.4467 - val_dice_coef: 0.4599 - val_f1_score: 0.2099 - lr: 0.0125
# Epoch 35/50
# 32/32 [==============================] - 4s 133ms/step - accuracy: 0.8972 - loss: -0.5580 - dice_coef: 0.5586 - f1_score: 0.5587 - val_accuracy: 0.8969 - val_loss: -0.5046 - val_dice_coef: 0.5161 - val_f1_score: 0.2660 - lr: 0.0125
# Epoch 36/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.8979 - loss: -0.5590 - dice_coef: 0.5591 - f1_score: 0.5592 - val_accuracy: 0.8974 - val_loss: -0.5240 - val_dice_coef: 0.5348 - val_f1_score: 0.2849 - lr: 0.0125
# Epoch 37/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8977 - loss: -0.5652 - dice_coef: 0.5645 - f1_score: 0.5645
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.8977 - loss: -0.5652 - dice_coef: 0.5645 - f1_score: 0.5645 - val_accuracy: 0.8979 - val_loss: -0.5532 - val_dice_coef: 0.5635 - val_f1_score: 0.3136 - lr: 0.0125
# Epoch 38/50
# ...
# Epoch 48/50
# 32/32 [==============================] - 4s 130ms/step - accuracy: 0.9227 - loss: -0.7560 - dice_coef: 0.7563 - f1_score: 0.7564 - val_accuracy: 0.9055 - val_loss: -0.6874 - val_dice_coef: 0.6930 - val_f1_score: 0.4431 - lr: 0.0125
# Epoch 49/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.9227 - loss: -0.7466 - dice_coef: 0.7457 - f1_score: 0.7458 - val_accuracy: 0.9037 - val_loss: -0.6460 - val_dice_coef: 0.6526 - val_f1_score: 0.4025 - lr: 0.0125
# Epoch 50/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.9226 - loss: -0.7571 - dice_coef: 0.7563 - f1_score: 0.7563
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 32/32 [==============================] - 4s 133ms/step - accuracy: 0.9226 - loss: -0.7571 - dice_coef: 0.7563 - f1_score: 0.7563 - val_accuracy: 0.9039 - val_loss: -0.6857 - val_dice_coef: 0.6921 - val_f1_score: 0.4421 - lr: 0.0125
#
# Completed UNet Training. (Step 04)
# Thu at 02:39:29PM
#
# Completed Unet Evaluation. (Step 04)
#
# Training Results (Step 04):
# - Dice Coef: 77.322%
# - F1 Score: 77.322%
#
# Validation Results (Step 04):
# - Dice Coef: 59.136%
# - F1 Score: 59.136%
#
# Testing Results (Step 04):
# - Dice Coef: 66.196%
# - F1 Score: 66.196%
# Thu at 02:39:37PM
# confusion_unet [[13700845    18041]
#  [  665070   668844]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98  13718886
#          1.0       0.97      0.50      0.66   1333914
#
#     accuracy                           0.95  15052800
#    macro avg       0.96      0.75      0.82  15052800
# weighted avg       0.96      0.95      0.95  15052800
#
#
# EM_Step 04 (07) Complete.
# - Precision: 25.91%
# - SourceDelta: 11.70%
# - StepDelta: 7.31%
# Thu at 02:40:49PM
# ----------------------------------
#
#
#
#
# EM Step 05 begun.
# Thu at 02:40:49PM
#
# Generated Probability Output Map from previous model. (Step 05)
# Thu at 02:40:50PM
#
# Created New Annotation. (Step 05)
# Thu at 02:41:29PM
#
# Created Y_train (1008, 224, 224, 1) and Y_val (60, 224, 224, 1). (Step 05)
# Thu at 02:41:32PM
#
# New Learning Rate: 0.100000. (Step 05)
# Epoch 1/50
# 32/32 [==============================] - 7s 222ms/step - accuracy: 0.8573 - loss: -0.4653 - dice_coef: 0.4659 - f1_score: 0.4708 - val_accuracy: 0.0399 - val_loss: -0.0754 - val_dice_coef: 0.0740 - val_f1_score: 0.0740 - lr: 0.1000
# Epoch 2/50
# 32/32 [==============================] - 5s 159ms/step - accuracy: 0.9136 - loss: -0.6121 - dice_coef: 0.6087 - f1_score: 0.6089 - val_accuracy: 0.8853 - val_loss: -0.1253 - val_dice_coef: 0.1330 - val_f1_score: 0.0114 - lr: 0.1000
# Epoch 3/50
# 32/32 [==============================] - 4s 124ms/step - accuracy: 0.9146 - loss: -0.6166 - dice_coef: 0.6110 - f1_score: 0.6111 - val_accuracy: 0.1083 - val_loss: -0.0780 - val_dice_coef: 0.0766 - val_f1_score: 0.0766 - lr: 0.1000
# Epoch 4/50
# 32/32 [==============================] - 4s 124ms/step - accuracy: 0.9157 - loss: -0.6339 - dice_coef: 0.6318 - f1_score: 0.6320 - val_accuracy: 0.8980 - val_loss: -3.9387e-10 - val_dice_coef: 4.2155e-10 - val_f1_score: 0.0000e+00 - lr: 0.1000
# Epoch 5/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9145 - loss: -0.6232 - dice_coef: 0.6205 - f1_score: 0.6207 - val_accuracy: 0.4916 - val_loss: -0.1059 - val_dice_coef: 0.1037 - val_f1_score: 0.1037 - lr: 0.1000
# Epoch 6/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9150 - loss: -0.6231 - dice_coef: 0.6227 - f1_score: 0.6227 - val_accuracy: 0.4974 - val_loss: -0.1045 - val_dice_coef: 0.1022 - val_f1_score: 0.1022 - lr: 0.1000
# Epoch 7/50
# 32/32 [==============================] - 5s 164ms/step - accuracy: 0.9168 - loss: -0.6539 - dice_coef: 0.6547 - f1_score: 0.6548 - val_accuracy: 0.7606 - val_loss: -0.2037 - val_dice_coef: 0.2004 - val_f1_score: 0.2005 - lr: 0.1000
# Epoch 8/50
# 32/32 [==============================] - 5s 164ms/step - accuracy: 0.9175 - loss: -0.6534 - dice_coef: 0.6551 - f1_score: 0.6551 - val_accuracy: 0.8978 - val_loss: -0.2602 - val_dice_coef: 0.2761 - val_f1_score: 0.0261 - lr: 0.1000
# Epoch 9/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.9176 - loss: -0.6644 - dice_coef: 0.6651 - f1_score: 0.6647 - val_accuracy: 0.8981 - val_loss: -0.2414 - val_dice_coef: 0.2577 - val_f1_score: 0.0077 - lr: 0.1000
# Epoch 10/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9183 - loss: -0.6655 - dice_coef: 0.6657 - f1_score: 0.6660 - val_accuracy: 0.8981 - val_loss: -0.2338 - val_dice_coef: 0.2504 - val_f1_score: 4.2326e-04 - lr: 0.1000
# Epoch 11/50
# 32/32 [==============================] - 5s 167ms/step - accuracy: 0.9194 - loss: -0.6844 - dice_coef: 0.6848 - f1_score: 0.6848 - val_accuracy: 0.9056 - val_loss: -0.5488 - val_dice_coef: 0.5578 - val_f1_score: 0.3078 - lr: 0.1000
# Epoch 12/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9177 - loss: -0.6495 - dice_coef: 0.6498 - f1_score: 0.6510 - val_accuracy: 0.5850 - val_loss: -0.3569 - val_dice_coef: 0.3708 - val_f1_score: 0.1208 - lr: 0.1000
# Epoch 13/50
# 32/32 [==============================] - 5s 166ms/step - accuracy: 0.9183 - loss: -0.6604 - dice_coef: 0.6603 - f1_score: 0.6605 - val_accuracy: 0.8857 - val_loss: -0.5886 - val_dice_coef: 0.5974 - val_f1_score: 0.3474 - lr: 0.1000
# Epoch 14/50
# 32/32 [==============================] - 5s 163ms/step - accuracy: 0.9177 - loss: -0.6610 - dice_coef: 0.6612 - f1_score: 0.6612 - val_accuracy: 0.8973 - val_loss: -0.6403 - val_dice_coef: 0.6474 - val_f1_score: 0.3974 - lr: 0.1000
# Epoch 15/50
# 32/32 [==============================] - 4s 125ms/step - accuracy: 0.9188 - loss: -0.6686 - dice_coef: 0.6664 - f1_score: 0.6664 - val_accuracy: 0.9095 - val_loss: -0.6292 - val_dice_coef: 0.6371 - val_f1_score: 0.3872 - lr: 0.1000
# Epoch 16/50
# 32/32 [==============================] - 5s 165ms/step - accuracy: 0.9204 - loss: -0.6911 - dice_coef: 0.6887 - f1_score: 0.6887 - val_accuracy: 0.9126 - val_loss: -0.7304 - val_dice_coef: 0.7357 - val_f1_score: 0.4857 - lr: 0.1000
# Epoch 17/50
# 32/32 [==============================] - 5s 166ms/step - accuracy: 0.9195 - loss: -0.6779 - dice_coef: 0.6766 - f1_score: 0.6785 - val_accuracy: 0.9149 - val_loss: -0.7390 - val_dice_coef: 0.7442 - val_f1_score: 0.4942 - lr: 0.1000
# Epoch 18/50
# 32/32 [==============================] - 4s 131ms/step - accuracy: 0.9205 - loss: -0.6926 - dice_coef: 0.6921 - f1_score: 0.6922 - val_accuracy: 0.9139 - val_loss: -0.7271 - val_dice_coef: 0.7325 - val_f1_score: 0.4825 - lr: 0.1000
# Epoch 19/50
# 32/32 [==============================] - 4s 125ms/step - accuracy: 0.9207 - loss: -0.6989 - dice_coef: 0.6993 - f1_score: 0.6994 - val_accuracy: 0.8981 - val_loss: -0.2333 - val_dice_coef: 0.2500 - val_f1_score: 0.0000e+00 - lr: 0.1000
# Epoch 20/50
# 32/32 [==============================] - 4s 129ms/step - accuracy: 0.9214 - loss: -0.7110 - dice_coef: 0.7105 - f1_score: 0.7105 - val_accuracy: 0.8992 - val_loss: -0.2763 - val_dice_coef: 0.2919 - val_f1_score: 0.0419 - lr: 0.1000
# Epoch 21/50
# 32/32 [==============================] - 4s 130ms/step - accuracy: 0.9205 - loss: -0.6895 - dice_coef: 0.6889 - f1_score: 0.6889 - val_accuracy: 0.8981 - val_loss: -0.2333 - val_dice_coef: 0.2500 - val_f1_score: 0.0000e+00 - lr: 0.1000
# Epoch 22/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.9210 - loss: -0.7014 - dice_coef: 0.7007 - f1_score: 0.7007
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 32/32 [==============================] - 4s 133ms/step - accuracy: 0.9210 - loss: -0.7014 - dice_coef: 0.7007 - f1_score: 0.7007 - val_accuracy: 0.9112 - val_loss: -0.6692 - val_dice_coef: 0.6767 - val_f1_score: 0.4267 - lr: 0.1000
# Epoch 23/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.9179 - loss: -0.6667 - dice_coef: 0.6666 - f1_score: 0.6665 - val_accuracy: 0.8884 - val_loss: -0.0794 - val_dice_coef: 0.0768 - val_f1_score: 0.0769 - lr: 0.0500
# Epoch 24/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.9193 - loss: -0.6771 - dice_coef: 0.6772 - f1_score: 0.6772 - val_accuracy: 0.8829 - val_loss: -0.2452 - val_dice_coef: 0.2420 - val_f1_score: 0.2420 - lr: 0.0500
# Epoch 25/50
# 32/32 [==============================] - 4s 129ms/step - accuracy: 0.9203 - loss: -0.6930 - dice_coef: 0.6925 - f1_score: 0.6925 - val_accuracy: 0.9014 - val_loss: -0.6765 - val_dice_coef: 0.6818 - val_f1_score: 0.4318 - lr: 0.0500
# Epoch 26/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.9223 - loss: -0.7197 - dice_coef: 0.7208 - f1_score: 0.7208 - val_accuracy: 0.8998 - val_loss: -0.2958 - val_dice_coef: 0.3116 - val_f1_score: 0.0618 - lr: 0.0500
# Epoch 27/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.9226 - loss: -0.7205 - dice_coef: 0.7209 - f1_score: 0.7209
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9226 - loss: -0.7205 - dice_coef: 0.7209 - f1_score: 0.7209 - val_accuracy: 0.9014 - val_loss: -0.3595 - val_dice_coef: 0.3742 - val_f1_score: 0.1241 - lr: 0.0500
# Epoch 28/50
# 32/32 [==============================] - 4s 133ms/step - accuracy: 0.9234 - loss: -0.7332 - dice_coef: 0.7310 - f1_score: 0.7311 - val_accuracy: 0.9137 - val_loss: -0.7163 - val_dice_coef: 0.7228 - val_f1_score: 0.4728 - lr: 0.0250
# Epoch 29/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9234 - loss: -0.7339 - dice_coef: 0.7298 - f1_score: 0.7297 - val_accuracy: 0.9111 - val_loss: -0.6609 - val_dice_coef: 0.6689 - val_f1_score: 0.4188 - lr: 0.0250
# Epoch 30/50
# 32/32 [==============================] - 5s 167ms/step - accuracy: 0.9238 - loss: -0.7390 - dice_coef: 0.7361 - f1_score: 0.7365 - val_accuracy: 0.9142 - val_loss: -0.7416 - val_dice_coef: 0.7473 - val_f1_score: 0.4972 - lr: 0.0250
# Epoch 31/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.9234 - loss: -0.7312 - dice_coef: 0.7286 - f1_score: 0.7286 - val_accuracy: 0.9069 - val_loss: -0.5325 - val_dice_coef: 0.5435 - val_f1_score: 0.2933 - lr: 0.0250
# Epoch 32/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9237 - loss: -0.7402 - dice_coef: 0.7406 - f1_score: 0.7403 - val_accuracy: 0.9030 - val_loss: -0.4163 - val_dice_coef: 0.4294 - val_f1_score: 0.1793 - lr: 0.0250
# Epoch 33/50
# 32/32 [==============================] - 6s 173ms/step - accuracy: 0.9247 - loss: -0.7437 - dice_coef: 0.7389 - f1_score: 0.7388 - val_accuracy: 0.9150 - val_loss: -0.7501 - val_dice_coef: 0.7554 - val_f1_score: 0.5054 - lr: 0.0250
# Epoch 34/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9247 - loss: -0.7558 - dice_coef: 0.7565 - f1_score: 0.7565 - val_accuracy: 0.9011 - val_loss: -0.3461 - val_dice_coef: 0.3609 - val_f1_score: 0.1109 - lr: 0.0250
# Epoch 35/50
# 32/32 [==============================] - 4s 129ms/step - accuracy: 0.9253 - loss: -0.7552 - dice_coef: 0.7555 - f1_score: 0.7555 - val_accuracy: 0.9128 - val_loss: -0.7016 - val_dice_coef: 0.7084 - val_f1_score: 0.4584 - lr: 0.0250
# Epoch 36/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9250 - loss: -0.7592 - dice_coef: 0.7595 - f1_score: 0.7592 - val_accuracy: 0.9073 - val_loss: -0.5570 - val_dice_coef: 0.5674 - val_f1_score: 0.3175 - lr: 0.0250
# Epoch 37/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.9251 - loss: -0.7607 - dice_coef: 0.7607 - f1_score: 0.7607 - val_accuracy: 0.9017 - val_loss: -0.3751 - val_dice_coef: 0.3891 - val_f1_score: 0.1390 - lr: 0.0250
# Epoch 38/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.9258 - loss: -0.7685 - dice_coef: 0.7693 - f1_score: 0.7690
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.9258 - loss: -0.7685 - dice_coef: 0.7693 - f1_score: 0.7690 - val_accuracy: 0.9024 - val_loss: -0.4021 - val_dice_coef: 0.4155 - val_f1_score: 0.1655 - lr: 0.0250
# Epoch 39/50
# 32/32 [==============================] - 4s 138ms/step - accuracy: 0.9259 - loss: -0.7618 - dice_coef: 0.7613 - f1_score: 0.7613 - val_accuracy: 0.9034 - val_loss: -0.4378 - val_dice_coef: 0.4502 - val_f1_score: 0.2000 - lr: 0.0125
# Epoch 40/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9262 - loss: -0.7713 - dice_coef: 0.7703 - f1_score: 0.7703 - val_accuracy: 0.9016 - val_loss: -0.3807 - val_dice_coef: 0.3943 - val_f1_score: 0.1442 - lr: 0.0125
# Epoch 41/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9268 - loss: -0.7895 - dice_coef: 0.7888 - f1_score: 0.7887 - val_accuracy: 0.9098 - val_loss: -0.6236 - val_dice_coef: 0.6324 - val_f1_score: 0.3825 - lr: 0.0125
# Epoch 42/50
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.9263 - loss: -0.7807 - dice_coef: 0.7813 - f1_score: 0.7811 - val_accuracy: 0.9126 - val_loss: -0.6811 - val_dice_coef: 0.6886 - val_f1_score: 0.4385 - lr: 0.0125
# Epoch 43/50
# 32/32 [==============================] - 5s 169ms/step - accuracy: 0.9262 - loss: -0.7736 - dice_coef: 0.7698 - f1_score: 0.7698 - val_accuracy: 0.9188 - val_loss: -0.7787 - val_dice_coef: 0.7835 - val_f1_score: 0.5336 - lr: 0.0125
# Epoch 44/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9267 - loss: -0.7833 - dice_coef: 0.7809 - f1_score: 0.7809 - val_accuracy: 0.9096 - val_loss: -0.6089 - val_dice_coef: 0.6180 - val_f1_score: 0.3680 - lr: 0.0125
# Epoch 45/50
# 32/32 [==============================] - 4s 132ms/step - accuracy: 0.9266 - loss: -0.7802 - dice_coef: 0.7778 - f1_score: 0.7775 - val_accuracy: 0.9051 - val_loss: -0.4957 - val_dice_coef: 0.5069 - val_f1_score: 0.2569 - lr: 0.0125
# Epoch 46/50
# 32/32 [==============================] - 4s 130ms/step - accuracy: 0.9270 - loss: -0.7858 - dice_coef: 0.7863 - f1_score: 0.7862 - val_accuracy: 0.9174 - val_loss: -0.7583 - val_dice_coef: 0.7638 - val_f1_score: 0.5137 - lr: 0.0125
# Epoch 47/50
# 32/32 [==============================] - 4s 127ms/step - accuracy: 0.9270 - loss: -0.7842 - dice_coef: 0.7841 - f1_score: 0.7839 - val_accuracy: 0.9171 - val_loss: -0.7577 - val_dice_coef: 0.7633 - val_f1_score: 0.5133 - lr: 0.0125
# Epoch 48/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.9276 - loss: -0.7972 - dice_coef: 0.7956 - f1_score: 0.7952
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 32/32 [==============================] - 4s 128ms/step - accuracy: 0.9276 - loss: -0.7972 - dice_coef: 0.7956 - f1_score: 0.7952 - val_accuracy: 0.9094 - val_loss: -0.6017 - val_dice_coef: 0.6113 - val_f1_score: 0.3614 - lr: 0.0125
# Epoch 49/50
# 32/32 [==============================] - 4s 130ms/step - accuracy: 0.9267 - loss: -0.7892 - dice_coef: 0.7864 - f1_score: 0.7861 - val_accuracy: 0.9129 - val_loss: -0.6734 - val_dice_coef: 0.6817 - val_f1_score: 0.4316 - lr: 0.0063
# Epoch 50/50
# 32/32 [==============================] - 4s 126ms/step - accuracy: 0.9275 - loss: -0.7943 - dice_coef: 0.7944 - f1_score: 0.7943 - val_accuracy: 0.9091 - val_loss: -0.5951 - val_dice_coef: 0.6051 - val_f1_score: 0.3551 - lr: 0.0063
#
# Completed UNet Training. (Step 05)
# Thu at 02:45:41PM
#
# Completed Unet Evaluation. (Step 05)
#
# Training Results (Step 05):
# - Dice Coef: 53.250%
# - F1 Score: 53.252%
#
# Validation Results (Step 05):
# - Dice Coef: 46.798%
# - F1 Score: 46.798%
#
# Testing Results (Step 05):
# - Dice Coef: 54.830%
# - F1 Score: 54.831%
# Thu at 02:45:49PM
# confusion_unet [[13703393    15493]
#  [  824235   509679]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97  13718886
#          1.0       0.97      0.38      0.55   1333914
#
#     accuracy                           0.94  15052800
#    macro avg       0.96      0.69      0.76  15052800
# weighted avg       0.95      0.94      0.93  15052800
#
#
# EM_Step 05 (08) Complete.
# - Precision: 36.60%
# - SourceDelta: 22.39%
# - StepDelta: 10.69%
# Thu at 02:47:00PM
# ----------------------------------

# %%
EM_target = 10
while EM_iterator < EM_target:   
    
    # ---------------------------
    # 0. Initialization
    # ---------------------------
    section_tstamp = time.time()
    section_name = 'EM_Step {:02}'.format(EM_iterator)

    # Create folder for em step
    emfolder = os.path.join(test.dir, 'Step_{:02}'.format(EM_iterator))
    if not os.path.exists(emfolder): os.mkdir(emfolder)

    print("\n\nEM Step {:02} begun.".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    anno_stamp = time.time()
    
    # ---------------------------
    # 1. Creating New Annotations
    # ---------------------------

    # 1.1 Get probability output map from last model (Skip first step since it was pre-generated)
    pmap_fp = os.path.join(emfolder, 'pmap_{:02}.tif'.format(EM_iterator))
    p_output = emt.Get_Pmap(train_raster, WinShape, unet_model, pmap_fp)
    
    print("\nGenerated Probability Output Map from previous model. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    
    # 1.2 Weight Candidate Frames
    newSegments = []
    for frame in candidateFrames:
        
        # Get Candidate Weights
        weightedFrame = emt.WeightCandidates(p_output, frame)
        
        # Select Likely or Top Candidate 
        if random.uniform(0,1) < random_candidate_chance:
            # Use 'likely' candidate (ENSURE Select_Candidate() FUNCTION IS UPDATED (lib/EMTools.py))
            newSegments.append(emt.Select_Candidate(weightedFrame, 'weight', weight_limit, default_random=default_random))
        else:
            # Use top candidate
            newSegments.append(emt.Top_Candidate(weightedFrame, 'weight', default_random=default_random))
            
            
        
    # 1.3 Convert List of segments to GeoDataFrame
    newSegmentFrame = gpd.GeoDataFrame(geometry=newSegments, crs=candidateFrames[0].crs)
    newSegmentFrame.to_file(os.path.join(emfolder, 'segments_{:02}.shp'.format(EM_iterator)))

    # 1.4 Connect top segments:
    newAnnotation = emt.Connect_Lines(newSegmentFrame, maxRepairDist)
    newAnnotation.to_file(os.path.join(emfolder, 'annotation_{:02}.shp'.format(EM_iterator)))

    # 1.5 Save mean precision of this annotation.
    annoPrecision = emt.GDF_Precision(gt_labels, newAnnotation, precisionBuffer)

    
    print("\nCreated New Annotation. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    anno_time = time.time() - anno_stamp
    
    # ---------------------------
    # 2. Create new Label Tensors
    # ---------------------------
    
    # 2.1 Rasterize New Labels
    buff_anno = st.GDF_Buffer(newAnnotation, labelBuffer, flatten=True)
    anno_raster = st.GDF_Rasterize(buff_anno, train_raster)
    
    # 2.2 Read Y_train, Y_val
    Y_train = gt.ResampleTiles(anno_raster, train_offsets_fp)
    Y_val = gt.ResampleTiles(anno_raster, val_offsets_fp)
    
    # 2.2 Augment Y_train, Y_val - NOTE: set horizontal flip to FALSE from Sultan's Setup
    Y_train = gt.AugmentImages(Y_train, h_flip=False, v_flip=train_v_flip, rotate=train_rotate)
    Y_val = gt.AugmentImages(Y_val, h_flip=False, v_flip=val_v_flip, rotate=val_rotate)
    
    print("\nCreated Y_train {} and Y_val {}. (Step {:02})".format(Y_train.shape, Y_val.shape, EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    
    
    # ---------------------------
    # 3. Re-Train U-Net 
    # ---------------------------
    
    # 3.1 Load Callbacks 
    callbacks = SetCallbacks(emfolder + '/model_{:02}.h5'.format(EM_iterator))
    
    # 3.2 Determine Learning Rate from schedule
    #EM_learningRate = Step_LR_Schedule(learningRate, EM_iterator, EM_target, lr_const)
    EM_learningRate = learningRate #(EM_iterator%2 + 1)*learningRate/2
    if EM_iterator > 5:
        EM_learningRate = learningRateReduced
    print("\nNew Learning Rate: {:.6f}. (Step {:02})".format(EM_learningRate, EM_iterator))
        
    training_stamp = time.time()
    with mirror_strategy.scope():
        unet_model = UNET_7_224(dropout_val = dropval)
        unet_model.compile(optimizer=Adam(lr=EM_learningRate), loss=dice_coef_loss, metrics=metrics)
        TrainData = unet_model.fit(X_train, Y_train, validation_data=(X_val, Y_val), shuffle=useShuffle, batch_size=batchSize, epochs=epochs, callbacks=callbacks)
    training_time = time.time() - training_stamp
    
    training_metrics = {
        'f1': Get_Metric_Data(TrainData, 'f1_score'),
        'dice_coef': Get_Metric_Data(TrainData, 'dice_coef'),
        'loss': Get_Metric_Data(TrainData, 'loss')
    }

    train_metrics_fp = os.path.join(emfolder, 'train_curve_{:02}.csv'.format(EM_iterator))
    with open(train_metrics_fp, 'a+', newline='\n') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter= ',')
        for key, data in training_metrics.items():
            csvwriter.writerow(['Training {}'.format(key)])
            csvwriter.writerow(data)
            
    validation_metrics = {
        'f1': Get_Metric_Data(TrainData, 'val_f1_score'),
        'dice_coef': Get_Metric_Data(TrainData, 'val_dice_coef'),
        'loss': Get_Metric_Data(TrainData, 'val_loss')
    }   
    val_metrics_fp = os.path.join(emfolder, 'val_curve_{:02}.csv'.format(EM_iterator))
    with open(val_metrics_fp, 'a+', newline='\n') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter= ',')
        for key, data in training_metrics.items():
            csvwriter.writerow(['Validation {}'.format(key)])
            csvwriter.writerow(data)
    
    SaveHistory(TrainData, os.path.join(emfolder, 'trainingResults_{:02}'.format(EM_iterator)), test.end) # Save Plots
    
    print("\nCompleted UNet Training. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    


    # ---------------------------
    # 4. Evaluate Model
    # ---------------------------

    
    # Training Results
    train_results = emt.Evaluate(X_train, Y_train, unet_model)
    # Validation Results
    val_results = emt.Evaluate(X_val, Y_val, unet_model)
    # Testing Results
    test_results = emt.Evaluate(X_test, Y_test, unet_model)

    
    
    # print
    print("\nCompleted Unet Evaluation. (Step {:02})".format(EM_iterator))
    print("\nTraining Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(train_results[0]))
    print("- {}".format(train_results[1]))
    print("\nValidation Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(val_results[0]))
    print("- {}".format(val_results[1]))   
    print("\nTesting Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(test_results[0]))
    print("- {}".format(test_results[1]))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    y_pred=np.copy(unet_model.predict(X_test))
    y_pred = np.round(y_pred)
    y_true=np.copy(Y_test)
    y_pred.shape = y_pred.shape[0]* y_pred.shape[1]*y_pred.shape[2]* y_pred.shape[3]
    y_true.shape = y_true.shape[0]* y_true.shape[1]*y_true.shape[2]* y_true.shape[3]

    c_matrix = confusion_matrix(y_true, y_pred, labels=[0, 1])
    print("confusion_unet", c_matrix)
    report_unet = classification_report(y_true, y_pred)
    print("report_unet", report_unet)
    
    # ---------------------------
    # 5. Save Step Data
    # ---------------------------
    
    # Save to dict for seperate CSV
    dataMatrix['precision'].append(annoPrecision*100)
    dataMatrix['trainDice'].append(train_results[0]) 
    dataMatrix['trainF1Score'].append(train_results[1]) 
    dataMatrix['valDice'].append(val_results[0]) 
    dataMatrix['valF1Score'].append(val_results[1]) 
    dataMatrix['testDice'].append(test_results[0]) 
    dataMatrix['testF1Score'].append(test_results[1]) 
    
    
    # Save EM Step Data 
    test.Results("EM Data {:02}".format(EM_iterator), {
            
        'Time Elapsed: Re-training': training_time,
        'Time Elapsed: New Annotation': anno_time,
            
        'Precision': '{:.2f}%'.format(annoPrecision*100),
        'SourceDelta': '{:.2f}%'.format((annoPrecision-sourcePrecision)*100),
        'StepDelta': '{:.2f}%'.format((annoPrecision-prevPrecision)*100),
        
        'UNet: LR': str(EM_learningRate),
        'UNet: Epochs': str(len(TrainData.history['dice_coef'])),
        
        'UNet: Training Results': train_results,
        'UNet: Validation Results': val_results,
        'UNet: Testing Results': test_results,
        'UNet: Confusion Matrix': c_matrix,
        'UNet: Report': report_unet
    })
    # Save as section
    section_data = {'time': time.time()-section_tstamp, 'stamp': section_tstamp}
    test.Section(section_name, section_data)
    
    # Print step data
    print("\n{} ({:02}) Complete.".format(section_name, len(test.sectionNames)))
    print('- Precision: {:.2f}%'.format(annoPrecision*100))
    print('- SourceDelta: {:.2f}%'.format((annoPrecision-sourcePrecision)*100))
    print('- StepDelta: {:.2f}%'.format((annoPrecision-prevPrecision)*100))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    print("----------------------------------\n\n")
    
    # Increase iterator and save previous precision for step_delta
    EM_iterator += 1
    prevPrecision = annoPrecision

# %% [markdown]
# ### Save Test Data

# %%
""" Save EM step data to csv
with open(os.path.join(test.dir, 'EM_Data.csv'), 'a+', newline='\n') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter= ',')
    csvwriter.writerow([test.name, 'Line Precisions (delta)', 'Train Dice Coef (delta)', 'Train F1 Score (delta)', 'Val Dice Coef (delta)', 'Val F1 Score (delta)', 'Test Dice Coef (delta)', 'Test F1 Score (delta)'])
    for i in range(len(dataMatrix['precision'])):
        row = ['step {:02}'.format(i)]
        for key, item in dataMatrix.items():
            row.append('{} ({})'.format(item[i], item[i]-item[0]))
        csvwriter.writerow(row)
"""

# Index test in master csv
test.index()

# Write test Info to Markdown
test.markdown()

# Print Completion
print("Data successfully saved to markdown file, indexed on csv.") 
print(dt.now().strftime('%a at %I:%M:%S%p'))
# Out:
# Data successfully saved to markdown file, indexed on csv.
# Thu at 02:51:13PM
