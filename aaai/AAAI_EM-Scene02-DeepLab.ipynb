# %% [markdown]
# # AAAI EM Iteration Notebook
#
# Slightly modified for current system.
#
#
# ---
#
# ### Required:
# - Tensors:
#     - `X_test`: Testing Image Tensor
#     - `Y_test`: Testing Label Tensor
#     - `X_train`: Training Image Tensor
#     - `X_val`: Validation Image Tensor
#     - `train_offsets`: Window offsets for scanning `Y_train` as path to csv.
#     - `val_offsets`: Window offsets for scanning `Y_val` as path to csv.
#
# - `segments`: Candidate line segments accross training raster in directory
#
# - `preweights`: pre-trained Weights for U-Net model on the passed `X_train`, `X_val` tensors
#
# - `initial_pmap`: pmap output from baseline data

# %%
# -- All Imports --
import os, sys, time, csv

import tensorflow as tf
import numpy as np
import random as rand
import geopandas as gpd
import matplotlib.pyplot as plt

from lib.ModuleTools import *
from lib.UnetTools import *
from lib.DeepLabV2 import *
import lib.GeoTools as gt
import lib.ShapeTools as st
import lib.EMTools as emt
import lib.LineGen as lg

# Parameters, Files
from lib.EMconfigScene02 import *
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# -- Module Information --
module_data = {
    'name': 'EM_Iteration_s02', # Module Name
    'desc': 'Iterate over EM process using the second dataset', # Module Description
    'test_name': 'aaai_emtest_s02', # Default test name
    'csv': 'master_s02.csv', # Csv path
    'verbose': True # Default verbosity
}
test = ModuleTest(module_data)
# -------------------------


# -- Iteration Parameters --
iteration = {}

# Number of EM iterations
EM_target = wrap(2, iteration) 
 
# Constant Value for Learning Rate Schedule 
lr_const = wrap(2, iteration)

# optionally reset layer weights between iterations
rebuild_model = wrap( True, iteration)

# (epsilon) Chance that a candidate will be selected outside of the top candidate, within the K top candidates.
random_candidate_chance = wrap( 0, iteration)

# (K) Consider K top-weighted segments. set 1 for top candidate, set 0 to consider all.
weight_limit = wrap( 13, iteration)


# Option to load candidates, generally set to true
load_candidates = True

# The parameters below are defined in the /lib/EMconfig.py file. 
test.Pgroup("Iteration", iteration)
test.Pgroup("Environment", env)
test.Pgroup("Tensor Data", TensorConfig)
test.Pgroup("Annotation Configuration", Annotations)
test.Pgroup("UNet Config", unetcfg)
test.Pgroup('Baseline Directories', inputDirs)
test.Fgroup('Input Arrays', InputArrays)
test.Fgroup('Source_Data', sourceData)


""" Test Parameters """

# UNET configuration
learningRate = 0.1
learningRateReduced = 0.05

# Candidate Segment Directory - Generate with other notebook
#CandidateDirectory = '/data/GeometricErrors/aaai_data/segments'
CandidateDirectory = '/data/GeometricErrors/tests/aaai_system/Candidates-Scene02/segment_sets_scene02_04/segments_04'
#04_new exp increase interval 15 1.5, 1.2 candidates
#03_No exp, equal interval, 20, 1.5 candidates
#02_No exp, equal interval, 15, 1.5

# Total number of EM steps
EM_target = 6

# Use random choice when selecting candidates below weight threshold (Implemented here)
default_random = False


mirror_strategy = tf.distribute.MirroredStrategy(devices=['/gpu:0', '/gpu:1', '/gpu:2', '/gpu:3'])

# ---------------
print(dt.now().strftime('Hyperparameters saved on %a at %I:%M:%S %p.'))
# Out:
# /home/jiang-ws1/.virtualenvs/geo_errors/lib/python3.7/site-packages/geopandas/_compat.py:88: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.8.1-CAPI-1.13.3). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string
# Describe aaai_emtest_s02_08:20 buffer
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# Hyperparameters saved on Sat at 11:25:44 PM.

# %%
print(inputDirs)
inputDirs.update({"CandidateDirectory": CandidateDirectory})
unetcfg.update({"learningRate": learningRate})
# Out:
# {'CandidateDirectory': '/data/GeometricErrors/aaai_data/scene02/segments', 'train_offsets_fp': '/data/GeometricErrors/aaai_data/scene02/train_offsets.csv', 'val_offsets_fp': '/data/GeometricErrors/aaai_data/scene02/val_offsets.csv'}

# %% [markdown]
# ## Load Baseline Data

# %%
labelBuffer = wrap( 20 , TensorConfig)

section_tstamp = time.time()
section_name = 'Prepare Base Data'
# --------------------

# 1. Shapefile Precisions
imp_labels = st.Flatten_Frame(imp_labels)
sourcePrecision = emt.GDF_Precision(gt_labels, imp_labels, precisionBuffer)
prevPrecision = sourcePrecision

emfolder = os.path.join(test.dir, 'Baseline')
if not os.path.exists(emfolder): os.mkdir(emfolder)
    
section_tstamp = time.time()
section_name = 'Prepare Model'
# --------------------

callbacks = SetCallbacks(test.dir + '/baseline_model.h5')

# 5. Load Unet Model
from tensorflow.keras.optimizers import Adam

# %%
with mirror_strategy.scope():
    deeplab_model = Deeplabv4(224, 224, dropout = 0.5) 
    deeplab_model.compile(optimizer=Adam(lr=learningRate), loss=dice_coef_loss, metrics=metrics)
    #unet_model.load_weights(preTrainedPath)
    callbacks = SetCallbacks(test.dir + '/model_baseline.h5')
    results_01 = deeplab_model.fit(X_train, Y_train, validation_data=(X_val, Y_val), shuffle=useShuffle, batch_size=batchSize, epochs=epochs, callbacks=callbacks)
# Out:
# *** Building DeepLabv3Plus Network ***
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# *** Output_Shape => (None, 224, 224, 1) ***
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 69 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 69 all-reduces with algorithm = nccl, num_packs = 1
# 32/32 [==============================] - 8s 264ms/step - dice_coef: 0.3670 - accuracy: 0.6979 - f1_score: 0.3698 - loss: -0.3653 - val_dice_coef: 0.0011 - val_accuracy: 0.8429 - val_f1_score: 0.0011 - val_loss: -9.8552e-04 - lr: 0.1000
# Epoch 2/50
# 32/32 [==============================] - 3s 107ms/step - dice_coef: 0.5203 - accuracy: 0.8623 - f1_score: 0.5205 - loss: -0.5200 - val_dice_coef: 0.2615 - val_accuracy: 0.8595 - val_f1_score: 0.0115 - val_loss: -0.2441 - lr: 0.1000
# Epoch 3/50
# 32/32 [==============================] - 3s 90ms/step - dice_coef: 0.5522 - accuracy: 0.8691 - f1_score: 0.5523 - loss: -0.5544 - val_dice_coef: 0.2047 - val_accuracy: 0.7395 - val_f1_score: 0.2047 - val_loss: -0.2089 - lr: 0.1000
# Epoch 4/50
# 32/32 [==============================] - 3s 106ms/step - dice_coef: 0.5661 - accuracy: 0.8712 - f1_score: 0.5663 - loss: -0.5665 - val_dice_coef: 0.2667 - val_accuracy: 0.8111 - val_f1_score: 0.2667 - val_loss: -0.2722 - lr: 0.1000
# Epoch 5/50
# 32/32 [==============================] - 3s 91ms/step - dice_coef: 0.5797 - accuracy: 0.8762 - f1_score: 0.5799 - loss: -0.5792 - val_dice_coef: 0.1513 - val_accuracy: 0.6316 - val_f1_score: 0.1513 - val_loss: -0.1551 - lr: 0.1000
# Epoch 6/50
# 32/32 [==============================] - 3s 91ms/step - dice_coef: 0.5941 - accuracy: 0.8778 - f1_score: 0.5942 - loss: -0.5965 - val_dice_coef: 0.1250 - val_accuracy: 0.8180 - val_f1_score: 0.1250 - val_loss: -0.1278 - lr: 0.1000
# Epoch 7/50
# 32/32 [==============================] - 3s 91ms/step - dice_coef: 0.6007 - accuracy: 0.8802 - f1_score: 0.6009 - loss: -0.5998 - val_dice_coef: 0.2048 - val_accuracy: 0.8309 - val_f1_score: 0.2047 - val_loss: -0.2091 - lr: 0.1000
# Epoch 8/50
# 32/32 [==============================] - 3s 92ms/step - dice_coef: 0.6274 - accuracy: 0.8853 - f1_score: 0.6275 - loss: -0.6280 - val_dice_coef: 0.2094 - val_accuracy: 0.7812 - val_f1_score: 0.2094 - val_loss: -0.2153 - lr: 0.1000
# Epoch 9/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.6517 - accuracy: 0.8898 - f1_score: 0.6519 - loss: -0.6511
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 32/32 [==============================] - 3s 92ms/step - dice_coef: 0.6517 - accuracy: 0.8898 - f1_score: 0.6519 - loss: -0.6511 - val_dice_coef: 0.2251 - val_accuracy: 0.7176 - val_f1_score: 0.2251 - val_loss: -0.2303 - lr: 0.1000
# Epoch 10/50
# 32/32 [==============================] - 3s 108ms/step - dice_coef: 0.6782 - accuracy: 0.8951 - f1_score: 0.6783 - loss: -0.6785 - val_dice_coef: 0.2866 - val_accuracy: 0.8485 - val_f1_score: 0.2816 - val_loss: -0.2918 - lr: 0.0500
# Epoch 11/50
# 32/32 [==============================] - 3s 92ms/step - dice_coef: 0.7058 - accuracy: 0.8986 - f1_score: 0.7060 - loss: -0.7066 - val_dice_coef: 0.1994 - val_accuracy: 0.8528 - val_f1_score: 0.1900 - val_loss: -0.1998 - lr: 0.0500
# Epoch 12/50
# 32/32 [==============================] - 3s 93ms/step - dice_coef: 0.7098 - accuracy: 0.9008 - f1_score: 0.7100 - loss: -0.7113 - val_dice_coef: 0.2140 - val_accuracy: 0.8574 - val_f1_score: 0.2139 - val_loss: -0.2186 - lr: 0.0500
# Epoch 13/50
# 32/32 [==============================] - 3s 92ms/step - dice_coef: 0.7440 - accuracy: 0.9058 - f1_score: 0.7442 - loss: -0.7437 - val_dice_coef: 0.1273 - val_accuracy: 0.8550 - val_f1_score: 0.1269 - val_loss: -0.1281 - lr: 0.0500
# Epoch 14/50
# 32/32 [==============================] - 3s 93ms/step - dice_coef: 0.7485 - accuracy: 0.9079 - f1_score: 0.7486 - loss: -0.7512 - val_dice_coef: 0.1741 - val_accuracy: 0.8575 - val_f1_score: 0.1741 - val_loss: -0.1764 - lr: 0.0500
# Epoch 15/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.7741 - accuracy: 0.9111 - f1_score: 0.7742 - loss: -0.7737
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.7741 - accuracy: 0.9111 - f1_score: 0.7742 - loss: -0.7737 - val_dice_coef: 0.0914 - val_accuracy: 0.8575 - val_f1_score: 0.0807 - val_loss: -0.0930 - lr: 0.0500
# Epoch 16/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8091 - accuracy: 0.9159 - f1_score: 0.8092 - loss: -0.8094 - val_dice_coef: 0.1781 - val_accuracy: 0.8545 - val_f1_score: 0.1776 - val_loss: -0.1803 - lr: 0.0250
# Epoch 17/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8157 - accuracy: 0.9181 - f1_score: 0.8158 - loss: -0.8185 - val_dice_coef: 0.2109 - val_accuracy: 0.8556 - val_f1_score: 0.2106 - val_loss: -0.2133 - lr: 0.0250
# Epoch 18/50
# 32/32 [==============================] - 3s 93ms/step - dice_coef: 0.8370 - accuracy: 0.9205 - f1_score: 0.8371 - loss: -0.8366 - val_dice_coef: 0.2620 - val_accuracy: 0.8566 - val_f1_score: 0.2594 - val_loss: -0.2658 - lr: 0.0250
# Epoch 19/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8353 - accuracy: 0.9209 - f1_score: 0.8354 - loss: -0.8384 - val_dice_coef: 0.2413 - val_accuracy: 0.8564 - val_f1_score: 0.2259 - val_loss: -0.2432 - lr: 0.0250
# Epoch 20/50
# 32/32 [==============================] - 3s 109ms/step - dice_coef: 0.8525 - accuracy: 0.9230 - f1_score: 0.8526 - loss: -0.8521 - val_dice_coef: 0.2942 - val_accuracy: 0.8598 - val_f1_score: 0.2933 - val_loss: -0.2997 - lr: 0.0250
# Epoch 21/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8597 - accuracy: 0.9246 - f1_score: 0.8598 - loss: -0.8634 - val_dice_coef: 0.0697 - val_accuracy: 0.8593 - val_f1_score: 0.0694 - val_loss: -0.0709 - lr: 0.0250
# Epoch 22/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8769 - accuracy: 0.9259 - f1_score: 0.8770 - loss: -0.8767 - val_dice_coef: 0.2360 - val_accuracy: 0.8585 - val_f1_score: 0.2341 - val_loss: -0.2396 - lr: 0.0250
# Epoch 23/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8670 - accuracy: 0.9258 - f1_score: 0.8672 - loss: -0.8667 - val_dice_coef: 0.2695 - val_accuracy: 0.8611 - val_f1_score: 0.2694 - val_loss: -0.2746 - lr: 0.0250
# Epoch 24/50
# 32/32 [==============================] - 4s 113ms/step - dice_coef: 0.8920 - accuracy: 0.9278 - f1_score: 0.8921 - loss: -0.8918 - val_dice_coef: 0.2996 - val_accuracy: 0.8672 - val_f1_score: 0.2984 - val_loss: -0.3042 - lr: 0.0250
# Epoch 25/50
# 32/32 [==============================] - 4s 111ms/step - dice_coef: 0.8965 - accuracy: 0.9285 - f1_score: 0.8966 - loss: -0.8963 - val_dice_coef: 0.3209 - val_accuracy: 0.8657 - val_f1_score: 0.3198 - val_loss: -0.3268 - lr: 0.0250
# Epoch 26/50
# 32/32 [==============================] - 3s 93ms/step - dice_coef: 0.8862 - accuracy: 0.9281 - f1_score: 0.8863 - loss: -0.8863 - val_dice_coef: 0.2784 - val_accuracy: 0.8639 - val_f1_score: 0.2772 - val_loss: -0.2826 - lr: 0.0250
# Epoch 27/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9003 - accuracy: 0.9294 - f1_score: 0.9004 - loss: -0.9000 - val_dice_coef: 0.2850 - val_accuracy: 0.8621 - val_f1_score: 0.2849 - val_loss: -0.2889 - lr: 0.0250
# Epoch 28/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8937 - accuracy: 0.9291 - f1_score: 0.8938 - loss: -0.8936 - val_dice_coef: 0.2686 - val_accuracy: 0.8616 - val_f1_score: 0.2684 - val_loss: -0.2726 - lr: 0.0250
# Epoch 29/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8892 - accuracy: 0.9289 - f1_score: 0.8893 - loss: -0.8929 - val_dice_coef: 0.3032 - val_accuracy: 0.8652 - val_f1_score: 0.2993 - val_loss: -0.3078 - lr: 0.0250
# Epoch 30/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.9017 - accuracy: 0.9304 - f1_score: 0.9018 - loss: -0.9043
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9017 - accuracy: 0.9304 - f1_score: 0.9018 - loss: -0.9043 - val_dice_coef: 0.2628 - val_accuracy: 0.8593 - val_f1_score: 0.2624 - val_loss: -0.2667 - lr: 0.0250
# Epoch 31/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9094 - accuracy: 0.9309 - f1_score: 0.9095 - loss: -0.9091 - val_dice_coef: 0.3001 - val_accuracy: 0.8661 - val_f1_score: 0.2955 - val_loss: -0.3040 - lr: 0.0125
# Epoch 32/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9220 - accuracy: 0.9324 - f1_score: 0.9221 - loss: -0.9231 - val_dice_coef: 0.2878 - val_accuracy: 0.8644 - val_f1_score: 0.2849 - val_loss: -0.2924 - lr: 0.0125
# Epoch 33/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9245 - accuracy: 0.9324 - f1_score: 0.9245 - loss: -0.9246 - val_dice_coef: 0.2862 - val_accuracy: 0.8637 - val_f1_score: 0.2832 - val_loss: -0.2910 - lr: 0.0125
# Epoch 34/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.9229 - accuracy: 0.9328 - f1_score: 0.9230 - loss: -0.9232 - val_dice_coef: 0.2773 - val_accuracy: 0.8633 - val_f1_score: 0.2720 - val_loss: -0.2813 - lr: 0.0125
# Epoch 35/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.9303 - accuracy: 0.9331 - f1_score: 0.9303 - loss: -0.9300
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9303 - accuracy: 0.9331 - f1_score: 0.9303 - loss: -0.9300 - val_dice_coef: 0.2945 - val_accuracy: 0.8649 - val_f1_score: 0.2918 - val_loss: -0.2986 - lr: 0.0125
# Epoch 36/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9289 - accuracy: 0.9337 - f1_score: 0.9290 - loss: -0.9290 - val_dice_coef: 0.2959 - val_accuracy: 0.8648 - val_f1_score: 0.2941 - val_loss: -0.3006 - lr: 0.0063
# Epoch 37/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9323 - accuracy: 0.9336 - f1_score: 0.9324 - loss: -0.9321 - val_dice_coef: 0.2822 - val_accuracy: 0.8645 - val_f1_score: 0.2804 - val_loss: -0.2860 - lr: 0.0063
# Epoch 38/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9350 - accuracy: 0.9342 - f1_score: 0.9351 - loss: -0.9349 - val_dice_coef: 0.2886 - val_accuracy: 0.8649 - val_f1_score: 0.2832 - val_loss: -0.2923 - lr: 0.0063
# Epoch 39/50
# 32/32 [==============================] - 3s 106ms/step - dice_coef: 0.9289 - accuracy: 0.9340 - f1_score: 0.9290 - loss: -0.9326 - val_dice_coef: 0.2774 - val_accuracy: 0.8640 - val_f1_score: 0.2735 - val_loss: -0.2813 - lr: 0.0063
# Epoch 40/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.9356 - accuracy: 0.9340 - f1_score: 0.9357 - loss: -0.9353
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9356 - accuracy: 0.9340 - f1_score: 0.9357 - loss: -0.9353 - val_dice_coef: 0.2689 - val_accuracy: 0.8623 - val_f1_score: 0.2648 - val_loss: -0.2730 - lr: 0.0063
# Epoch 41/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.9377 - accuracy: 0.9346 - f1_score: 0.9378 - loss: -0.9377 - val_dice_coef: 0.2776 - val_accuracy: 0.8636 - val_f1_score: 0.2748 - val_loss: -0.2822 - lr: 0.0031
# Epoch 42/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9397 - accuracy: 0.9344 - f1_score: 0.9398 - loss: -0.9398 - val_dice_coef: 0.2800 - val_accuracy: 0.8640 - val_f1_score: 0.2776 - val_loss: -0.2843 - lr: 0.0031
# Epoch 43/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9337 - accuracy: 0.9346 - f1_score: 0.9338 - loss: -0.9376 - val_dice_coef: 0.2818 - val_accuracy: 0.8639 - val_f1_score: 0.2787 - val_loss: -0.2862 - lr: 0.0031
# Epoch 44/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.9262 - accuracy: 0.9340 - f1_score: 0.9263 - loss: -0.9296 - val_dice_coef: 0.2681 - val_accuracy: 0.8628 - val_f1_score: 0.2651 - val_loss: -0.2720 - lr: 0.0031
# Epoch 45/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.9336 - accuracy: 0.9346 - f1_score: 0.9337 - loss: -0.9373
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.0015625000232830644.
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9336 - accuracy: 0.9346 - f1_score: 0.9337 - loss: -0.9373 - val_dice_coef: 0.2721 - val_accuracy: 0.8628 - val_f1_score: 0.2693 - val_loss: -0.2759 - lr: 0.0031

# %%
pmap_fp = os.path.join(emfolder, 'pmap_baseline.tif')
initial_pmap = emt.Get_Pmap(train_raster, WinShape, deeplab_model, pmap_fp)
    
print("\nInitialized U_Net model.")
print(dt.now().strftime('%a at %I:%M:%S%p'))

# 6. Evaluate Unet Model
# Save Training Results
train_results = emt.Evaluate(X_train, Y_train, deeplab_model)
# Save Validation Results
val_results = emt.Evaluate(X_val, Y_val, deeplab_model)
# Save Testing Results
test_results = emt.Evaluate(X_test, Y_test, deeplab_model)

y_pred=np.copy(deeplab_model.predict(X_test))
y_pred = np.round(y_pred)
y_true=np.copy(Y_test)
y_pred.shape = y_pred.shape[0]* y_pred.shape[1]*y_pred.shape[2]* y_pred.shape[3]
y_true.shape = y_true.shape[0]* y_true.shape[1]*y_true.shape[2]* y_true.shape[3]

c_matrix = confusion_matrix(y_true, y_pred, labels=[0, 1])
print("Confusion Matrix", c_matrix)
report_unet = classification_report(y_true, y_pred)
print("report_unet", report_unet)

# Print the baseline metrics
print("\nRan Initial U_Net evaluation:")
print("\nBaseline Training Results:")
print("- {}".format(train_results[0]))
print("- {}".format(train_results[1]))
print("\nBaseline Validation Results:")
print("- {}".format(val_results[0]))
print("- {}".format(val_results[1]))
print("\nBaseline Testing Results:")
print("- {}".format(test_results[0]))
print("- {}".format(test_results[1]))
print("\nBaseline Shape Metrics")
print("- Precision: {:.2f}".format(sourcePrecision*100))
print(dt.now().strftime('%a at %I:%M:%S%p'))


# Save initial EM Data 
test.Results("Baseline Data", {
    'Precision': '{:.2f}%'.format(sourcePrecision*100),
    'UNet: Training Results': train_results,
    'UNet: Validation Results': val_results,
    'UNet: Testing Results': test_results,
    'UNet: Report': report_unet, 
    'UNet: Confusion Matrix': c_matrix
})


# Create Matrix to save step data in seperate CSV
dataMatrix = {
    'precision': [sourcePrecision*100],
    
    'trainDice': [train_results[0]],
    'trainF1Score': [train_results[1]],
    
    'valDice': [val_results[0]],
    'valF1Score': [val_results[1]],
    
    'testDice': [test_results[0]],
    'testF1Score': [test_results[1]]
}

# --------------------
section_data = {'time': time.time()-section_tstamp, 'stamp': section_tstamp}
test.Section(section_name, section_data)
# --------------------
if test.verbose:
    print("\n{} ({:02}) Complete.".format(section_name, len(test.sectionNames)))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
# Out:
# Initialized U_Net model.
# Sat at 11:28:44PM
# Confusion Matrix [[13502413   216473]
#  [  806709   527205]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.94      0.98      0.96  13718886
#          1.0       0.71      0.40      0.51   1333914
#
#     accuracy                           0.93  15052800
#    macro avg       0.83      0.69      0.74  15052800
# weighted avg       0.92      0.93      0.92  15052800
#
#
# Ran Initial U_Net evaluation:
#
# Baseline Training Results:
# - Dice Coef: 95.922%
# - F1 Score: 95.930%
#
# Baseline Validation Results:
# - Dice Coef: 37.459%
# - F1 Score: 37.457%
#
# Baseline Testing Results:
# - Dice Coef: 50.764%
# - F1 Score: 50.752%
#
# Baseline Shape Metrics
# - Precision: 28.70
# Sat at 11:30:02PM
#
# Prepare Model (01) Complete.
# Sat at 11:30:02PM

# %%
# preTrainedPath = '/data/GeometricErrors/tests/aaai_system/EM_Iteration_s02/aaai_emtest_s02_03/baseline_model.h5'
# unet_model = UNET_7_224()
# unet_model.compile(optimizer=Adam(lr=learningRate), loss=dice_coef_loss, metrics=metrics)
# unet_model.load_weights(preTrainedPath)

# pmap_fp = os.path.join(emfolder, 'pmap_baseline.tif')
# initial_pmap = emt.Get_Pmap(train_raster, WinShape, unet_model, pmap_fp)
    
# print("\nInitialized U_Net model.")
# print(dt.now().strftime('%a at %I:%M:%S%p'))

# # 6. Evaluate Unet Model
# # Save Training Results
# train_results = emt.Evaluate(X_train, Y_train, unet_model)
# # Save Validation Results
# val_results = emt.Evaluate(X_val, Y_val, unet_model)
# # Save Testing Results
# test_results = emt.Evaluate(X_test, Y_test, unet_model)

# y_pred=np.copy(unet_model.predict(X_test))
# y_pred = np.round(y_pred)
# y_true=np.copy(Y_test)
# y_pred.shape = y_pred.shape[0]* y_pred.shape[1]*y_pred.shape[2]* y_pred.shape[3]
# y_true.shape = y_true.shape[0]* y_true.shape[1]*y_true.shape[2]* y_true.shape[3]

# c_matrix = confusion_matrix(y_true, y_pred, labels=[0, 1])
# print("Confusion Matrix", c_matrix)
# report_unet = classification_report(y_true, y_pred)
# print("report_unet", report_unet)

# # Print the baseline metrics
# print("\nRan Initial U_Net evaluation:")
# print("\nBaseline Training Results:")
# print("- {}".format(train_results[0]))
# print("- {}".format(train_results[1]))
# print("\nBaseline Validation Results:")
# print("- {}".format(val_results[0]))
# print("- {}".format(val_results[1]))
# print("\nBaseline Testing Results:")
# print("- {}".format(test_results[0]))
# print("- {}".format(test_results[1]))
# print("\nBaseline Shape Metrics")
# print("- Precision: {:.2f}".format(sourcePrecision*100))
# print(dt.now().strftime('%a at %I:%M:%S%p'))


# # Save initial EM Data 
# test.Results("Baseline Data", {
#     'Precision': '{:.2f}%'.format(sourcePrecision*100),
#     'UNet: Training Results': train_results,
#     'UNet: Validation Results': val_results,
#     'UNet: Testing Results': test_results,
#     'UNet: Report': report_unet, 
#     'UNet: Confusion Matrix': c_matrix
# })


# # Create Matrix to save step data in seperate CSV
# dataMatrix = {
#     'precision': [sourcePrecision*100],
    
#     'trainDice': [train_results[0]],
#     'trainF1Score': [train_results[1]],
    
#     'valDice': [val_results[0]],
#     'valF1Score': [val_results[1]],
    
#     'testDice': [test_results[0]],
#     'testF1Score': [test_results[1]]
# }

# # --------------------
# section_data = {'time': time.time()-section_tstamp, 'stamp': section_tstamp}
# test.Section(section_name, section_data)
# # --------------------
# if test.verbose:
#     print("\n{} ({:02}) Complete.".format(section_name, len(test.sectionNames)))
#     print(dt.now().strftime('%a at %I:%M:%S%p'))

# %%
# 2. Check Array Shapes
print("-- Inputs  --")
for (title, arr) in [('X_train',X_train), ('X_val',X_val), ('X_test',X_test), ('Y_test',Y_test)]:
    print("{} Shape: {}".format(title, arr.shape))

if load_candidates:
    # 3. Load Candidates 
    candidateFrames = lg.LoadCandidates(CandidateDirectory)
    print("\n-- Candidates  --")
    print("Loaded Candidate Frames: {}".format(len(candidateFrames)))
    print("Candidates Per Segment (~): {}".format(len(candidateFrames[0].geometry)))

    # 4. Add Windows and Masks to candidates
    tstamp = time.time()
    candidateFrames = [emt.CandidateWindows(initial_pmap, c_frame, weightBuffer, convert_crs=False) for c_frame in candidateFrames]
    # %store candidateFrames
else:
    # %store -r candidateFrames
    print("Recalled {} candidate frames.".format(len(candidateFrames)))


# --------------------
section_data = {'time': time.time()-section_tstamp, 'stamp': section_tstamp}
test.Section(section_name, section_data)
# --------------------
if test.verbose:
    print("\n{} ({:02}) Complete.".format(section_name, len(test.sectionNames)))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
# Out:
# -- Inputs  --
# X_train Shape: (1008, 224, 224, 7)
# X_val Shape: (60, 224, 224, 7)
# X_test Shape: (300, 224, 224, 7)
# Y_test Shape: (300, 224, 224, 1)
#
# -- Candidates  --
# Loaded Candidate Frames: 547
# Candidates Per Segment (~): 61
# Stored 'candidateFrames' (list)
#
# Prepare Model (02) Complete.
# Sat at 11:30:46PM

# %%
print(candidateFrames[0].crs)
print(train_raster.crs)
# Out:
# epsg:26915
# EPSG:26915

# %% [markdown]
# ## EM Iteration

# %%
# Prepare EM iterator index.
#labelBuffer = wrap( 15 , TensorConfig)
EM_iterator = 0
dropval = 0.5
learningRate = 0.1
print("Target Steps:", EM_target)
print(rebuild_model)

import random

# -----------------------------------------------------------------------------
# Begin Iteration -------------------------------------------------------------
while EM_iterator < EM_target:   
    
    # ---------------------------
    # 0. Initialization
    # ---------------------------
    section_tstamp = time.time()
    section_name = 'EM_Step {:02}'.format(EM_iterator)

    # Create folder for em step
    emfolder = os.path.join(test.dir, 'Step_{:02}'.format(EM_iterator))
    if not os.path.exists(emfolder): os.mkdir(emfolder)

    print("\n\nEM Step {:02} begun.".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    anno_stamp = time.time()
    
    # ---------------------------
    # 1. Creating New Annotations
    # ---------------------------

    # 1.1 Get probability output map from last model (Skip first step since it was pre-generated)
    pmap_fp = os.path.join(emfolder, 'pmap_{:02}.tif'.format(EM_iterator))
    p_output = emt.Get_Pmap(train_raster, WinShape, deeplab_model, pmap_fp)
    
    print("\nGenerated Probability Output Map from previous model. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    
    # 1.2 Weight Candidate Frames
    newSegments = []
    for frame in candidateFrames:
        
        # Get Candidate Weights
        weightedFrame = emt.WeightCandidates(p_output, frame)
        
        # Select Likely or Top Candidate 
        if random.uniform(0,1) < random_candidate_chance:
            # Use 'likely' candidate (ENSURE Select_Candidate() FUNCTION IS UPDATED (lib/EMTools.py))
            newSegments.append(emt.Select_Candidate(weightedFrame, 'weight', weight_limit, default_random=default_random))
        else:
            # Use top candidate
            newSegments.append(emt.Top_Candidate(weightedFrame, 'weight', default_random=default_random))
            
            
        
    # 1.3 Convert List of segments to GeoDataFrame
    newSegmentFrame = gpd.GeoDataFrame(geometry=newSegments, crs=candidateFrames[0].crs)
    newSegmentFrame.to_file(os.path.join(emfolder, 'segments_{:02}.shp'.format(EM_iterator)))

    # 1.4 Connect top segments:
    newAnnotation = emt.Connect_Lines(newSegmentFrame, maxRepairDist)
    newAnnotation.to_file(os.path.join(emfolder, 'annotation_{:02}.shp'.format(EM_iterator)))

    # 1.5 Save mean precision of this annotation.
    annoPrecision = emt.GDF_Precision(gt_labels, newAnnotation, precisionBuffer)

    
    print("\nCreated New Annotation. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    anno_time = time.time() - anno_stamp
    
    # ---------------------------
    # 2. Create new Label Tensors
    # ---------------------------
    
    # 2.1 Rasterize New Labels
    buff_anno = st.GDF_Buffer(newAnnotation, labelBuffer, flatten=True)
    anno_raster = st.GDF_Rasterize(buff_anno, train_raster)
    
    # 2.2 Read Y_train, Y_val
    Y_train = gt.ResampleTiles(anno_raster, train_offsets_fp)
    Y_val = gt.ResampleTiles(anno_raster, val_offsets_fp)
    
    # 2.2 Augment Y_train, Y_val - NOTE: set horizontal flip to FALSE from Sultan's Setup
    Y_train = gt.AugmentImages(Y_train, h_flip=False, v_flip=train_v_flip, rotate=train_rotate)
    Y_val = gt.AugmentImages(Y_val, h_flip=False, v_flip=val_v_flip, rotate=val_rotate)
    
    print("\nCreated Y_train {} and Y_val {}. (Step {:02})".format(Y_train.shape, Y_val.shape, EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    
    
    # ---------------------------
    # 3. Re-Train U-Net 
    # ---------------------------
    
    # 3.1 Load Callbacks 
    callbacks = SetCallbacks(emfolder + '/model_{:02}.h5'.format(EM_iterator))
    
    # 3.2 Determine Learning Rate from schedule
    #EM_learningRate = Step_LR_Schedule(learningRate, EM_iterator, EM_target, lr_const)
    EM_learningRate = learningRate #(EM_iterator%2 + 1)*learningRate/2
    if EM_iterator > 5:
        EM_learningRate = learningRateReduced
    print("\nNew Learning Rate: {:.6f}. (Step {:02})".format(EM_learningRate, EM_iterator))
        
    training_stamp = time.time()
    with mirror_strategy.scope():
        deeplab_model = Deeplabv4(224, 224, dropout = 0.5) 
        deeplab_model.compile(optimizer=Adam(lr=learningRate), loss=dice_coef_loss, metrics=metrics)
        TrainData = deeplab_model.fit(X_train, Y_train, validation_data=(X_val, Y_val), shuffle=useShuffle, batch_size=batchSize, epochs=epochs, callbacks=callbacks)
    training_time = time.time() - training_stamp
    
    training_metrics = {
        'f1': Get_Metric_Data(TrainData, 'f1_score'),
        'dice_coef': Get_Metric_Data(TrainData, 'dice_coef'),
        'loss': Get_Metric_Data(TrainData, 'loss')
    }

    train_metrics_fp = os.path.join(emfolder, 'train_curve_{:02}.csv'.format(EM_iterator))
    with open(train_metrics_fp, 'a+', newline='\n') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter= ',')
        for key, data in training_metrics.items():
            csvwriter.writerow(['Training {}'.format(key)])
            csvwriter.writerow(data)
            
    validation_metrics = {
        'f1': Get_Metric_Data(TrainData, 'val_f1_score'),
        'dice_coef': Get_Metric_Data(TrainData, 'val_dice_coef'),
        'loss': Get_Metric_Data(TrainData, 'val_loss')
    }   
    val_metrics_fp = os.path.join(emfolder, 'val_curve_{:02}.csv'.format(EM_iterator))
    with open(val_metrics_fp, 'a+', newline='\n') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter= ',')
        for key, data in validation_metrics.items():
            csvwriter.writerow(['Validation {}'.format(key)])
            csvwriter.writerow(data)
    
    SaveHistory(TrainData, os.path.join(emfolder, 'trainingResults_{:02}'.format(EM_iterator)), test.end) # Save Plots
    
    print("\nCompleted UNet Training. (Step {:02})".format(EM_iterator))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    


    # ---------------------------
    # 4. Evaluate Model
    # ---------------------------

    
    # Training Results
    train_results = emt.Evaluate(X_train, Y_train, deeplab_model)
    # Validation Results
    val_results = emt.Evaluate(X_val, Y_val, deeplab_model)
    # Testing Results
    test_results = emt.Evaluate(X_test, Y_test, deeplab_model)

    
    
    # print
    print("\nCompleted Unet Evaluation. (Step {:02})".format(EM_iterator))
    print("\nTraining Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(train_results[0]))
    print("- {}".format(train_results[1]))
    print("\nValidation Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(val_results[0]))
    print("- {}".format(val_results[1]))   
    print("\nTesting Results (Step {:02}):".format(EM_iterator))
    print("- {}".format(test_results[0]))
    print("- {}".format(test_results[1]))
    print(dt.now().strftime('%a at %I:%M:%S%p'))

    y_pred=np.copy(deeplab_model.predict(X_test))
    y_pred = np.round(y_pred)
    y_true=np.copy(Y_test)
    y_pred.shape = y_pred.shape[0]* y_pred.shape[1]*y_pred.shape[2]* y_pred.shape[3]
    y_true.shape = y_true.shape[0]* y_true.shape[1]*y_true.shape[2]* y_true.shape[3]

    c_matrix = confusion_matrix(y_true, y_pred, labels=[0, 1])
    print("confusion_unet", c_matrix)
    report_unet = classification_report(y_true, y_pred)
    print("report_unet", report_unet)
    
    # ---------------------------
    # 5. Save Step Data
    # ---------------------------
    
    # Save to dict for seperate CSV
    dataMatrix['precision'].append(annoPrecision*100)
    dataMatrix['trainDice'].append(train_results[0]) 
    dataMatrix['trainF1Score'].append(train_results[1]) 
    dataMatrix['valDice'].append(val_results[0]) 
    dataMatrix['valF1Score'].append(val_results[1]) 
    dataMatrix['testDice'].append(test_results[0]) 
    dataMatrix['testF1Score'].append(test_results[1]) 
    
    
    # Save EM Step Data 
    test.Results("EM Data {:02}".format(EM_iterator), {
            
        'Time Elapsed: Re-training': training_time,
        'Time Elapsed: New Annotation': anno_time,
            
        'Precision': '{:.2f}%'.format(annoPrecision*100),
        'SourceDelta': '{:.2f}%'.format((annoPrecision-sourcePrecision)*100),
        'StepDelta': '{:.2f}%'.format((annoPrecision-prevPrecision)*100),
        
        'UNet: LR': str(EM_learningRate),
        'UNet: Epochs': str(len(TrainData.history['dice_coef'])),
        
        'UNet: Training Results': train_results,
        'UNet: Validation Results': val_results,
        'UNet: Testing Results': test_results,
        'UNet: Confusion Matrix': c_matrix,
        'UNet: Report': report_unet
    })
    # Save as section
    section_data = {'time': time.time()-section_tstamp, 'stamp': section_tstamp}
    test.Section(section_name, section_data)
    
    # Print step data
    print("\n{} ({:02}) Complete.".format(section_name, len(test.sectionNames)))
    print('- Precision: {:.2f}%'.format(annoPrecision*100))
    print('- SourceDelta: {:.2f}%'.format((annoPrecision-sourcePrecision)*100))
    print('- StepDelta: {:.2f}%'.format((annoPrecision-prevPrecision)*100))
    print(dt.now().strftime('%a at %I:%M:%S%p'))
    print("----------------------------------\n\n")
    
    # Increase iterator and save previous precision for step_delta
    EM_iterator += 1
    prevPrecision = annoPrecision
# Out:
# Target Steps: 6
# True
#
#
# EM Step 00 begun.
# Sat at 11:30:46PM
#
# Generated Probability Output Map from previous model. (Step 00)
# Sat at 11:30:48PM
#
# Created New Annotation. (Step 00)
# Sat at 11:31:56PM
# /home/jiang-ws1/.virtualenvs/geo_errors/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# Created Y_train (1008, 224, 224, 1) and Y_val (60, 224, 224, 1). (Step 00)
# Sat at 11:31:58PM
#
# New Learning Rate: 0.100000. (Step 00)
# *** Building DeepLabv3Plus Network ***
# *** Output_Shape => (None, 224, 224, 1) ***
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 69 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 69 all-reduces with algorithm = nccl, num_packs = 1
# 32/32 [==============================] - 6s 180ms/step - dice_coef: 0.3139 - accuracy: 0.5395 - f1_score: 0.3780 - loss: -0.3122 - val_dice_coef: 0.2075 - val_accuracy: 0.1251 - val_f1_score: 0.2075 - val_loss: -0.2113 - lr: 0.1000
# Epoch 2/50
# 32/32 [==============================] - 3s 91ms/step - dice_coef: 0.5556 - accuracy: 0.8408 - f1_score: 0.5898 - loss: -0.5548 - val_dice_coef: 0.2075 - val_accuracy: 0.1251 - val_f1_score: 0.2075 - val_loss: -0.2113 - lr: 0.1000
# Epoch 3/50
# 32/32 [==============================] - 3s 107ms/step - dice_coef: 0.6018 - accuracy: 0.8457 - f1_score: 0.6085 - loss: -0.5998 - val_dice_coef: 0.2094 - val_accuracy: 0.1583 - val_f1_score: 0.2094 - val_loss: -0.2132 - lr: 0.1000
# Epoch 4/50
# 32/32 [==============================] - 3s 105ms/step - dice_coef: 0.6234 - accuracy: 0.8542 - f1_score: 0.6274 - loss: -0.6232 - val_dice_coef: 0.2291 - val_accuracy: 0.3035 - val_f1_score: 0.2304 - val_loss: -0.2333 - lr: 0.1000
# Epoch 5/50
# 32/32 [==============================] - 4s 109ms/step - dice_coef: 0.6293 - accuracy: 0.8561 - f1_score: 0.6321 - loss: -0.6303 - val_dice_coef: 0.2650 - val_accuracy: 0.5042 - val_f1_score: 0.2652 - val_loss: -0.2701 - lr: 0.1000
# Epoch 6/50
# 32/32 [==============================] - 3s 107ms/step - dice_coef: 0.6510 - accuracy: 0.8613 - f1_score: 0.6532 - loss: -0.6507 - val_dice_coef: 0.2844 - val_accuracy: 0.6069 - val_f1_score: 0.2861 - val_loss: -0.2913 - lr: 0.1000
# Epoch 7/50
# 32/32 [==============================] - 3s 108ms/step - dice_coef: 0.6518 - accuracy: 0.8630 - f1_score: 0.6535 - loss: -0.6515 - val_dice_coef: 0.2906 - val_accuracy: 0.5359 - val_f1_score: 0.2917 - val_loss: -0.2961 - lr: 0.1000
# Epoch 8/50
# 32/32 [==============================] - 3s 109ms/step - dice_coef: 0.6614 - accuracy: 0.8642 - f1_score: 0.6628 - loss: -0.6610 - val_dice_coef: 0.3954 - val_accuracy: 0.7734 - val_f1_score: 0.3959 - val_loss: -0.4044 - lr: 0.1000
# Epoch 9/50
# 32/32 [==============================] - 3s 92ms/step - dice_coef: 0.6716 - accuracy: 0.8691 - f1_score: 0.6729 - loss: -0.6713 - val_dice_coef: 0.3302 - val_accuracy: 0.7295 - val_f1_score: 0.3300 - val_loss: -0.3398 - lr: 0.1000
# Epoch 10/50
# 32/32 [==============================] - 3s 93ms/step - dice_coef: 0.6892 - accuracy: 0.8733 - f1_score: 0.6903 - loss: -0.6899 - val_dice_coef: 0.3946 - val_accuracy: 0.7711 - val_f1_score: 0.3949 - val_loss: -0.4041 - lr: 0.1000
# Epoch 11/50
# 32/32 [==============================] - 4s 111ms/step - dice_coef: 0.7089 - accuracy: 0.8784 - f1_score: 0.7098 - loss: -0.7084 - val_dice_coef: 0.4312 - val_accuracy: 0.8378 - val_f1_score: 0.4314 - val_loss: -0.4427 - lr: 0.1000
# Epoch 12/50
# 32/32 [==============================] - 4s 110ms/step - dice_coef: 0.7328 - accuracy: 0.8839 - f1_score: 0.7337 - loss: -0.7331 - val_dice_coef: 0.4759 - val_accuracy: 0.8481 - val_f1_score: 0.4762 - val_loss: -0.4863 - lr: 0.1000
# Epoch 13/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.7265 - accuracy: 0.8832 - f1_score: 0.7273 - loss: -0.7262 - val_dice_coef: 0.3868 - val_accuracy: 0.8097 - val_f1_score: 0.3869 - val_loss: -0.3956 - lr: 0.1000
# Epoch 14/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.7478 - accuracy: 0.8878 - f1_score: 0.7485 - loss: -0.7481 - val_dice_coef: 0.2912 - val_accuracy: 0.8404 - val_f1_score: 0.2912 - val_loss: -0.2991 - lr: 0.1000
# Epoch 15/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.7619 - accuracy: 0.8923 - f1_score: 0.7626 - loss: -0.7622 - val_dice_coef: 0.2751 - val_accuracy: 0.8298 - val_f1_score: 0.2748 - val_loss: -0.2812 - lr: 0.1000
# Epoch 16/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.7639 - accuracy: 0.8925 - f1_score: 0.7645 - loss: -0.7664 - val_dice_coef: 0.4002 - val_accuracy: 0.8538 - val_f1_score: 0.4000 - val_loss: -0.4099 - lr: 0.1000
# Epoch 17/50
# 32/32 [==============================] - 4s 113ms/step - dice_coef: 0.7706 - accuracy: 0.8936 - f1_score: 0.7711 - loss: -0.7701 - val_dice_coef: 0.4806 - val_accuracy: 0.8683 - val_f1_score: 0.4808 - val_loss: -0.4915 - lr: 0.1000
# Epoch 18/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.7935 - accuracy: 0.8978 - f1_score: 0.7941 - loss: -0.7934 - val_dice_coef: 0.3391 - val_accuracy: 0.8446 - val_f1_score: 0.3391 - val_loss: -0.3487 - lr: 0.1000
# Epoch 19/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8073 - accuracy: 0.9023 - f1_score: 0.8078 - loss: -0.8075 - val_dice_coef: 0.4470 - val_accuracy: 0.8611 - val_f1_score: 0.4470 - val_loss: -0.4581 - lr: 0.1000
# Epoch 20/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8085 - accuracy: 0.9024 - f1_score: 0.8089 - loss: -0.8089 - val_dice_coef: 0.0076 - val_accuracy: 0.8170 - val_f1_score: 0.0073 - val_loss: -0.0072 - lr: 0.1000
# Epoch 21/50
# 32/32 [==============================] - 4s 112ms/step - dice_coef: 0.8055 - accuracy: 0.9021 - f1_score: 0.8059 - loss: -0.8056 - val_dice_coef: 0.5066 - val_accuracy: 0.8739 - val_f1_score: 0.5067 - val_loss: -0.5186 - lr: 0.1000
# Epoch 22/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8140 - accuracy: 0.9028 - f1_score: 0.8144 - loss: -0.8140 - val_dice_coef: 0.3012 - val_accuracy: 0.6273 - val_f1_score: 0.3013 - val_loss: -0.3072 - lr: 0.1000
# Epoch 23/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8297 - accuracy: 0.9066 - f1_score: 0.8300 - loss: -0.8294 - val_dice_coef: 0.4393 - val_accuracy: 0.8499 - val_f1_score: 0.4394 - val_loss: -0.4494 - lr: 0.1000
# Epoch 24/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8263 - accuracy: 0.9072 - f1_score: 0.8267 - loss: -0.8258 - val_dice_coef: 0.4985 - val_accuracy: 0.8652 - val_f1_score: 0.4985 - val_loss: -0.5103 - lr: 0.1000
# Epoch 25/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8446 - accuracy: 0.9094 - f1_score: 0.8449 - loss: -0.8442 - val_dice_coef: 0.4789 - val_accuracy: 0.8688 - val_f1_score: 0.4789 - val_loss: -0.4892 - lr: 0.1000
# Epoch 26/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8469 - accuracy: 0.9104 - f1_score: 0.8472 - loss: -0.8462
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8469 - accuracy: 0.9104 - f1_score: 0.8472 - loss: -0.8462 - val_dice_coef: 0.2388 - val_accuracy: 0.8361 - val_f1_score: 0.2387 - val_loss: -0.2426 - lr: 0.1000
# Epoch 27/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8681 - accuracy: 0.9141 - f1_score: 0.8684 - loss: -0.8682 - val_dice_coef: 0.3924 - val_accuracy: 0.8536 - val_f1_score: 0.3922 - val_loss: -0.4002 - lr: 0.0500
# Epoch 28/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8809 - accuracy: 0.9164 - f1_score: 0.8812 - loss: -0.8812 - val_dice_coef: 0.4386 - val_accuracy: 0.8616 - val_f1_score: 0.4385 - val_loss: -0.4477 - lr: 0.0500
# Epoch 29/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8782 - accuracy: 0.9172 - f1_score: 0.8785 - loss: -0.8780 - val_dice_coef: 0.3744 - val_accuracy: 0.8523 - val_f1_score: 0.3742 - val_loss: -0.3818 - lr: 0.0500
# Epoch 30/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8893 - accuracy: 0.9184 - f1_score: 0.8896 - loss: -0.8891 - val_dice_coef: 0.4715 - val_accuracy: 0.8682 - val_f1_score: 0.4714 - val_loss: -0.4811 - lr: 0.0500
# Epoch 31/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8780 - accuracy: 0.9164 - f1_score: 0.8783 - loss: -0.8780
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8780 - accuracy: 0.9164 - f1_score: 0.8783 - loss: -0.8780 - val_dice_coef: 0.4322 - val_accuracy: 0.8613 - val_f1_score: 0.4321 - val_loss: -0.4420 - lr: 0.0500
# Epoch 32/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8901 - accuracy: 0.9183 - f1_score: 0.8904 - loss: -0.8907 - val_dice_coef: 0.4471 - val_accuracy: 0.8654 - val_f1_score: 0.4469 - val_loss: -0.4561 - lr: 0.0250
# Epoch 33/50
# 32/32 [==============================] - 3s 106ms/step - dice_coef: 0.8967 - accuracy: 0.9196 - f1_score: 0.8970 - loss: -0.8968 - val_dice_coef: 0.4400 - val_accuracy: 0.8632 - val_f1_score: 0.4399 - val_loss: -0.4488 - lr: 0.0250
# Epoch 34/50
# 32/32 [==============================] - 3s 92ms/step - dice_coef: 0.9020 - accuracy: 0.9207 - f1_score: 0.9023 - loss: -0.9023 - val_dice_coef: 0.4937 - val_accuracy: 0.8760 - val_f1_score: 0.4937 - val_loss: -0.5042 - lr: 0.0250
# Epoch 35/50
# 32/32 [==============================] - 4s 112ms/step - dice_coef: 0.8980 - accuracy: 0.9203 - f1_score: 0.8983 - loss: -0.8977 - val_dice_coef: 0.4674 - val_accuracy: 0.8690 - val_f1_score: 0.4672 - val_loss: -0.4766 - lr: 0.0250
# Epoch 36/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8996 - accuracy: 0.9211 - f1_score: 0.8999 - loss: -0.8996
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 32/32 [==============================] - 3s 92ms/step - dice_coef: 0.8996 - accuracy: 0.9211 - f1_score: 0.8999 - loss: -0.8996 - val_dice_coef: 0.4538 - val_accuracy: 0.8659 - val_f1_score: 0.4535 - val_loss: -0.4628 - lr: 0.0250
# Epoch 37/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.9096 - accuracy: 0.9223 - f1_score: 0.9099 - loss: -0.9097 - val_dice_coef: 0.4561 - val_accuracy: 0.8664 - val_f1_score: 0.4559 - val_loss: -0.4654 - lr: 0.0125
# Epoch 38/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.9110 - accuracy: 0.9223 - f1_score: 0.9112 - loss: -0.9111 - val_dice_coef: 0.4731 - val_accuracy: 0.8697 - val_f1_score: 0.4731 - val_loss: -0.4830 - lr: 0.0125
# Epoch 39/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.9053 - accuracy: 0.9221 - f1_score: 0.9056 - loss: -0.9089 - val_dice_coef: 0.4734 - val_accuracy: 0.8699 - val_f1_score: 0.4734 - val_loss: -0.4830 - lr: 0.0125
# Epoch 40/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.9152 - accuracy: 0.9233 - f1_score: 0.9155 - loss: -0.9152 - val_dice_coef: 0.4803 - val_accuracy: 0.8719 - val_f1_score: 0.4803 - val_loss: -0.4897 - lr: 0.0125
# Epoch 41/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.9088 - accuracy: 0.9231 - f1_score: 0.9091 - loss: -0.9086
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.9088 - accuracy: 0.9231 - f1_score: 0.9091 - loss: -0.9086 - val_dice_coef: 0.4652 - val_accuracy: 0.8680 - val_f1_score: 0.4651 - val_loss: -0.4746 - lr: 0.0125
#
# Completed UNet Training. (Step 00)
# Sat at 11:34:33PM
#
# Completed Unet Evaluation. (Step 00)
#
# Training Results (Step 00):
# - Dice Coef: 93.006%
# - F1 Score: 93.028%
#
# Validation Results (Step 00):
# - Dice Coef: 62.674%
# - F1 Score: 62.664%
#
# Testing Results (Step 00):
# - Dice Coef: 68.127%
# - F1 Score: 68.145%
# Sat at 11:34:41PM
# confusion_unet [[13252643   466243]
#  [  403553   930361]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97  13718886
#          1.0       0.67      0.70      0.68   1333914
#
#     accuracy                           0.94  15052800
#    macro avg       0.82      0.83      0.82  15052800
# weighted avg       0.94      0.94      0.94  15052800
#
#
# EM_Step 00 (03) Complete.
# - Precision: 38.15%
# - SourceDelta: 9.45%
# - StepDelta: 9.45%
# Sat at 11:35:52PM
# ----------------------------------
#
#
#
#
# EM Step 01 begun.
# Sat at 11:35:52PM
#
# Generated Probability Output Map from previous model. (Step 01)
# Sat at 11:35:54PM
#
# Created New Annotation. (Step 01)
# Sat at 11:37:02PM
#
# Created Y_train (1008, 224, 224, 1) and Y_val (60, 224, 224, 1). (Step 01)
# Sat at 11:37:05PM
#
# New Learning Rate: 0.100000. (Step 01)
# *** Building DeepLabv3Plus Network ***
# *** Output_Shape => (None, 224, 224, 1) ***
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 69 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 69 all-reduces with algorithm = nccl, num_packs = 1
# 32/32 [==============================] - 6s 184ms/step - dice_coef: 0.3690 - accuracy: 0.5543 - f1_score: 0.3773 - loss: -0.3663 - val_dice_coef: 0.1941 - val_accuracy: 0.1156 - val_f1_score: 0.1941 - val_loss: -0.1976 - lr: 0.1000
# Epoch 2/50
# 32/32 [==============================] - 3s 91ms/step - dice_coef: 0.6115 - accuracy: 0.8497 - f1_score: 0.6118 - loss: -0.6105 - val_dice_coef: 0.1941 - val_accuracy: 0.1156 - val_f1_score: 0.1941 - val_loss: -0.1976 - lr: 0.1000
# Epoch 3/50
# 32/32 [==============================] - 3s 108ms/step - dice_coef: 0.6392 - accuracy: 0.8630 - f1_score: 0.6393 - loss: -0.6411 - val_dice_coef: 0.1942 - val_accuracy: 0.1178 - val_f1_score: 0.1942 - val_loss: -0.1977 - lr: 0.1000
# Epoch 4/50
# 32/32 [==============================] - 3s 106ms/step - dice_coef: 0.6587 - accuracy: 0.8687 - f1_score: 0.6587 - loss: -0.6570 - val_dice_coef: 0.2066 - val_accuracy: 0.2285 - val_f1_score: 0.2066 - val_loss: -0.2104 - lr: 0.1000
# Epoch 5/50
# 32/32 [==============================] - 3s 107ms/step - dice_coef: 0.6828 - accuracy: 0.8730 - f1_score: 0.6828 - loss: -0.6815 - val_dice_coef: 0.2764 - val_accuracy: 0.6000 - val_f1_score: 0.2764 - val_loss: -0.2823 - lr: 0.1000
# Epoch 6/50
# 32/32 [==============================] - 3s 93ms/step - dice_coef: 0.7013 - accuracy: 0.8798 - f1_score: 0.7014 - loss: -0.7011 - val_dice_coef: 0.1885 - val_accuracy: 0.7724 - val_f1_score: 0.1884 - val_loss: -0.1928 - lr: 0.1000
# Epoch 7/50
# 32/32 [==============================] - 3s 109ms/step - dice_coef: 0.6940 - accuracy: 0.8801 - f1_score: 0.6941 - loss: -0.6993 - val_dice_coef: 0.5941 - val_accuracy: 0.8475 - val_f1_score: 0.3443 - val_loss: -0.5857 - lr: 0.1000
# Epoch 8/50
# 32/32 [==============================] - 3s 92ms/step - dice_coef: 0.7155 - accuracy: 0.8837 - f1_score: 0.7156 - loss: -0.7158 - val_dice_coef: 0.4938 - val_accuracy: 0.8091 - val_f1_score: 0.2441 - val_loss: -0.4812 - lr: 0.1000
# Epoch 9/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.7230 - accuracy: 0.8860 - f1_score: 0.7231 - loss: -0.7220 - val_dice_coef: 0.2548 - val_accuracy: 0.8076 - val_f1_score: 0.2548 - val_loss: -0.2595 - lr: 0.1000
# Epoch 10/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.7200 - accuracy: 0.8841 - f1_score: 0.7200 - loss: -0.7198 - val_dice_coef: 0.5703 - val_accuracy: 0.8280 - val_f1_score: 0.3210 - val_loss: -0.5596 - lr: 0.1000
# Epoch 11/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.7192 - accuracy: 0.8850 - f1_score: 0.7192 - loss: -0.7195 - val_dice_coef: 0.5610 - val_accuracy: 0.8177 - val_f1_score: 0.3134 - val_loss: -0.5517 - lr: 0.1000
# Epoch 12/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.7290 - accuracy: 0.8890 - f1_score: 0.7291 - loss: -0.7294
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.7290 - accuracy: 0.8890 - f1_score: 0.7291 - loss: -0.7294 - val_dice_coef: 0.3641 - val_accuracy: 0.7986 - val_f1_score: 0.3641 - val_loss: -0.3712 - lr: 0.1000
# Epoch 13/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.7480 - accuracy: 0.8910 - f1_score: 0.7480 - loss: -0.7472 - val_dice_coef: 0.2104 - val_accuracy: 0.8068 - val_f1_score: 0.2104 - val_loss: -0.2143 - lr: 0.0500
# Epoch 14/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.7574 - accuracy: 0.8945 - f1_score: 0.7575 - loss: -0.7565 - val_dice_coef: 0.4706 - val_accuracy: 0.8190 - val_f1_score: 0.2297 - val_loss: -0.4589 - lr: 0.0500
# Epoch 15/50
# 32/32 [==============================] - 3s 104ms/step - dice_coef: 0.7759 - accuracy: 0.8977 - f1_score: 0.7760 - loss: -0.7762 - val_dice_coef: 0.4774 - val_accuracy: 0.8301 - val_f1_score: 0.2401 - val_loss: -0.4654 - lr: 0.0500
# Epoch 16/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.7732 - accuracy: 0.8983 - f1_score: 0.7733 - loss: -0.7760 - val_dice_coef: 0.5099 - val_accuracy: 0.8415 - val_f1_score: 0.2675 - val_loss: -0.4994 - lr: 0.0500
# Epoch 17/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.7822 - accuracy: 0.8997 - f1_score: 0.7823 - loss: -0.7844
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.7822 - accuracy: 0.8997 - f1_score: 0.7823 - loss: -0.7844 - val_dice_coef: 0.5385 - val_accuracy: 0.8520 - val_f1_score: 0.3059 - val_loss: -0.5293 - lr: 0.0500
# Epoch 18/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.7799 - accuracy: 0.8989 - f1_score: 0.7800 - loss: -0.7789 - val_dice_coef: 0.5659 - val_accuracy: 0.8506 - val_f1_score: 0.3426 - val_loss: -0.5581 - lr: 0.0250
# Epoch 19/50
# 32/32 [==============================] - 4s 119ms/step - dice_coef: 0.7956 - accuracy: 0.9019 - f1_score: 0.7956 - loss: -0.7952 - val_dice_coef: 0.5953 - val_accuracy: 0.8564 - val_f1_score: 0.3654 - val_loss: -0.5874 - lr: 0.0250
# Epoch 20/50
# 32/32 [==============================] - 4s 111ms/step - dice_coef: 0.8088 - accuracy: 0.9043 - f1_score: 0.8089 - loss: -0.8088 - val_dice_coef: 0.6003 - val_accuracy: 0.8566 - val_f1_score: 0.3619 - val_loss: -0.5919 - lr: 0.0250
# Epoch 21/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8048 - accuracy: 0.9041 - f1_score: 0.8049 - loss: -0.8081 - val_dice_coef: 0.5987 - val_accuracy: 0.8503 - val_f1_score: 0.3582 - val_loss: -0.5903 - lr: 0.0250
# Epoch 22/50
# 32/32 [==============================] - 3s 98ms/step - dice_coef: 0.8085 - accuracy: 0.9049 - f1_score: 0.8086 - loss: -0.8114 - val_dice_coef: 0.5924 - val_accuracy: 0.8575 - val_f1_score: 0.3551 - val_loss: -0.5843 - lr: 0.0250
# Epoch 23/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8153 - accuracy: 0.9059 - f1_score: 0.8153 - loss: -0.8153 - val_dice_coef: 0.5558 - val_accuracy: 0.8491 - val_f1_score: 0.3158 - val_loss: -0.5474 - lr: 0.0250
# Epoch 24/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8251 - accuracy: 0.9075 - f1_score: 0.8252 - loss: -0.8249 - val_dice_coef: 0.5865 - val_accuracy: 0.8549 - val_f1_score: 0.3566 - val_loss: -0.5790 - lr: 0.0250
# Epoch 25/50
# 32/32 [==============================] - 4s 118ms/step - dice_coef: 0.8200 - accuracy: 0.9074 - f1_score: 0.8201 - loss: -0.8200 - val_dice_coef: 0.6019 - val_accuracy: 0.8571 - val_f1_score: 0.3673 - val_loss: -0.5942 - lr: 0.0250
# Epoch 26/50
# 32/32 [==============================] - 3s 93ms/step - dice_coef: 0.8339 - accuracy: 0.9091 - f1_score: 0.8340 - loss: -0.8337 - val_dice_coef: 0.5259 - val_accuracy: 0.8507 - val_f1_score: 0.2940 - val_loss: -0.5174 - lr: 0.0250
# Epoch 27/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8321 - accuracy: 0.9091 - f1_score: 0.8321 - loss: -0.8317 - val_dice_coef: 0.5870 - val_accuracy: 0.8524 - val_f1_score: 0.3552 - val_loss: -0.5802 - lr: 0.0250
# Epoch 28/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8385 - accuracy: 0.9103 - f1_score: 0.8386 - loss: -0.8385 - val_dice_coef: 0.5441 - val_accuracy: 0.8497 - val_f1_score: 0.3065 - val_loss: -0.5351 - lr: 0.0250
# Epoch 29/50
# 32/32 [==============================] - 4s 114ms/step - dice_coef: 0.8415 - accuracy: 0.9113 - f1_score: 0.8416 - loss: -0.8412 - val_dice_coef: 0.6406 - val_accuracy: 0.8553 - val_f1_score: 0.4026 - val_loss: -0.6336 - lr: 0.0250
# Epoch 30/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8399 - accuracy: 0.9117 - f1_score: 0.8399 - loss: -0.8428 - val_dice_coef: 0.6262 - val_accuracy: 0.8555 - val_f1_score: 0.3974 - val_loss: -0.6201 - lr: 0.0250
# Epoch 31/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8466 - accuracy: 0.9132 - f1_score: 0.8467 - loss: -0.8498 - val_dice_coef: 0.6315 - val_accuracy: 0.8560 - val_f1_score: 0.3918 - val_loss: -0.6247 - lr: 0.0250
# Epoch 32/50
# 32/32 [==============================] - 4s 110ms/step - dice_coef: 0.8516 - accuracy: 0.9141 - f1_score: 0.8516 - loss: -0.8557 - val_dice_coef: 0.6376 - val_accuracy: 0.8528 - val_f1_score: 0.4001 - val_loss: -0.6314 - lr: 0.0250
# Epoch 33/50
# 32/32 [==============================] - 4s 110ms/step - dice_coef: 0.8543 - accuracy: 0.9146 - f1_score: 0.8544 - loss: -0.8541 - val_dice_coef: 0.6537 - val_accuracy: 0.8586 - val_f1_score: 0.4123 - val_loss: -0.6477 - lr: 0.0250
# Epoch 34/50
# 32/32 [==============================] - 3s 109ms/step - dice_coef: 0.8560 - accuracy: 0.9145 - f1_score: 0.8561 - loss: -0.8557 - val_dice_coef: 0.6577 - val_accuracy: 0.8595 - val_f1_score: 0.4205 - val_loss: -0.6510 - lr: 0.0250
# Epoch 35/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8655 - accuracy: 0.9166 - f1_score: 0.8655 - loss: -0.8653 - val_dice_coef: 0.6490 - val_accuracy: 0.8558 - val_f1_score: 0.4094 - val_loss: -0.6423 - lr: 0.0250
# Epoch 36/50
# 32/32 [==============================] - 4s 112ms/step - dice_coef: 0.8660 - accuracy: 0.9172 - f1_score: 0.8661 - loss: -0.8658 - val_dice_coef: 0.6643 - val_accuracy: 0.8593 - val_f1_score: 0.4187 - val_loss: -0.6578 - lr: 0.0250
# Epoch 37/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8605 - accuracy: 0.9177 - f1_score: 0.8606 - loss: -0.8640 - val_dice_coef: 0.5595 - val_accuracy: 0.8510 - val_f1_score: 0.3170 - val_loss: -0.5509 - lr: 0.0250
# Epoch 38/50
# 32/32 [==============================] - 3s 101ms/step - dice_coef: 0.8774 - accuracy: 0.9181 - f1_score: 0.8775 - loss: -0.8775 - val_dice_coef: 0.5971 - val_accuracy: 0.8542 - val_f1_score: 0.3503 - val_loss: -0.5891 - lr: 0.0250
# Epoch 39/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8766 - accuracy: 0.9196 - f1_score: 0.8766 - loss: -0.8802 - val_dice_coef: 0.6538 - val_accuracy: 0.8597 - val_f1_score: 0.4061 - val_loss: -0.6467 - lr: 0.0250
# Epoch 40/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8721 - accuracy: 0.9193 - f1_score: 0.8722 - loss: -0.8758 - val_dice_coef: 0.6104 - val_accuracy: 0.8533 - val_f1_score: 0.3613 - val_loss: -0.6018 - lr: 0.0250
# Epoch 41/50
# 32/32 [==============================] - 4s 111ms/step - dice_coef: 0.8788 - accuracy: 0.9204 - f1_score: 0.8789 - loss: -0.8853 - val_dice_coef: 0.6867 - val_accuracy: 0.8582 - val_f1_score: 0.4405 - val_loss: -0.6801 - lr: 0.0250
# Epoch 42/50
# 32/32 [==============================] - 4s 111ms/step - dice_coef: 0.8870 - accuracy: 0.9206 - f1_score: 0.8871 - loss: -0.8867 - val_dice_coef: 0.6951 - val_accuracy: 0.8622 - val_f1_score: 0.4463 - val_loss: -0.6889 - lr: 0.0250
# Epoch 43/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9013 - accuracy: 0.9225 - f1_score: 0.9014 - loss: -0.9016 - val_dice_coef: 0.6548 - val_accuracy: 0.8589 - val_f1_score: 0.4063 - val_loss: -0.6484 - lr: 0.0250
# Epoch 44/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8944 - accuracy: 0.9223 - f1_score: 0.8944 - loss: -0.8982 - val_dice_coef: 0.6162 - val_accuracy: 0.8559 - val_f1_score: 0.3702 - val_loss: -0.6096 - lr: 0.0250
# Epoch 45/50
# 32/32 [==============================] - 3s 100ms/step - dice_coef: 0.8849 - accuracy: 0.9207 - f1_score: 0.8849 - loss: -0.8848 - val_dice_coef: 0.6392 - val_accuracy: 0.8535 - val_f1_score: 0.3914 - val_loss: -0.6320 - lr: 0.0250
# Epoch 46/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8912 - accuracy: 0.9222 - f1_score: 0.8912 - loss: -0.8909 - val_dice_coef: 0.6652 - val_accuracy: 0.8602 - val_f1_score: 0.4163 - val_loss: -0.6585 - lr: 0.0250
# Epoch 47/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.9066 - accuracy: 0.9239 - f1_score: 0.9067 - loss: -0.9069
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9066 - accuracy: 0.9239 - f1_score: 0.9067 - loss: -0.9069 - val_dice_coef: 0.6274 - val_accuracy: 0.8560 - val_f1_score: 0.3778 - val_loss: -0.6189 - lr: 0.0250
# Epoch 48/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9075 - accuracy: 0.9243 - f1_score: 0.9076 - loss: -0.9076 - val_dice_coef: 0.6136 - val_accuracy: 0.8565 - val_f1_score: 0.3639 - val_loss: -0.6047 - lr: 0.0125
# Epoch 49/50
# 32/32 [==============================] - 3s 101ms/step - dice_coef: 0.9102 - accuracy: 0.9243 - f1_score: 0.9103 - loss: -0.9100 - val_dice_coef: 0.6369 - val_accuracy: 0.8574 - val_f1_score: 0.3881 - val_loss: -0.6294 - lr: 0.0125
# Epoch 50/50
# 32/32 [==============================] - 3s 93ms/step - dice_coef: 0.9158 - accuracy: 0.9260 - f1_score: 0.9159 - loss: -0.9162 - val_dice_coef: 0.6329 - val_accuracy: 0.8555 - val_f1_score: 0.3834 - val_loss: -0.6253 - lr: 0.0125
#
# Completed UNet Training. (Step 01)
# Sat at 11:40:11PM
#
# Completed Unet Evaluation. (Step 01)
#
# Training Results (Step 01):
# - Dice Coef: 93.438%
# - F1 Score: 93.440%
#
# Validation Results (Step 01):
# - Dice Coef: 52.141%
# - F1 Score: 52.137%
#
# Testing Results (Step 01):
# - Dice Coef: 60.549%
# - F1 Score: 60.548%
# Sat at 11:40:18PM
# confusion_unet [[13141409   577477]
#  [  504017   829897]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96  13718886
#          1.0       0.59      0.62      0.61   1333914
#
#     accuracy                           0.93  15052800
#    macro avg       0.78      0.79      0.78  15052800
# weighted avg       0.93      0.93      0.93  15052800
#
#
# EM_Step 01 (04) Complete.
# - Precision: 32.75%
# - SourceDelta: 4.05%
# - StepDelta: -5.40%
# Sat at 11:41:29PM
# ----------------------------------
#
#
#
#
# EM Step 02 begun.
# Sat at 11:41:29PM
#
# Generated Probability Output Map from previous model. (Step 02)
# Sat at 11:41:31PM
#
# Created New Annotation. (Step 02)
# Sat at 11:42:40PM
#
# Created Y_train (1008, 224, 224, 1) and Y_val (60, 224, 224, 1). (Step 02)
# Sat at 11:42:43PM
#
# New Learning Rate: 0.100000. (Step 02)
# *** Building DeepLabv3Plus Network ***
# *** Output_Shape => (None, 224, 224, 1) ***
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 69 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 69 all-reduces with algorithm = nccl, num_packs = 1
# 32/32 [==============================] - 6s 189ms/step - dice_coef: 0.3557 - accuracy: 0.6566 - f1_score: 0.4449 - loss: -0.3546 - val_dice_coef: 0.2078 - val_accuracy: 0.1253 - val_f1_score: 0.2078 - val_loss: -0.2115 - lr: 0.1000
# Epoch 2/50
# 32/32 [==============================] - 3s 92ms/step - dice_coef: 0.5852 - accuracy: 0.8456 - f1_score: 0.6131 - loss: -0.5860 - val_dice_coef: 0.2078 - val_accuracy: 0.1253 - val_f1_score: 0.2078 - val_loss: -0.2115 - lr: 0.1000
# Epoch 3/50
# 32/32 [==============================] - 3s 106ms/step - dice_coef: 0.6432 - accuracy: 0.8607 - f1_score: 0.6512 - loss: -0.6435 - val_dice_coef: 0.2095 - val_accuracy: 0.1559 - val_f1_score: 0.2095 - val_loss: -0.2134 - lr: 0.1000
# Epoch 4/50
# 32/32 [==============================] - 3s 107ms/step - dice_coef: 0.6665 - accuracy: 0.8673 - f1_score: 0.6712 - loss: -0.6671 - val_dice_coef: 0.2877 - val_accuracy: 0.6032 - val_f1_score: 0.2929 - val_loss: -0.2937 - lr: 0.1000
# Epoch 5/50
# 32/32 [==============================] - 3s 92ms/step - dice_coef: 0.6593 - accuracy: 0.8677 - f1_score: 0.6626 - loss: -0.6612 - val_dice_coef: 0.2491 - val_accuracy: 0.4292 - val_f1_score: 0.2493 - val_loss: -0.2539 - lr: 0.1000
# Epoch 6/50
# 32/32 [==============================] - 3s 109ms/step - dice_coef: 0.7006 - accuracy: 0.8767 - f1_score: 0.7032 - loss: -0.6997 - val_dice_coef: 0.3044 - val_accuracy: 0.6233 - val_f1_score: 0.3049 - val_loss: -0.3108 - lr: 0.1000
# Epoch 7/50
# 32/32 [==============================] - 3s 108ms/step - dice_coef: 0.7198 - accuracy: 0.8809 - f1_score: 0.7218 - loss: -0.7217 - val_dice_coef: 0.4495 - val_accuracy: 0.8468 - val_f1_score: 0.4503 - val_loss: -0.4594 - lr: 0.1000
# Epoch 8/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.7159 - accuracy: 0.8819 - f1_score: 0.7176 - loss: -0.7182 - val_dice_coef: 0.3813 - val_accuracy: 0.8438 - val_f1_score: 0.3810 - val_loss: -0.3905 - lr: 0.1000
# Epoch 9/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.7360 - accuracy: 0.8863 - f1_score: 0.7375 - loss: -0.7391 - val_dice_coef: 0.2980 - val_accuracy: 0.8256 - val_f1_score: 0.2980 - val_loss: -0.3045 - lr: 0.1000
# Epoch 10/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.7361 - accuracy: 0.8856 - f1_score: 0.7373 - loss: -0.7357 - val_dice_coef: 0.3951 - val_accuracy: 0.8381 - val_f1_score: 0.3953 - val_loss: -0.4026 - lr: 0.1000
# Epoch 11/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.7534 - accuracy: 0.8902 - f1_score: 0.7544 - loss: -0.7560 - val_dice_coef: 0.2862 - val_accuracy: 0.8436 - val_f1_score: 0.2862 - val_loss: -0.2905 - lr: 0.1000
# Epoch 12/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.7551 - accuracy: 0.8907 - f1_score: 0.7561 - loss: -0.7577
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.7551 - accuracy: 0.8907 - f1_score: 0.7561 - loss: -0.7577 - val_dice_coef: 0.2355 - val_accuracy: 0.8182 - val_f1_score: 0.2351 - val_loss: -0.2408 - lr: 0.1000
# Epoch 13/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.7704 - accuracy: 0.8935 - f1_score: 0.7713 - loss: -0.7696 - val_dice_coef: 0.3763 - val_accuracy: 0.8617 - val_f1_score: 0.3764 - val_loss: -0.3835 - lr: 0.0500
# Epoch 14/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.7875 - accuracy: 0.8974 - f1_score: 0.7884 - loss: -0.7900 - val_dice_coef: 0.3190 - val_accuracy: 0.8478 - val_f1_score: 0.3181 - val_loss: -0.3245 - lr: 0.0500
# Epoch 15/50
# 32/32 [==============================] - 4s 110ms/step - dice_coef: 0.7984 - accuracy: 0.8991 - f1_score: 0.7993 - loss: -0.7984 - val_dice_coef: 0.4952 - val_accuracy: 0.8759 - val_f1_score: 0.4954 - val_loss: -0.5056 - lr: 0.0500
# Epoch 16/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.7916 - accuracy: 0.8989 - f1_score: 0.7925 - loss: -0.7910 - val_dice_coef: 0.2674 - val_accuracy: 0.8452 - val_f1_score: 0.2671 - val_loss: -0.2703 - lr: 0.0500
# Epoch 17/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8042 - accuracy: 0.9003 - f1_score: 0.8049 - loss: -0.8043 - val_dice_coef: 0.3681 - val_accuracy: 0.8585 - val_f1_score: 0.3679 - val_loss: -0.3742 - lr: 0.0500
# Epoch 18/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8088 - accuracy: 0.9013 - f1_score: 0.8095 - loss: -0.8092 - val_dice_coef: 0.3963 - val_accuracy: 0.8542 - val_f1_score: 0.3963 - val_loss: -0.4039 - lr: 0.0500
# Epoch 19/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8032 - accuracy: 0.9010 - f1_score: 0.8040 - loss: -0.8058 - val_dice_coef: 0.4470 - val_accuracy: 0.8655 - val_f1_score: 0.4471 - val_loss: -0.4560 - lr: 0.0500
# Epoch 20/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8111 - accuracy: 0.9029 - f1_score: 0.8117 - loss: -0.8109
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8111 - accuracy: 0.9029 - f1_score: 0.8117 - loss: -0.8109 - val_dice_coef: 0.4699 - val_accuracy: 0.8685 - val_f1_score: 0.4700 - val_loss: -0.4789 - lr: 0.0500
# Epoch 21/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8292 - accuracy: 0.9051 - f1_score: 0.8298 - loss: -0.8287 - val_dice_coef: 0.4838 - val_accuracy: 0.8742 - val_f1_score: 0.4839 - val_loss: -0.4938 - lr: 0.0250
# Epoch 22/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8257 - accuracy: 0.9056 - f1_score: 0.8263 - loss: -0.8252 - val_dice_coef: 0.4933 - val_accuracy: 0.8757 - val_f1_score: 0.4934 - val_loss: -0.5035 - lr: 0.0250
# Epoch 23/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8284 - accuracy: 0.9069 - f1_score: 0.8290 - loss: -0.8285 - val_dice_coef: 0.4729 - val_accuracy: 0.8712 - val_f1_score: 0.4730 - val_loss: -0.4825 - lr: 0.0250
# Epoch 24/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8281 - accuracy: 0.9064 - f1_score: 0.8287 - loss: -0.8272 - val_dice_coef: 0.4773 - val_accuracy: 0.8709 - val_f1_score: 0.4774 - val_loss: -0.4871 - lr: 0.0250
# Epoch 25/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8376 - accuracy: 0.9081 - f1_score: 0.8382 - loss: -0.8378
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 32/32 [==============================] - 3s 107ms/step - dice_coef: 0.8376 - accuracy: 0.9081 - f1_score: 0.8382 - loss: -0.8378 - val_dice_coef: 0.4502 - val_accuracy: 0.8672 - val_f1_score: 0.4502 - val_loss: -0.4590 - lr: 0.0250
# Epoch 26/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8442 - accuracy: 0.9096 - f1_score: 0.8447 - loss: -0.8441 - val_dice_coef: 0.4289 - val_accuracy: 0.8628 - val_f1_score: 0.4290 - val_loss: -0.4376 - lr: 0.0125
# Epoch 27/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8549 - accuracy: 0.9111 - f1_score: 0.8555 - loss: -0.8550 - val_dice_coef: 0.4493 - val_accuracy: 0.8673 - val_f1_score: 0.4493 - val_loss: -0.4582 - lr: 0.0125
# Epoch 28/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8491 - accuracy: 0.9110 - f1_score: 0.8497 - loss: -0.8525 - val_dice_coef: 0.4408 - val_accuracy: 0.8653 - val_f1_score: 0.4408 - val_loss: -0.4497 - lr: 0.0125
# Epoch 29/50
# 32/32 [==============================] - 3s 97ms/step - dice_coef: 0.8520 - accuracy: 0.9112 - f1_score: 0.8526 - loss: -0.8523 - val_dice_coef: 0.3784 - val_accuracy: 0.8562 - val_f1_score: 0.3783 - val_loss: -0.3847 - lr: 0.0125
# Epoch 30/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8553 - accuracy: 0.9117 - f1_score: 0.8559 - loss: -0.8553
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8553 - accuracy: 0.9117 - f1_score: 0.8559 - loss: -0.8553 - val_dice_coef: 0.4046 - val_accuracy: 0.8583 - val_f1_score: 0.4044 - val_loss: -0.4118 - lr: 0.0125
# Epoch 31/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8684 - accuracy: 0.9135 - f1_score: 0.8690 - loss: -0.8685 - val_dice_coef: 0.4097 - val_accuracy: 0.8601 - val_f1_score: 0.4095 - val_loss: -0.4175 - lr: 0.0063
# Epoch 32/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8721 - accuracy: 0.9148 - f1_score: 0.8727 - loss: -0.8721 - val_dice_coef: 0.4331 - val_accuracy: 0.8623 - val_f1_score: 0.4330 - val_loss: -0.4420 - lr: 0.0063
# Epoch 33/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8720 - accuracy: 0.9152 - f1_score: 0.8726 - loss: -0.8721 - val_dice_coef: 0.4311 - val_accuracy: 0.8630 - val_f1_score: 0.4310 - val_loss: -0.4398 - lr: 0.0063
# Epoch 34/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8634 - accuracy: 0.9143 - f1_score: 0.8640 - loss: -0.8671 - val_dice_coef: 0.3880 - val_accuracy: 0.8555 - val_f1_score: 0.3879 - val_loss: -0.3948 - lr: 0.0063
# Epoch 35/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8710 - accuracy: 0.9154 - f1_score: 0.8716 - loss: -0.8745
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8710 - accuracy: 0.9154 - f1_score: 0.8716 - loss: -0.8745 - val_dice_coef: 0.3897 - val_accuracy: 0.8558 - val_f1_score: 0.3895 - val_loss: -0.3966 - lr: 0.0063
#
# Completed UNet Training. (Step 02)
# Sat at 11:44:57PM
#
# Completed Unet Evaluation. (Step 02)
#
# Training Results (Step 02):
# - Dice Coef: 87.970%
# - F1 Score: 88.005%
#
# Validation Results (Step 02):
# - Dice Coef: 52.499%
# - F1 Score: 52.487%
#
# Testing Results (Step 02):
# - Dice Coef: 46.598%
# - F1 Score: 46.598%
# Sat at 11:45:05PM
# confusion_unet [[13420854   298032]
#  [  838183   495731]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.94      0.98      0.96  13718886
#          1.0       0.62      0.37      0.47   1333914
#
#     accuracy                           0.92  15052800
#    macro avg       0.78      0.67      0.71  15052800
# weighted avg       0.91      0.92      0.92  15052800
#
#
# EM_Step 02 (05) Complete.
# - Precision: 35.96%
# - SourceDelta: 7.26%
# - StepDelta: 3.21%
# Sat at 11:46:17PM
# ----------------------------------
#
#
#
#
# EM Step 03 begun.
# Sat at 11:46:17PM
#
# Generated Probability Output Map from previous model. (Step 03)
# Sat at 11:46:18PM
#
# Created New Annotation. (Step 03)
# Sat at 11:47:27PM
#
# Created Y_train (1008, 224, 224, 1) and Y_val (60, 224, 224, 1). (Step 03)
# Sat at 11:47:30PM
#
# New Learning Rate: 0.100000. (Step 03)
# *** Building DeepLabv3Plus Network ***
# *** Output_Shape => (None, 224, 224, 1) ***
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 69 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 69 all-reduces with algorithm = nccl, num_packs = 1
# 32/32 [==============================] - 6s 181ms/step - dice_coef: 0.3429 - accuracy: 0.6485 - f1_score: 0.4334 - loss: -0.3446 - val_dice_coef: 0.2040 - val_accuracy: 0.1225 - val_f1_score: 0.2040 - val_loss: -0.2077 - lr: 0.1000
# Epoch 2/50
# 32/32 [==============================] - 3s 91ms/step - dice_coef: 0.5354 - accuracy: 0.8317 - f1_score: 0.5628 - loss: -0.5386 - val_dice_coef: 0.2040 - val_accuracy: 0.1225 - val_f1_score: 0.2040 - val_loss: -0.2077 - lr: 0.1000
# Epoch 3/50
# 32/32 [==============================] - 3s 91ms/step - dice_coef: 0.5965 - accuracy: 0.8479 - f1_score: 0.6040 - loss: -0.5977 - val_dice_coef: 0.2040 - val_accuracy: 0.1225 - val_f1_score: 0.2040 - val_loss: -0.2077 - lr: 0.1000
# Epoch 4/50
# 32/32 [==============================] - 3s 109ms/step - dice_coef: 0.6061 - accuracy: 0.8504 - f1_score: 0.6104 - loss: -0.6094 - val_dice_coef: 0.2391 - val_accuracy: 0.4161 - val_f1_score: 0.2392 - val_loss: -0.2438 - lr: 0.1000
# Epoch 5/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.6431 - accuracy: 0.8597 - f1_score: 0.6465 - loss: -0.6442 - val_dice_coef: 0.2365 - val_accuracy: 0.4050 - val_f1_score: 0.2366 - val_loss: -0.2412 - lr: 0.1000
# Epoch 6/50
# 32/32 [==============================] - 4s 110ms/step - dice_coef: 0.6370 - accuracy: 0.8574 - f1_score: 0.6393 - loss: -0.6362 - val_dice_coef: 0.2862 - val_accuracy: 0.6806 - val_f1_score: 0.2864 - val_loss: -0.2925 - lr: 0.1000
# Epoch 7/50
# 32/32 [==============================] - 4s 111ms/step - dice_coef: 0.6495 - accuracy: 0.8624 - f1_score: 0.6513 - loss: -0.6509 - val_dice_coef: 0.3050 - val_accuracy: 0.6788 - val_f1_score: 0.3086 - val_loss: -0.3125 - lr: 0.1000
# Epoch 8/50
# 32/32 [==============================] - 3s 109ms/step - dice_coef: 0.6626 - accuracy: 0.8658 - f1_score: 0.6641 - loss: -0.6620 - val_dice_coef: 0.3125 - val_accuracy: 0.6821 - val_f1_score: 0.3130 - val_loss: -0.3194 - lr: 0.1000
# Epoch 9/50
# 32/32 [==============================] - 4s 110ms/step - dice_coef: 0.6566 - accuracy: 0.8650 - f1_score: 0.6579 - loss: -0.6558 - val_dice_coef: 0.3302 - val_accuracy: 0.7353 - val_f1_score: 0.3305 - val_loss: -0.3384 - lr: 0.1000
# Epoch 10/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.6784 - accuracy: 0.8705 - f1_score: 0.6795 - loss: -0.6784 - val_dice_coef: 0.2870 - val_accuracy: 0.8012 - val_f1_score: 0.2871 - val_loss: -0.2945 - lr: 0.1000
# Epoch 11/50
# 32/32 [==============================] - 4s 110ms/step - dice_coef: 0.7032 - accuracy: 0.8762 - f1_score: 0.7042 - loss: -0.7028 - val_dice_coef: 0.3449 - val_accuracy: 0.8186 - val_f1_score: 0.3451 - val_loss: -0.3559 - lr: 0.1000
# Epoch 12/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.6975 - accuracy: 0.8769 - f1_score: 0.6983 - loss: -0.7011 - val_dice_coef: 0.3392 - val_accuracy: 0.8130 - val_f1_score: 0.3393 - val_loss: -0.3472 - lr: 0.1000
# Epoch 13/50
# 32/32 [==============================] - 4s 110ms/step - dice_coef: 0.7093 - accuracy: 0.8794 - f1_score: 0.7101 - loss: -0.7099 - val_dice_coef: 0.3820 - val_accuracy: 0.8152 - val_f1_score: 0.3822 - val_loss: -0.3935 - lr: 0.1000
# Epoch 14/50
# 32/32 [==============================] - 4s 111ms/step - dice_coef: 0.7082 - accuracy: 0.8779 - f1_score: 0.7088 - loss: -0.7084 - val_dice_coef: 0.3849 - val_accuracy: 0.8281 - val_f1_score: 0.3851 - val_loss: -0.3953 - lr: 0.1000
# Epoch 15/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.7178 - accuracy: 0.8818 - f1_score: 0.7185 - loss: -0.7221 - val_dice_coef: 0.1624 - val_accuracy: 0.8282 - val_f1_score: 0.1622 - val_loss: -0.1670 - lr: 0.1000
# Epoch 16/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.7363 - accuracy: 0.8843 - f1_score: 0.7369 - loss: -0.7360 - val_dice_coef: 0.3090 - val_accuracy: 0.8396 - val_f1_score: 0.3092 - val_loss: -0.3221 - lr: 0.1000
# Epoch 17/50
# 32/32 [==============================] - 4s 112ms/step - dice_coef: 0.7471 - accuracy: 0.8871 - f1_score: 0.7477 - loss: -0.7463 - val_dice_coef: 0.4210 - val_accuracy: 0.8366 - val_f1_score: 0.4212 - val_loss: -0.4349 - lr: 0.1000
# Epoch 18/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.7593 - accuracy: 0.8916 - f1_score: 0.7598 - loss: -0.7597 - val_dice_coef: 0.2460 - val_accuracy: 0.8224 - val_f1_score: 0.2459 - val_loss: -0.2557 - lr: 0.1000
# Epoch 19/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.7553 - accuracy: 0.8894 - f1_score: 0.7557 - loss: -0.7543 - val_dice_coef: 0.4133 - val_accuracy: 0.8333 - val_f1_score: 0.4134 - val_loss: -0.4252 - lr: 0.1000
# Epoch 20/50
# 32/32 [==============================] - 4s 111ms/step - dice_coef: 0.7634 - accuracy: 0.8911 - f1_score: 0.7638 - loss: -0.7661 - val_dice_coef: 0.4352 - val_accuracy: 0.8505 - val_f1_score: 0.4353 - val_loss: -0.4494 - lr: 0.1000
# Epoch 21/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.7680 - accuracy: 0.8939 - f1_score: 0.7683 - loss: -0.7736 - val_dice_coef: 0.3990 - val_accuracy: 0.8497 - val_f1_score: 0.3990 - val_loss: -0.4116 - lr: 0.1000
# Epoch 22/50
# 32/32 [==============================] - 3s 107ms/step - dice_coef: 0.7736 - accuracy: 0.8938 - f1_score: 0.7740 - loss: -0.7733 - val_dice_coef: 0.3709 - val_accuracy: 0.8409 - val_f1_score: 0.3709 - val_loss: -0.3812 - lr: 0.1000
# Epoch 23/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8042 - accuracy: 0.8991 - f1_score: 0.8046 - loss: -0.8043 - val_dice_coef: 0.3235 - val_accuracy: 0.8430 - val_f1_score: 0.3234 - val_loss: -0.3360 - lr: 0.1000
# Epoch 24/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8165 - accuracy: 0.9017 - f1_score: 0.8169 - loss: -0.8164 - val_dice_coef: 0.4012 - val_accuracy: 0.8509 - val_f1_score: 0.4012 - val_loss: -0.4134 - lr: 0.1000
# Epoch 25/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8162 - accuracy: 0.9026 - f1_score: 0.8166 - loss: -0.8160
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8162 - accuracy: 0.9026 - f1_score: 0.8166 - loss: -0.8160 - val_dice_coef: 0.3572 - val_accuracy: 0.8478 - val_f1_score: 0.3571 - val_loss: -0.3698 - lr: 0.1000
# Epoch 26/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8410 - accuracy: 0.9075 - f1_score: 0.8414 - loss: -0.8408 - val_dice_coef: 0.2994 - val_accuracy: 0.8443 - val_f1_score: 0.2992 - val_loss: -0.3096 - lr: 0.0500
# Epoch 27/50
# 32/32 [==============================] - 4s 119ms/step - dice_coef: 0.8475 - accuracy: 0.9093 - f1_score: 0.8479 - loss: -0.8470 - val_dice_coef: 0.3117 - val_accuracy: 0.8458 - val_f1_score: 0.3116 - val_loss: -0.3228 - lr: 0.0500
# Epoch 28/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8714 - accuracy: 0.9127 - f1_score: 0.8717 - loss: -0.8711 - val_dice_coef: 0.3785 - val_accuracy: 0.8565 - val_f1_score: 0.3784 - val_loss: -0.3911 - lr: 0.0500
# Epoch 29/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8683 - accuracy: 0.9124 - f1_score: 0.8687 - loss: -0.8682 - val_dice_coef: 0.3634 - val_accuracy: 0.8538 - val_f1_score: 0.3633 - val_loss: -0.3748 - lr: 0.0500
# Epoch 30/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8607 - accuracy: 0.9120 - f1_score: 0.8611 - loss: -0.8646
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8607 - accuracy: 0.9120 - f1_score: 0.8611 - loss: -0.8646 - val_dice_coef: 0.3252 - val_accuracy: 0.8475 - val_f1_score: 0.3250 - val_loss: -0.3361 - lr: 0.0500
# Epoch 31/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8757 - accuracy: 0.9150 - f1_score: 0.8761 - loss: -0.8756 - val_dice_coef: 0.3399 - val_accuracy: 0.8494 - val_f1_score: 0.3397 - val_loss: -0.3513 - lr: 0.0250
# Epoch 32/50
# 32/32 [==============================] - 3s 102ms/step - dice_coef: 0.8804 - accuracy: 0.9158 - f1_score: 0.8807 - loss: -0.8802 - val_dice_coef: 0.3413 - val_accuracy: 0.8486 - val_f1_score: 0.3411 - val_loss: -0.3528 - lr: 0.0250
# Epoch 33/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8852 - accuracy: 0.9162 - f1_score: 0.8856 - loss: -0.8852 - val_dice_coef: 0.3458 - val_accuracy: 0.8503 - val_f1_score: 0.3456 - val_loss: -0.3573 - lr: 0.0250
# Epoch 34/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8820 - accuracy: 0.9163 - f1_score: 0.8823 - loss: -0.8818 - val_dice_coef: 0.3385 - val_accuracy: 0.8487 - val_f1_score: 0.3384 - val_loss: -0.3500 - lr: 0.0250
# Epoch 35/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8952 - accuracy: 0.9185 - f1_score: 0.8956 - loss: -0.8954
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 32/32 [==============================] - 3s 98ms/step - dice_coef: 0.8952 - accuracy: 0.9185 - f1_score: 0.8956 - loss: -0.8954 - val_dice_coef: 0.3222 - val_accuracy: 0.8469 - val_f1_score: 0.3220 - val_loss: -0.3325 - lr: 0.0250
# Epoch 36/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.9013 - accuracy: 0.9195 - f1_score: 0.9017 - loss: -0.9018 - val_dice_coef: 0.3541 - val_accuracy: 0.8521 - val_f1_score: 0.3539 - val_loss: -0.3657 - lr: 0.0125
# Epoch 37/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9007 - accuracy: 0.9195 - f1_score: 0.9010 - loss: -0.9006 - val_dice_coef: 0.3348 - val_accuracy: 0.8507 - val_f1_score: 0.3346 - val_loss: -0.3458 - lr: 0.0125
# Epoch 38/50
# ...
# Epoch 26/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8589 - accuracy: 0.9104 - f1_score: 0.8589 - loss: -0.8604
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8589 - accuracy: 0.9104 - f1_score: 0.8589 - loss: -0.8604 - val_dice_coef: 0.5951 - val_accuracy: 0.8537 - val_f1_score: 0.3678 - val_loss: -0.5930 - lr: 0.0250
# Epoch 27/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8637 - accuracy: 0.9120 - f1_score: 0.8638 - loss: -0.8673 - val_dice_coef: 0.6468 - val_accuracy: 0.8594 - val_f1_score: 0.4122 - val_loss: -0.6454 - lr: 0.0125
# Epoch 28/50
# 32/32 [==============================] - 3s 100ms/step - dice_coef: 0.8725 - accuracy: 0.9126 - f1_score: 0.8725 - loss: -0.8728 - val_dice_coef: 0.5925 - val_accuracy: 0.8547 - val_f1_score: 0.3844 - val_loss: -0.5925 - lr: 0.0125
# Epoch 29/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8804 - accuracy: 0.9138 - f1_score: 0.8805 - loss: -0.8807 - val_dice_coef: 0.6220 - val_accuracy: 0.8576 - val_f1_score: 0.4123 - val_loss: -0.6223 - lr: 0.0125
# Epoch 30/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8765 - accuracy: 0.9138 - f1_score: 0.8765 - loss: -0.8768 - val_dice_coef: 0.6214 - val_accuracy: 0.8565 - val_f1_score: 0.3964 - val_loss: -0.6207 - lr: 0.0125
# Epoch 31/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8768 - accuracy: 0.9138 - f1_score: 0.8768 - loss: -0.8768
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8768 - accuracy: 0.9138 - f1_score: 0.8768 - loss: -0.8768 - val_dice_coef: 0.5710 - val_accuracy: 0.8515 - val_f1_score: 0.3350 - val_loss: -0.5685 - lr: 0.0125
# Epoch 32/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8870 - accuracy: 0.9152 - f1_score: 0.8870 - loss: -0.8866 - val_dice_coef: 0.6343 - val_accuracy: 0.8587 - val_f1_score: 0.4042 - val_loss: -0.6331 - lr: 0.0063
# Epoch 33/50
# 32/32 [==============================] - 3s 109ms/step - dice_coef: 0.8902 - accuracy: 0.9162 - f1_score: 0.8902 - loss: -0.8903 - val_dice_coef: 0.6020 - val_accuracy: 0.8553 - val_f1_score: 0.3799 - val_loss: -0.6011 - lr: 0.0063
# Epoch 34/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8822 - accuracy: 0.9159 - f1_score: 0.8822 - loss: -0.8856 - val_dice_coef: 0.6033 - val_accuracy: 0.8565 - val_f1_score: 0.3800 - val_loss: -0.6022 - lr: 0.0063
# Epoch 35/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8936 - accuracy: 0.9166 - f1_score: 0.8936 - loss: -0.8934 - val_dice_coef: 0.6052 - val_accuracy: 0.8559 - val_f1_score: 0.3830 - val_loss: -0.6046 - lr: 0.0063
# Epoch 36/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8892 - accuracy: 0.9165 - f1_score: 0.8893 - loss: -0.8889
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8892 - accuracy: 0.9165 - f1_score: 0.8893 - loss: -0.8889 - val_dice_coef: 0.6355 - val_accuracy: 0.8586 - val_f1_score: 0.4102 - val_loss: -0.6345 - lr: 0.0063
# Epoch 37/50
# 32/32 [==============================] - 3s 101ms/step - dice_coef: 0.8966 - accuracy: 0.9175 - f1_score: 0.8966 - loss: -0.8968 - val_dice_coef: 0.6213 - val_accuracy: 0.8576 - val_f1_score: 0.3955 - val_loss: -0.6202 - lr: 0.0031
# Epoch 38/50
# 32/32 [==============================] - 3s 98ms/step - dice_coef: 0.8971 - accuracy: 0.9179 - f1_score: 0.8971 - loss: -0.8968 - val_dice_coef: 0.6078 - val_accuracy: 0.8548 - val_f1_score: 0.3777 - val_loss: -0.6060 - lr: 0.0031
# Epoch 39/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8943 - accuracy: 0.9178 - f1_score: 0.8944 - loss: -0.8982 - val_dice_coef: 0.6058 - val_accuracy: 0.8547 - val_f1_score: 0.3784 - val_loss: -0.6043 - lr: 0.0031
# Epoch 40/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8994 - accuracy: 0.9181 - f1_score: 0.8994 - loss: -0.8996 - val_dice_coef: 0.6081 - val_accuracy: 0.8548 - val_f1_score: 0.3811 - val_loss: -0.6067 - lr: 0.0031
# Epoch 41/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8940 - accuracy: 0.9179 - f1_score: 0.8940 - loss: -0.8948
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0015625000232830644.
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8940 - accuracy: 0.9179 - f1_score: 0.8940 - loss: -0.8948 - val_dice_coef: 0.6197 - val_accuracy: 0.8565 - val_f1_score: 0.3937 - val_loss: -0.6185 - lr: 0.0031
#
# Completed UNet Training. (Step 04)
# Sat at 11:55:13PM
#
# Completed Unet Evaluation. (Step 04)
#
# Training Results (Step 04):
# - Dice Coef: 91.448%
# - F1 Score: 91.449%
#
# Validation Results (Step 04):
# - Dice Coef: 55.318%
# - F1 Score: 55.309%
#
# Testing Results (Step 04):
# - Dice Coef: 35.858%
# - F1 Score: 35.852%
# Sat at 11:55:20PM
# confusion_unet [[13050177   668709]
#  [  896516   437398]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.94      0.95      0.94  13718886
#          1.0       0.40      0.33      0.36   1333914
#
#     accuracy                           0.90  15052800
#    macro avg       0.67      0.64      0.65  15052800
# weighted avg       0.89      0.90      0.89  15052800
#
#
# EM_Step 04 (07) Complete.
# - Precision: 34.49%
# - SourceDelta: 5.80%
# - StepDelta: 4.05%
# Sat at 11:56:31PM
# ----------------------------------
#
#
#
#
# EM Step 05 begun.
# Sat at 11:56:32PM
#
# Generated Probability Output Map from previous model. (Step 05)
# Sat at 11:56:33PM
#
# Created New Annotation. (Step 05)
# Sat at 11:57:42PM
#
# Created Y_train (1008, 224, 224, 1) and Y_val (60, 224, 224, 1). (Step 05)
# Sat at 11:57:44PM
#
# New Learning Rate: 0.100000. (Step 05)
# *** Building DeepLabv3Plus Network ***
# *** Output_Shape => (None, 224, 224, 1) ***
# Epoch 1/50
# 32/32 [==============================] - 6s 196ms/step - dice_coef: 0.3995 - accuracy: 0.6249 - f1_score: 0.4462 - loss: -0.3960 - val_dice_coef: 0.2103 - val_accuracy: 0.1272 - val_f1_score: 0.2103 - val_loss: -0.2141 - lr: 0.1000
# Epoch 2/50
# 32/32 [==============================] - 3s 92ms/step - dice_coef: 0.6300 - accuracy: 0.8581 - f1_score: 0.6326 - loss: -0.6302 - val_dice_coef: 0.1599 - val_accuracy: 0.7860 - val_f1_score: 0.1599 - val_loss: -0.1656 - lr: 0.1000
# Epoch 3/50
# 32/32 [==============================] - 3s 108ms/step - dice_coef: 0.6589 - accuracy: 0.8683 - f1_score: 0.6603 - loss: -0.6619 - val_dice_coef: 0.4240 - val_accuracy: 0.7925 - val_f1_score: 0.4240 - val_loss: -0.4335 - lr: 0.1000
# Epoch 4/50
# 32/32 [==============================] - 3s 92ms/step - dice_coef: 0.7021 - accuracy: 0.8766 - f1_score: 0.7033 - loss: -0.7020 - val_dice_coef: 0.3464 - val_accuracy: 0.7880 - val_f1_score: 0.3464 - val_loss: -0.3547 - lr: 0.1000
# Epoch 5/50
# 32/32 [==============================] - 3s 92ms/step - dice_coef: 0.7160 - accuracy: 0.8804 - f1_score: 0.7171 - loss: -0.7156 - val_dice_coef: 0.3434 - val_accuracy: 0.8353 - val_f1_score: 0.3433 - val_loss: -0.3534 - lr: 0.1000
# Epoch 6/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.7056 - accuracy: 0.8793 - f1_score: 0.7065 - loss: -0.7055 - val_dice_coef: 0.3587 - val_accuracy: 0.7748 - val_f1_score: 0.3587 - val_loss: -0.3696 - lr: 0.1000
# Epoch 7/50
# 32/32 [==============================] - 4s 110ms/step - dice_coef: 0.7382 - accuracy: 0.8858 - f1_score: 0.7390 - loss: -0.7391 - val_dice_coef: 0.6071 - val_accuracy: 0.8279 - val_f1_score: 0.3587 - val_loss: -0.6002 - lr: 0.1000
# Epoch 8/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.7425 - accuracy: 0.8863 - f1_score: 0.7431 - loss: -0.7417 - val_dice_coef: 0.4085 - val_accuracy: 0.8106 - val_f1_score: 0.1618 - val_loss: -0.3972 - lr: 0.1000
# Epoch 9/50
# 32/32 [==============================] - 3s 104ms/step - dice_coef: 0.7375 - accuracy: 0.8869 - f1_score: 0.7381 - loss: -0.7396 - val_dice_coef: 0.5684 - val_accuracy: 0.8454 - val_f1_score: 0.3331 - val_loss: -0.5617 - lr: 0.1000
# Epoch 10/50
# 32/32 [==============================] - 3s 93ms/step - dice_coef: 0.7618 - accuracy: 0.8917 - f1_score: 0.7623 - loss: -0.7634 - val_dice_coef: 0.5650 - val_accuracy: 0.8548 - val_f1_score: 0.3867 - val_loss: -0.5638 - lr: 0.1000
# Epoch 11/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.7594 - accuracy: 0.8933 - f1_score: 0.7599 - loss: -0.7596 - val_dice_coef: 0.3301 - val_accuracy: 0.8274 - val_f1_score: 0.3301 - val_loss: -0.3376 - lr: 0.1000
# Epoch 12/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.7745 - accuracy: 0.8949 - f1_score: 0.7750 - loss: -0.7740
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.7745 - accuracy: 0.8949 - f1_score: 0.7750 - loss: -0.7740 - val_dice_coef: 0.5492 - val_accuracy: 0.8371 - val_f1_score: 0.3843 - val_loss: -0.5491 - lr: 0.1000
# Epoch 13/50
# 32/32 [==============================] - 4s 111ms/step - dice_coef: 0.8024 - accuracy: 0.9001 - f1_score: 0.8028 - loss: -0.8026 - val_dice_coef: 0.6425 - val_accuracy: 0.8644 - val_f1_score: 0.4379 - val_loss: -0.6413 - lr: 0.0500
# Epoch 14/50
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8089 - accuracy: 0.9025 - f1_score: 0.8093 - loss: -0.8086 - val_dice_coef: 0.5186 - val_accuracy: 0.8608 - val_f1_score: 0.4438 - val_loss: -0.5253 - lr: 0.0500
# Epoch 15/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8096 - accuracy: 0.9028 - f1_score: 0.8100 - loss: -0.8090 - val_dice_coef: 0.0537 - val_accuracy: 0.8154 - val_f1_score: 0.0081 - val_loss: -0.0507 - lr: 0.0500
# Epoch 16/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8141 - accuracy: 0.9031 - f1_score: 0.8145 - loss: -0.8145 - val_dice_coef: 0.6361 - val_accuracy: 0.8653 - val_f1_score: 0.4477 - val_loss: -0.6366 - lr: 0.0500
# Epoch 17/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8304 - accuracy: 0.9070 - f1_score: 0.8308 - loss: -0.8300 - val_dice_coef: 0.5011 - val_accuracy: 0.8652 - val_f1_score: 0.4547 - val_loss: -0.5108 - lr: 0.0500
# Epoch 18/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8308 - accuracy: 0.9077 - f1_score: 0.8311 - loss: -0.8339
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8308 - accuracy: 0.9077 - f1_score: 0.8311 - loss: -0.8339 - val_dice_coef: 0.4754 - val_accuracy: 0.8576 - val_f1_score: 0.4258 - val_loss: -0.4838 - lr: 0.0500
# Epoch 19/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8460 - accuracy: 0.9102 - f1_score: 0.8463 - loss: -0.8489 - val_dice_coef: 0.5031 - val_accuracy: 0.8677 - val_f1_score: 0.4638 - val_loss: -0.5131 - lr: 0.0250
# Epoch 20/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8459 - accuracy: 0.9110 - f1_score: 0.8462 - loss: -0.8457 - val_dice_coef: 0.4839 - val_accuracy: 0.8677 - val_f1_score: 0.4752 - val_loss: -0.4959 - lr: 0.0250
# Epoch 21/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8504 - accuracy: 0.9123 - f1_score: 0.8508 - loss: -0.8537 - val_dice_coef: 0.4601 - val_accuracy: 0.8627 - val_f1_score: 0.4557 - val_loss: -0.4725 - lr: 0.0250
# Epoch 22/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8694 - accuracy: 0.9149 - f1_score: 0.8697 - loss: -0.8693 - val_dice_coef: 0.4566 - val_accuracy: 0.8633 - val_f1_score: 0.4504 - val_loss: -0.4693 - lr: 0.0250
# Epoch 23/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8661 - accuracy: 0.9153 - f1_score: 0.8664 - loss: -0.8658
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8661 - accuracy: 0.9153 - f1_score: 0.8664 - loss: -0.8658 - val_dice_coef: 0.4912 - val_accuracy: 0.8721 - val_f1_score: 0.4836 - val_loss: -0.5040 - lr: 0.0250
# Epoch 24/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8644 - accuracy: 0.9150 - f1_score: 0.8648 - loss: -0.8643 - val_dice_coef: 0.4954 - val_accuracy: 0.8683 - val_f1_score: 0.4716 - val_loss: -0.5071 - lr: 0.0125
# Epoch 25/50
# 32/32 [==============================] - 3s 99ms/step - dice_coef: 0.8771 - accuracy: 0.9176 - f1_score: 0.8774 - loss: -0.8766 - val_dice_coef: 0.4750 - val_accuracy: 0.8651 - val_f1_score: 0.4516 - val_loss: -0.4858 - lr: 0.0125
# Epoch 26/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8897 - accuracy: 0.9187 - f1_score: 0.8900 - loss: -0.8895 - val_dice_coef: 0.4680 - val_accuracy: 0.8665 - val_f1_score: 0.4479 - val_loss: -0.4794 - lr: 0.0125
# Epoch 27/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.8879 - accuracy: 0.9188 - f1_score: 0.8882 - loss: -0.8877 - val_dice_coef: 0.4795 - val_accuracy: 0.8674 - val_f1_score: 0.4608 - val_loss: -0.4908 - lr: 0.0125
# Epoch 28/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8974 - accuracy: 0.9202 - f1_score: 0.8977 - loss: -0.8973
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 32/32 [==============================] - 4s 114ms/step - dice_coef: 0.8974 - accuracy: 0.9202 - f1_score: 0.8977 - loss: -0.8973 - val_dice_coef: 0.4955 - val_accuracy: 0.8640 - val_f1_score: 0.4450 - val_loss: -0.5047 - lr: 0.0125
# Epoch 29/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.9004 - accuracy: 0.9206 - f1_score: 0.9007 - loss: -0.9004 - val_dice_coef: 0.5124 - val_accuracy: 0.8669 - val_f1_score: 0.4531 - val_loss: -0.5212 - lr: 0.0063
# Epoch 30/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8879 - accuracy: 0.9200 - f1_score: 0.8883 - loss: -0.8878 - val_dice_coef: 0.4873 - val_accuracy: 0.8675 - val_f1_score: 0.4585 - val_loss: -0.4984 - lr: 0.0063
# Epoch 31/50
# 32/32 [==============================] - 3s 96ms/step - dice_coef: 0.9006 - accuracy: 0.9211 - f1_score: 0.9009 - loss: -0.9005 - val_dice_coef: 0.4663 - val_accuracy: 0.8686 - val_f1_score: 0.4536 - val_loss: -0.4780 - lr: 0.0063
# Epoch 32/50
# 32/32 [==============================] - 3s 95ms/step - dice_coef: 0.8978 - accuracy: 0.9212 - f1_score: 0.8982 - loss: -0.8978 - val_dice_coef: 0.4473 - val_accuracy: 0.8654 - val_f1_score: 0.4373 - val_loss: -0.4587 - lr: 0.0063
# Epoch 33/50
# 32/32 [==============================] - ETA: 0s - dice_coef: 0.8949 - accuracy: 0.9209 - f1_score: 0.8953 - loss: -0.8948
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# 32/32 [==============================] - 3s 94ms/step - dice_coef: 0.8949 - accuracy: 0.9209 - f1_score: 0.8953 - loss: -0.8948 - val_dice_coef: 0.4454 - val_accuracy: 0.8642 - val_f1_score: 0.4322 - val_loss: -0.4564 - lr: 0.0063
#
# Completed UNet Training. (Step 05)
# Sat at 11:59:53PM
#
# Completed Unet Evaluation. (Step 05)
#
# Training Results (Step 05):
# - Dice Coef: 90.380%
# - F1 Score: 90.381%
#
# Validation Results (Step 05):
# - Dice Coef: 59.826%
# - F1 Score: 59.822%
#
# Testing Results (Step 05):
# - Dice Coef: 44.280%
# - F1 Score: 44.263%
# Sun at 12:00:00AM
# confusion_unet [[13064094   654792]
#  [  768683   565231]]
# report_unet               precision    recall  f1-score   support
#
#          0.0       0.94      0.95      0.95  13718886
#          1.0       0.46      0.42      0.44   1333914
#
#     accuracy                           0.91  15052800
#    macro avg       0.70      0.69      0.70  15052800
# weighted avg       0.90      0.91      0.90  15052800
#
#
# EM_Step 05 (08) Complete.
# - Precision: 37.90%
# - SourceDelta: 9.20%
# - StepDelta: 3.41%
# Sun at 12:01:13AM
# ----------------------------------

# %% [markdown]
# ### Save Test Data

# %%
""" Save EM step data to csv
with open(os.path.join(test.dir, 'EM_Data.csv'), 'a+', newline='\n') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter= ',')
    csvwriter.writerow([test.name, 'Line Precisions (delta)', 'Train Dice Coef (delta)', 'Train F1 Score (delta)', 'Val Dice Coef (delta)', 'Val F1 Score (delta)', 'Test Dice Coef (delta)', 'Test F1 Score (delta)'])
    for i in range(len(dataMatrix['precision'])):
        row = ['step {:02}'.format(i)]
        for key, item in dataMatrix.items():
            row.append('{} ({})'.format(item[i], item[i]-item[0]))
        csvwriter.writerow(row)
"""

# Index test in master csv
test.index()

# Write test Info to Markdown
test.markdown()

# Print Completion
print("Data successfully saved to markdown file, indexed on csv.") 
print(dt.now().strftime('%a at %I:%M:%S%p'))
# Out:
# Data successfully saved to markdown file, indexed on csv.
# Sun at 12:01:13AM
